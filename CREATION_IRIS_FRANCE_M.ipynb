# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option("display.max_row",50)
pd.set_option("display.max_columns",130)

# %%
data_orig = pd.read_excel("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER_VERSION_2/base-ic-couples-familles-menages-2017.xlsx", header=5)
data = data_orig.copy()

# %%
###################### CODES EN FRANCE METROPOLITAINE ##################

data_metro = data.copy()
temp_sup_97501 = 0
temp_lettre = 0
for k in data["COM"].value_counts().index:
    try:
        temp_k = int(k)
        if (temp_k >= 97000):
            temp_sup_97501 = temp_sup_97501 + 1
            print(temp_k)
            data_metro = data_metro[data_metro["COM"]!=k]
            
    except:
        temp_lettre = temp_lettre +1
        #print(k)
# Out:
# 97411
# 97415
# 97209
# 97416
# 97422
# 97101
# 97302
# 97414
# 97407
# 97409
# 97410
# 97418
# 97412
# 97408
# 97413
# 97213
# 97420
# 97229
# 97419
# 97304
# 97117
# 97307
# 97421
# 97210
# 97120
# 97222
# 97311
# 97107
# 97116
# 97228
# 97113
# 97129
# 97118
# 97128
# 97103
# 97224
# 97404
# 97309
# 97220
# 97417
# 97230
# 97405
# 97105
# 97207
# 97424
# 97402
# 97115
# 97221
# 97423
# 97212
# 97401
# 97125
# 97227
# 97119
# 97106
# 97124
# 97109
# 97232
# 97132
# 97403
# 97121
# 97214
# 97104
# 97223
# 97134
# 97217
# 97306
# 97305
# 97114
# 97102
# 97122
# 97112
# 97215
# 97234
# 97301
# 97204
# 97226
# 97202
# 97231
# 97111
# 97357
# 97218
# 97406
# 97208
# 97353
# 97108
# 97308
# 97211
# 97110
# 97313
# 97216
# 97356
# 97131
# 97358
# 97201
# 97133
# 97361
# 97225
# 97352
# 97130
# 97360
# 97206
# 97126
# 97219
# 97203
# 97362
# 97205
# 97310
# 97233
# 97312
# 97314
# 97303

# %%
data_metro
# Out:
#             IRIS  REG DEP UU2010    COM                   LIBCOM  TRIRIS  \
# 0      010010000   84  01  01000  01001  L'Abergement-Clémenciat  ZZZZZZ
# 1      010020000   84  01  01000  01002    L'Abergement-de-Varey  ZZZZZZ
# 2      010040101   84  01  01302  01004        Ambérieu-en-Bugey  ZZZZZZ
# 3      010040102   84  01  01302  01004        Ambérieu-en-Bugey  ZZZZZZ
# 4      010040201   84  01  01302  01004        Ambérieu-en-Bugey  ZZZZZZ
# ...          ...  ...  ..    ...    ...                      ...     ...
# 48585  956800112   11  95  00851  95680          Villiers-le-Bel  951021
# 48586  956800113   11  95  00851  95680          Villiers-le-Bel  951021
# 48587  956800114   11  95  00851  95680          Villiers-le-Bel  951021
# 48588  956820000   11  95  95000  95682          Villiers-le-Sec  ZZZZZZ
# 48589  956900000   11  95  95000  95690      Wy-dit-Joli-Village  ZZZZZZ
#
#       GRD_QUART                                       LIBIRIS TYP_IRIS  \
# ...

# %%
data_metro["IRIS"].value_counts() # pas de doublons
# Out:
# 031850112    1
# 292330105    1
# 542380000    1
# 390100000    1
# 682540000    1
#             ..
# 352740000    1
# 606260000    1
# 452650000    1
# 060690107    1
# 570370000    1
# Name: IRIS, Length: 48590, dtype: int64

# %%
# ENREGISTREMENT
data_metro.to_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER_VERSION_2/IRIS_FM.txt",sep=";", index=False)
