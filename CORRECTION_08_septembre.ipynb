# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option("display.max_row",50)
pd.set_option("display.max_columns",130)

# %%
# LOUIS
data_louis_orig = pd.read_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER_VERSION_2/Geo_bureaux_de_vote_access.txt",sep=";", header=0, dtype=str)
data_louis = data_louis_orig.copy()
print(data_louis.shape)
data_louis.iloc[70045:70045+1,:]
# Out:
# (70048, 25)
#       commune_code                  libelle code code_corr Code du bvote  \
# 70045        14563  Saint-Benoît-d'Hébertot  001       NaN          0001
#
#       Code du bvote_sans 0 devant               libelle_bv num_voie  \
# 70045                           1  SAINT BENOIT D'HEBERTOT      185
#
#                     voie complement1 complement2 lieu_dit code_postal  \
# 70045  route de l'Eglise      Mairie         NaN      NaN       14130
#
#                        commune canton_code circonscription_code longitude  \
# 70045  SAINT BENOIT D'HEBERTOT       14-21                14-04   0.27055
#
#         latitude geo_score geo_type  \
# 70045  49.316366      0.62   street
#
#                                             geo_adresse        geo_id  \
# 70045  Chemin de l'Eglise 14130 Saint-Benoît-d'Hébertot  14563_396noi
#
#       geo_ligne              geo_l4 geo_l5
# 70045         G  CHEMIN DE L EGLISE    NaN

# %%
data_louis["longitude"].isnull().sum(), data_louis["latitude"].isnull().sum()
# Out:
# (9010, 9050)

# %%
nom_longitude = 0
index_total = data_louis.index
index_int = []
index_autre= []

for k in index_total:
    try :
        float(data_louis.loc[k,"longitude"])
        index_int.append(k)
    except:
        nom_longitude = nom_longitude + 1
        index_autre.append(k)

# %%
print(data_louis.loc[index_int,:].shape, data_louis.loc[index_autre,:].shape)
base_int = data_louis.loc[index_int,:]
base_autre = data_louis.loc[index_autre,:]
# Out:
# (67353, 25) (2695, 25)

# %%
base_autre["longitude"] = base_autre["latitude"].copy()
base_autre["latitude"] = base_autre["geo_score"].copy()

data_louis = pd.concat([base_int,base_autre],axis=0)
data_louis.shape
# Out:
# (70048, 25)

# %%
base_autre[base_autre["longitude"].isnull()].shape
# Out:
# (42, 25)

# %%
(base_int[base_int["longitude"].isnull()]["geo_score"]!="0").sum()
# Out:
# 9

# %%
base_int[base_int["longitude"].isnull()][base_int[base_int["longitude"].isnull()]["geo_score"] !="0"]
# Out:
#       commune_code                    libelle code code_corr Code du bvote  \
# 5551         31079                     Bouloc    2       NaN          0002
# 7309         70174                  Cordonnet    1       NaN          0001
# 7310       Mairie"                        NaN  NaN       NaN           NaN
# 31844        63209                 Mareugheol  001       NaN          0001
# 36387        67480                      Still   01       NaN          0001
# 37203        98734                     Papara   01       NaN          0001
# 38578        57446    Marimont-lès-Bénestroff    1       NaN          0001
# 46192        76123  Bosc-Guérard-Saint-Adrien    1       NaN          0001
# 52584        74211                 Pers-Jussy    1       NaN          0001
#
#       Code du bvote_sans 0 devant                    libelle_bv num_voie  \
# 5551                            2                     Bureau 02      NaN
# ...

# %%
[base_int[base_int["longitude"].isnull()]["geo_score"]!="0"]
# Out:
# (9010, 25)

# %%
nom_longitude = 0
for k in range(base_autre.shape[0]):
    try :
        float(base_autre.iloc[k,13])
        
    except:
        nom_longitude = nom_longitude + 1
        #print(bv_louis.iloc[k,13])
        
nom_latitude = 0
for k in range(base_autre.shape[0]):
    try :
        float(base_autre.iloc[k,14])

    except:
        nom_latitude = nom_latitude + 1
        
print(nom_longitude,nom_latitude)
# Out:
# 4 2364

# %%
""" 
nom_longitude = 0
index_total = data_louis.index

base_1 = pd.DataFrame(columns = data_louis.columns)
base_2 = pd.DataFrame(columns = data_louis.columns)

for k in range(data_louis.shape[0]):
    try :
        float(data_louis.iloc[k,16])
        base_1 = pd.concat([base_1, pd.DataFrame(data_louis.iloc[k,:]).T], axis = 0)
    except:
        nom_longitude = nom_longitude + 1
        base_2 = pd.concat([base_2, pd.DataFrame(data_louis.iloc[k,:]).T], axis = 0)
"""
# Out:
# ' \nnom_longitude = 0\nindex_total = data_louis.index\n\nbase_1 = pd.DataFrame(columns = data_louis.columns)\nbase_2 = pd.DataFrame(columns = data_louis.columns)\n\nfor k in range(data_louis.shape[0]):\n    try :\n        float(data_louis.iloc[k,16])\n        base_1 = pd.concat([base_1, pd.DataFrame(data_louis.iloc[k,:]).T], axis = 0)\n    except:\n        nom_longitude = nom_longitude + 1\n        base_2 = pd.concat([base_2, pd.DataFrame(data_louis.iloc[k,:]).T], axis = 0)\n'

# %%
nom_latitude = 0
index_lati = []
for k in range(data_louis.shape[0]):
    try :
        float(data_louis.iloc[k,17])
       
    except:
        nom_latitude = nom_latitude + 1

# %%
nom_longitude,nom_latitude
# Out:
# (4, 14)

# %%
#########################################################################################
#                               DOUBLONS ET NAN COORDONEEES
#########################################################################################
#louis_sans_doublons= data_louis
louis_sans_doublons= data_louis.drop_duplicates(subset=["code","longitude","latitude"])
print(louis_sans_doublons.shape)
louis_sans_doublons = louis_sans_doublons[louis_sans_doublons["latitude"].isnull()==False]
print(louis_sans_doublons.shape)
# Out:
# (61527, 25)
# (60991, 25)

# %%
###################### CODES EN FRANCE METROPOLITAINE ##################

louis_sans_nan_doublons_sup_97501 = louis_sans_doublons.copy()
temp_sup_97501 = 0
temp_lettre = 0
for k in louis_sans_doublons["commune_code"].value_counts().index:
    try:
        temp_k = int(k)
        if (temp_k >= 97000):
            temp_sup_97501 = temp_sup_97501 + 1
            print(temp_k)
            louis_sans_nan_doublons_sup_97501 = louis_sans_nan_doublons_sup_97501[louis_sans_nan_doublons_sup_97501["commune_code"]!=k]
            
    except:
        temp_lettre = temp_lettre +1
        #print(k)
# Out:
# 97411
# 97415
# 97416
# 97422
# 97209
# 97414
# 97412
# 97101
# 97409
# 97410
# 97413
# 97418
# 97407
# 97408
# 97420
# 97611
# 97213
# 97107
# 97103
# 97128
# 97117
# 97118
# 97113
# 97120
# 97302
# 97116
# 97228
# 97222
# 97115
# 97404
# 97125
# 97307
# 97405
# 97210
# 97224
# 97401
# 97105
# 97604
# 97230
# 97309
# 97304
# 97132
# 97207
# 97229
# 97220
# 97124
# 97610
# 97227
# 97311
# 97602
# 97212
# 97603
# 97221
# 97614
# 97119
# 97223
# 97617
# 97421
# 97612
# 97605
# 97601
# 97608
# 97102
# 97424
# 97121
# 97423
# 97305
# 97607
# 97616
# 97114
# 97417
# 97104
# 97106
# 97403
# 97214
# 97217
# 97122
# 97406
# 97109
# 97111
# 97609
# 97615
# 97225
# 97226
# 97606
# 97112
# 97218
# 97216
# 97205
# 97204
# 97206
# 97203
# 97202
# 97126
# 97613
# 97134
# 97306
# 97310
# 97110
# 97234
# 97360
# 97130
# 97232
# 97308
# 97133
# 97362
# 97219
# 97312
# 97313
# 97301
# 97131
# 97129
# 97419
# 97231
# 97108
# 97356
# 97201
# 97361
# 97215
# 97208
# 98734
# 97358
# 97211
# 97357
# 97352
# ...

# %%
louis_sans_nan_doublons_sup_97501.loc[36387,"longitude"] =louis_sans_nan_doublons_sup_97501.loc[36387,"geo_type"]
louis_sans_nan_doublons_sup_97501.loc[36387,"latitude"] = louis_sans_nan_doublons_sup_97501.loc[36387,"geo_adresse"]

# %%
louis_sans_nan_doublons_sup_97501["CHR_CODE"] = louis_sans_nan_doublons_sup_97501["commune_code"]+louis_sans_nan_doublons_sup_97501["Code du bvote_sans 0 devant"]
louis_sans_nan_doublons_sup_97501.head(1)
# Out:
#   commune_code libelle code code_corr Code du bvote  \
# 0        59350   Lille  807       NaN          0807
#
#   Code du bvote_sans 0 devant    libelle_bv num_voie        voie complement1  \
# 0                         807  ECOLE AMPERE       64  RUE D'IENA         NaN
#
#   complement2 lieu_dit code_postal commune canton_code circonscription_code  \
# 0         NaN      NaN       59000   LILLE       59-27                59-11
#
#   longitude   latitude geo_score geo_type             geo_adresse      geo_id  \
# 0  3.043027  50.621124      0.96   street  Rue d'Iena 59000 Lille  59350_4658
#
#   geo_ligne      geo_l4 geo_l5  CHR_CODE
# 0         G  RUE D IENA    NaN  59350807

# %%
# SANS DOUBLONS "CHR_CODE"
louis_sans_nan_doublons_sup_97501 = louis_sans_nan_doublons_sup_97501.drop_duplicates(subset=["CHR_CODE"])
louis_sans_nan_doublons_sup_97501.shape
# Out:
# (59092, 26)

# %%
70048-69959
# Out:
# 89

# %%
# vérification 1
print(louis_sans_nan_doublons_sup_97501["geo_score"].isnull().sum())
louis_sans_nan_doublons_sup_97501[louis_sans_nan_doublons_sup_97501["geo_score"].isnull()]
# Out:
# 0
# Empty DataFrame
# Columns: [commune_code, libelle, code, code_corr, Code du bvote, Code du bvote_sans 0 devant, libelle_bv, num_voie, voie, complement1, complement2, lieu_dit, code_postal, commune, canton_code, circonscription_code, longitude, latitude, geo_score, geo_type, geo_adresse, geo_id, geo_ligne, geo_l4, geo_l5, CHR_CODE]
# Index: []

# %%
# index
louis_sans_nan_doublons_sup_97501[louis_sans_nan_doublons_sup_97501["geo_score"].isnull()]
index_elim=louis_sans_nan_doublons_sup_97501[louis_sans_nan_doublons_sup_97501["geo_score"].isnull()].index

# %%
# effacer
for i in index_elim:
    louis_sans_nan_doublons_sup_97501 =  louis_sans_nan_doublons_sup_97501.drop(i,0)

# %%
# vérification 2
louis_sans_nan_doublons_sup_97501["geo_score"].isnull().sum()
# Out:
# 0

# %%
# CORRECTION D'UNE LIGNE
louis_sans_nan_doublons_sup_97501[louis_sans_nan_doublons_sup_97501["libelle_bv"]=="ANCIENNE CURE"]
# Out:
#       commune_code             libelle  code code_corr Code du bvote  \
# 45678        85151  Mortagne-sur-Sèvre  0004       NaN          0004
# 65731        42154             Néronde     1       NaN          0001
#
#       Code du bvote_sans 0 devant     libelle_bv num_voie             voie  \
# 45678                           4  ANCIENNE CURE      NaN  1 rue du Centre
# 65731                           1  ANCIENNE CURE    42510          NERONDE
#
#       complement1 complement2 lieu_dit code_postal             commune  \
# 45678     Evrunes         NaN      NaN       85290  MORTAGNE SUR SEVRE
# 65731         NaN         NaN      NaN       42510             NÉRONDE
#
#       canton_code circonscription_code  longitude   latitude geo_score  \
# 45678       85-11                85-04  -0.971915  47.000255      0.95
# 65731       42-04                42-06   2.127469  22.927179      0.93
#
#            geo_type                               geo_adresse  \
# ...

# %%
louis_sans_nan_doublons_sup_97501.loc[65731,"longitude"] = 4.236545
louis_sans_nan_doublons_sup_97501.loc[65731,"latitude"] = 45.838744

# %%
# VERIFICATION
louis_sans_nan_doublons_sup_97501[louis_sans_nan_doublons_sup_97501["libelle_bv"]=="ANCIENNE CURE"]
# Out:
#       commune_code             libelle  code code_corr Code du bvote  \
# 45678        85151  Mortagne-sur-Sèvre  0004       NaN          0004
# 65731        42154             Néronde     1       NaN          0001
#
#       Code du bvote_sans 0 devant     libelle_bv num_voie             voie  \
# 45678                           4  ANCIENNE CURE      NaN  1 rue du Centre
# 65731                           1  ANCIENNE CURE    42510          NERONDE
#
#       complement1 complement2 lieu_dit code_postal             commune  \
# 45678     Evrunes         NaN      NaN       85290  MORTAGNE SUR SEVRE
# 65731         NaN         NaN      NaN       42510             NÉRONDE
#
#       canton_code circonscription_code  longitude   latitude geo_score  \
# 45678       85-11                85-04  -0.971915  47.000255      0.95
# 65731       42-04                42-06   4.236545  45.838744      0.93
#
#            geo_type                               geo_adresse  \
# ...

# %%
# PIERRE
bv_euro_brut = pd.read_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER_VERSION_2/Resultats-definitifs-par-bureau-de-vote_access.txt",sep=";",header=0, dtype=str,encoding="iso-8859-1")
bv_euro =bv_euro_brut.copy()
print(bv_euro.shape )
bv_euro.head(1)
# Out:
# (69297, 226)
#   Code_INSEE Code_commune Code du département Libellé du département  \
# 0      01004        01004                  01                    Ain
#
#   Code de la commune Libellé de la commune Code du bvote  \
# 0                004     Ambérieu-en-Bugey          0008
#
#   Code du bvote_sans 0 devant Inscrits Abstentions % Abs/Ins Votants  \
# 0                           8      978         476     48,67     502
#
#   % Vot/Ins Blancs % Blancs/Ins % Blancs/Vot Nuls % Nuls/Ins % Nuls/Vot  \
# 0     51,33     16         1,64         3,19    6       0,61       1,20
#
#   Exprimés % Exp/Ins % Exp/Vot N°Liste_1 Libellé Abrégé Liste_1  \
# 0      480     49,08     95,62         1    LA FRANCE INSOUMISE
#
#   Nom Tête de Liste_1 Voix_1 % Voix/Ins_1 % Voix/Exp_1 N°Liste_2  \
# 0         AUBRY Manon     35         3,58         7,29         2
#
#   Libellé Abrégé Liste_2  Nom Tête de Liste_2 Voix_2 % Voix/Ins_2  \
# 0      UNE FRANCE ROYALE  DE PREVOISIN Robert      0            0
# ...

# %%
# EFFACER LES BV A L'ETRANGER
liste_a_effacer=["ZD","ZA","ZB","ZN","ZP","ZZ","ZM","ZC","ZX","ZS","ZW"]
inscrit_etranger=0
votant_etranger=0
for i in liste_a_effacer:
    inscrit_etranger = inscrit_etranger + bv_euro[bv_euro["Code du département"]==i]["Inscrits"].astype(int).sum()
    votant_etranger = votant_etranger + bv_euro[bv_euro["Code du département"]==i]["Votants"].astype(int).sum()
    
    bv_euro = bv_euro[bv_euro["Code du département"]!=i]
bv_euro.shape, inscrit_etranger, votant_etranger
# Out:
# ((66578, 226), 3114713, 643090)

# %%
## DROP COLONNES
bv_euro = bv_euro.iloc[:,:12]
bv_euro.head(1)
# Out:
#   Code_INSEE Code_commune Code du département Libellé du département  \
# 0      01004        01004                  01                    Ain
#
#   Code de la commune Libellé de la commune Code du bvote  \
# 0                004     Ambérieu-en-Bugey          0008
#
#   Code du bvote_sans 0 devant Inscrits Abstentions % Abs/Ins Votants
# 0                           8      978         476     48,67     502

# %%
bv_euro["CHR_CODE"] = bv_euro["Code_commune"]+bv_euro["Code du bvote_sans 0 devant"]
bv_euro.head(1)
# Out:
#   Code_INSEE Code_commune Code du département Libellé du département  \
# 0      01004        01004                  01                    Ain
#
#   Code de la commune Libellé de la commune Code du bvote  \
# 0                004     Ambérieu-en-Bugey          0008
#
#   Code du bvote_sans 0 devant Inscrits Abstentions % Abs/Ins Votants CHR_CODE
# 0                           8      978         476     48,67     502   010048

# %%
jointure_interne = louis_sans_nan_doublons_sup_97501.merge(bv_euro, on = "CHR_CODE")
jointure_interne
# Out:
#       commune_code                 libelle  code code_corr Code du bvote_x  \
# 0            59350                   Lille   807       NaN            0807
# 1            50502                Saint-Lô   008       NaN            0008
# 2            56121                 Lorient    11       NaN            0011
# 3            76558  Saint-Aubin-Celloville     1       NaN            0001
# 4            70407                Perrouse     1       NaN            0001
# ...            ...                     ...   ...       ...             ...
# 57431        69096                  Grigny  0004       NaN            0004
# 57432        69096                  Grigny  0006       NaN            0006
# 57433        49200      Longuenée-en-Anjou     3       NaN            0003
# 57434        02275                   Effry     1       NaN            0001
# 57435        76263             La Feuillie     1       NaN            0001
#
# ...

# %%
data_louis_orig.shape, bv_euro.shape
# Out:
# ((70048, 25), (66578, 13))

# %%
inscri_total = bv_euro["Inscrits"].astype(int)
inscri_total.sum()
# Out:
# 44230615

# %%
inscri_recon = jointure_interne["Inscrits"].astype(int)
inscri_recon.sum()
# Out:
# 39862311

# %%
(44230615-39862311)/44230615
# Out:
# 0.09876200003097402

# %%
44230615 - 43269823, 961113 - 960792 # 961113 (taille de commune du fichier Pierre)
# Out:
# (960792, 321)

# %%
################################ table_non_recon ###############################

# %%
table_non_recon = bv_euro.merge(jointure_interne,on="CHR_CODE", how="left")[bv_euro.merge(jointure_interne,on="CHR_CODE", how="left")["Code_commune_y"].isnull()][["Code_commune_x","Libellé de la commune_x","Inscrits_x"] ] 
table_non_recon
# Out:
#       Code_commune_x Libellé de la commune_x Inscrits_x
# 4              01015         Arboys en Bugey        116
# 79             01045                 Birieux        200
# 113            01063                   Brion        379
# 118            01067                 Ceignes        208
# 124            01072               Ceyzériat       1055
# ...              ...                     ...        ...
# 66316          95447        Neuilly-en-Vexin        138
# 66352          95489                  Piscop        503
# 66360          95492       Le Plessis-Gassot         41
# 66389          95509       Puiseux-en-France        339
# 66515          95607                 Taverny        744
#
# [9142 rows x 3 columns]

# %%
table_non_recon["id"] = table_non_recon["Code_commune_x"]+table_non_recon["Libellé de la commune_x"]

# %%
table_non_recon["Inscrits_x"] = table_non_recon["Inscrits_x"].astype(int)

# %%
table_non_recon["id"].value_counts()
# Out:
# 76351Le Havre            112
# 37261Tours                84
# 30189Nîmes                84
# 84007Avignon              70
# 17300La Rochelle          40
#                         ...
# 10306Proverville           1
# 56065Gourhel               1
# 50237La Haye-Pesnel        1
# 23260Vidaillat             1
# 19117Lissac-sur-Couze      1
# Name: id, Length: 6948, dtype: int64

# %%
table_non_recon["Code_commune_x"].value_counts()
# Out:
# 76351    112
# 37261     84
# 30189     84
# 84007     70
# 17300     40
#         ...
# 55244      1
# 77248      1
# 70419      1
# 33153      1
# 77457      1
# Name: Code_commune_x, Length: 6948, dtype: int64

# %%
table_inscrit_x = table_non_recon.groupby(['Code_commune_x',"Libellé de la commune_x"]).sum().sort_values(by=['Inscrits_x'], ascending=False)
table_inscrit_x
# Out:
#                                         Inscrits_x
# Code_commune_x Libellé de la commune_x
# 76351          Le Havre                     103885
# 30189          Nîmes                         87478
# 37261          Tours                         79122
# 84007          Avignon                       55029
# 17300          La Rochelle                   35932
# ...                                            ...
# 65379          Ris                              12
# 55394          Ornes                            11
# 52109          Charmes-en-l'Angle               11
# 26274          Rochefourchat                     8
# 54310          Leménil-Mitry                     5
#
# [6948 rows x 1 columns]

# %%
table_non_recon[table_non_recon["Code_commune_x"]=="76351"]["Inscrits_x"].sum()
# Out:
# 103885

# %%
bv_euro.shape
# Out:
# (66578, 13)

# %%
57436+9142    #4368304 Inscrits_x"].astype(int).sum()
# Out:
# 66578

# %%
table_code_commune_x = pd.DataFrame(table_non_recon['Code_commune_x'].value_counts())
#table_code_commune_x
table_code_commune_x.rename(columns={'Code_commune_x':"Nb_non_reconcilies"}, inplace=True)
ttt= pd.DataFrame(table_code_commune_x.index,columns=["Code_commune_x"], index = range(table_code_commune_x.shape[0]))
#ttt

table_code_commune_x.index =range(table_code_commune_x.shape[0])
#table_code_commune_x
deux_col=pd.concat([ttt,table_code_commune_x], axis=1)
#deux_col
table_inscrit_x_nb_non_recon = table_inscrit_x.merge(deux_col, on="Code_commune_x")
table_inscrit_x_nb_non_recon
# Out:
#      Code_commune_x  Inscrits_x  Nb_non_reconcilies
# 0             76351      103885                 112
# 1             30189       87478                  84
# 2             37261       79122                  84
# 3             84007       55029                  70
# 4             17300       35932                  40
# ...             ...         ...                 ...
# 6943          65379          12                   1
# 6944          55394          11                   1
# 6945          52109          11                   1
# 6946          26274           8                   1
# 6947          54310           5                   1
#
# [6948 rows x 3 columns]

# %%
table_avant_final = table_inscrit_x_nb_non_recon.merge(table_non_recon, on="Code_commune_x", how="left").drop_duplicates(subset="Code_commune_x").iloc[:,:-2]
talbe_final_non_recon =table_avant_final[["Code_commune_x","Libellé de la commune_x","Inscrits_x_x","Nb_non_reconcilies"]]
talbe_final_non_recon
# Out:
#      Code_commune_x Libellé de la commune_x  Inscrits_x_x  Nb_non_reconcilies
# 0             76351                Le Havre        103885                 112
# 112           30189                   Nîmes         87478                  84
# 196           37261                   Tours         79122                  84
# 280           84007                 Avignon         55029                  70
# 350           17300             La Rochelle         35932                  40
# ...             ...                     ...           ...                 ...
# 9137          65379                     Ris            12                   1
# 9138          55394                   Ornes            11                   1
# 9139          52109      Charmes-en-l'Angle            11                   1
# 9140          26274           Rochefourchat             8                   1
# 9141          54310           Leménil-Mitry             5                   1
#
# [6948 rows x 4 columns]

# %%
talbe_final_non_recon
# Out:
#      Code_commune_x Libellé de la commune_x  Inscrits_x_x  Nb_non_reconcilies
# 0             76351                Le Havre        103885                 112
# 112           30189                   Nîmes         87478                  84
# 196           37261                   Tours         79122                  84
# 280           84007                 Avignon         55029                  70
# 350           17300             La Rochelle         35932                  40
# ...             ...                     ...           ...                 ...
# 9137          65379                     Ris            12                   1
# 9138          55394                   Ornes            11                   1
# 9139          52109      Charmes-en-l'Angle            11                   1
# 9140          26274           Rochefourchat             8                   1
# 9141          54310           Leménil-Mitry             5                   1
#
# [6948 rows x 4 columns]

# %%
######################################################################
#                      ENREGISTREMENT
######################################################################
louis_sans_nan_doublons_sup_97501 = louis_sans_nan_doublons_sup_97501.drop(["CHR_CODE"], axis=1)
jointure_interne = jointure_interne.drop(["CHR_CODE"], axis=1)

louis_sans_nan_doublons_sup_97501.to_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER_VERSION_2/louis_sans_nan_sans_doublons_FM.txt",sep=";", index=False)
jointure_interne.to_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER_VERSION_2/jointure_sans_nan_sans_doublons_FM.txt",sep=";", index=False)

talbe_final_non_recon.to_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER_VERSION_2/FM_commune_bv_non_reconciliees.txt",sep=";", index=False)

# %%
###############################################################################################v
###############################################################################################

# %%
bv_euro["Inscrits"].astype(int).sum()
# Out:
# 44230615

# %%
talbe_final_non_recon["Inscrits_x_x"].sum()
# Out:
# 4368304

# %%
jointure_interne["Inscrits"].astype(int).sum()
# Out:
# 39862311

# %%
4368304+39862311
# Out:
# 44230615

# %%
jointure_interne[jointure_interne["longitude"].isnull()]
# Out:
# Empty DataFrame
# Columns: [commune_code, libelle, code, code_corr, Code du bvote_x, Code du bvote_sans 0 devant_x, libelle_bv, num_voie, voie, complement1, complement2, lieu_dit, code_postal, commune, canton_code, circonscription_code, longitude, latitude, geo_score, geo_type, geo_adresse, geo_id, geo_ligne, geo_l4, geo_l5, CHR_CODE, Code_INSEE, Code_commune, Code du département, Libellé du département, Code de la commune, Libellé de la commune, Code du bvote_y, Code du bvote_sans 0 devant_y, Inscrits, Abstentions, % Abs/Ins, Votants]
# Index: []

# %%
louis_sans_nan_doublons_sup_97501[louis_sans_nan_doublons_sup_97501["longitude"].isnull()]
# Out:
# Empty DataFrame
# Columns: [commune_code, libelle, code, code_corr, Code du bvote, Code du bvote_sans 0 devant, libelle_bv, num_voie, voie, complement1, complement2, lieu_dit, code_postal, commune, canton_code, circonscription_code, longitude, latitude, geo_score, geo_type, geo_adresse, geo_id, geo_ligne, geo_l4, geo_l5, CHR_CODE]
# Index: []
