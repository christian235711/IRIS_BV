# %%
nom_colonnes = ['Code du département','Libellé du département','Code de la commune',
 'Libellé de la commune','Code du b.vote','Inscrits', 'Abstentions', '% Abs/Ins', 'Votants',
 '% Vot/Ins', 'Blancs', '% Blancs/Ins', '% Blancs/Vot',
 'Nuls','% Nuls/Ins', '% Nuls/Vot', 'Exprimés', '% Exp/Ins', '% Exp/Vot',
 'N°Liste_1', 'Libellé Abrégé Liste_1', 'Libellé Etendu Liste_1', 'Nom Tête de Liste_1', 'Voix_1', '% Voix/Ins_1', '% Voix/Exp_1',
 'N°Liste_2', 'Libellé Abrégé Liste_2', 'Libellé Etendu Liste_2', 'Nom Tête de Liste_2', 'Voix_2', '% Voix/Ins_2', '% Voix/Exp_2',
 'N°Liste_3', 'Libellé Abrégé Liste_3', 'Libellé Etendu Liste_3', 'Nom Tête de Liste_3', 'Voix_3', '% Voix/Ins_3', '% Voix/Exp_3',
 'N°Liste_4', 'Libellé Abrégé Liste_4', 'Libellé Etendu Liste_4', 'Nom Tête de Liste_4', 'Voix_4', '% Voix/Ins_4', '% Voix/Exp_4',
 'N°Liste_5', 'Libellé Abrégé Liste_5', 'Libellé Etendu Liste_5', 'Nom Tête de Liste_5', 'Voix_5', '% Voix/Ins_5', '% Voix/Exp_5',
 'N°Liste_6', 'Libellé Abrégé Liste_6', 'Libellé Etendu Liste_6', 'Nom Tête de Liste_6', 'Voix_6', '% Voix/Ins_6', '% Voix/Exp_6',
 'N°Liste_7', 'Libellé Abrégé Liste_7', 'Libellé Etendu Liste_7', 'Nom Tête de Liste_7', 'Voix_7', '% Voix/Ins_7', '% Voix/Exp_7',
 'N°Liste_8', 'Libellé Abrégé Liste_8', 'Libellé Etendu Liste_8', 'Nom Tête de Liste_8', 'Voix_8', '% Voix/Ins_8', '% Voix/Exp_8',
 'N°Liste_9', 'Libellé Abrégé Liste_9', 'Libellé Etendu Liste_9', 'Nom Tête de Liste_9', 'Voix_9', '% Voix/Ins_9', '% Voix/Exp_9',
 'N°Liste_10', 'Libellé Abrégé Liste_10', 'Libellé Etendu Liste_10', 'Nom Tête de Liste_10', 'Voix_10', '% Voix/Ins_10', '% Voix/Exp_10',
 'N°Liste_11', 'Libellé Abrégé Liste_11', 'Libellé Etendu Liste_11', 'Nom Tête de Liste_11', 'Voix_11', '% Voix/Ins_11', '% Voix/Exp_11',
 'N°Liste_12', 'Libellé Abrégé Liste_12', 'Libellé Etendu Liste_12', 'Nom Tête de Liste_12', 'Voix_12', '% Voix/Ins_12', '% Voix/Exp_12',
 'N°Liste_13', 'Libellé Abrégé Liste_13', 'Libellé Etendu Liste_13', 'Nom Tête de Liste_13', 'Voix_13', '% Voix/Ins_13', '% Voix/Exp_13',
 'N°Liste_14', 'Libellé Abrégé Liste_14', 'Libellé Etendu Liste_14', 'Nom Tête de Liste_14', 'Voix_14', '% Voix/Ins_14', '% Voix/Exp_14',
 'N°Liste_15', 'Libellé Abrégé Liste_15', 'Libellé Etendu Liste_15', 'Nom Tête de Liste_15', 'Voix_15', '% Voix/Ins_15', '% Voix/Exp_15',
 'N°Liste_16', 'Libellé Abrégé Liste_16', 'Libellé Etendu Liste_16', 'Nom Tête de Liste_16', 'Voix_16', '% Voix/Ins_16', '% Voix/Exp_16',
 'N°Liste_17', 'Libellé Abrégé Liste_17', 'Libellé Etendu Liste_17', 'Nom Tête de Liste_17', 'Voix_17', '% Voix/Ins_17', '% Voix/Exp_17',
 'N°Liste_18', 'Libellé Abrégé Liste_18', 'Libellé Etendu Liste_18', 'Nom Tête de Liste_18', 'Voix_18', '% Voix/Ins_18', '% Voix/Exp_18',
 'N°Liste_19', 'Libellé Abrégé Liste_19', 'Libellé Etendu Liste_19', 'Nom Tête de Liste_19', 'Voix_19', '% Voix/Ins_19', '% Voix/Exp_19',
 'N°Liste_20', 'Libellé Abrégé Liste_20', 'Libellé Etendu Liste_20', 'Nom Tête de Liste_20', 'Voix_20', '% Voix/Ins_20', '% Voix/Exp_20',
 'N°Liste_21', 'Libellé Abrégé Liste_21', 'Libellé Etendu Liste_21', 'Nom Tête de Liste_21', 'Voix_21', '% Voix/Ins_21', '% Voix/Exp_21',
 'N°Liste_22', 'Libellé Abrégé Liste_22', 'Libellé Etendu Liste_22', 'Nom Tête de Liste_22', 'Voix_22', '% Voix/Ins_22', '% Voix/Exp_22',
 'N°Liste_23', 'Libellé Abrégé Liste_23', 'Libellé Etendu Liste_23', 'Nom Tête de Liste_23', 'Voix_23', '% Voix/Ins_23', '% Voix/Exp_23',
 'N°Liste_24', 'Libellé Abrégé Liste_24', 'Libellé Etendu Liste_24', 'Nom Tête de Liste_24', 'Voix_24', '% Voix/Ins_24', '% Voix/Exp_24',
 'N°Liste_25', 'Libellé Abrégé Liste_25', 'Libellé Etendu Liste_25', 'Nom Tête de Liste_25', 'Voix_25', '% Voix/Ins_25', '% Voix/Exp_25',
 'N°Liste_26', 'Libellé Abrégé Liste_26', 'Libellé Etendu Liste_26', 'Nom Tête de Liste_26', 'Voix_26', '% Voix/Ins_26', '% Voix/Exp_26',
 'N°Liste_27', 'Libellé Abrégé Liste_27', 'Libellé Etendu Liste_27', 'Nom Tête de Liste_27', 'Voix_27', '% Voix/Ins_27', '% Voix/Exp_27',
 'N°Liste_28', 'Libellé Abrégé Liste_28', 'Libellé Etendu Liste_28', 'Nom Tête de Liste_28', 'Voix_28', '% Voix/Ins_28', '% Voix/Exp_28',
 'N°Liste_29', 'Libellé Abrégé Liste_29', 'Libellé Etendu Liste_29', 'Nom Tête de Liste_29', 'Voix_29', '% Voix/Ins_29', '% Voix/Exp_29',
 'N°Liste_30', 'Libellé Abrégé Liste_30', 'Libellé Etendu Liste_30', 'Nom Tête de Liste_30', 'Voix_30', '% Voix/Ins_30', '% Voix/Exp_30',
 'N°Liste_31', 'Libellé Abrégé Liste_31', 'Libellé Etendu Liste_31', 'Nom Tête de Liste_31', 'Voix_31', '% Voix/Ins_31', '% Voix/Exp_31',
 'N°Liste_32', 'Libellé Abrégé Liste_32', 'Libellé Etendu Liste_32', 'Nom Tête de Liste_32', 'Voix_32', '% Voix/Ins_32', '% Voix/Exp_32',
 'N°Liste_33', 'Libellé Abrégé Liste_33', 'Libellé Etendu Liste_33', 'Nom Tête de Liste_33', 'Voix_33', '% Voix/Ins_33', '% Voix/Exp_33',
 'N°Liste_34', 'Libellé Abrégé Liste_34', 'Libellé Etendu Liste_34', 'Nom Tête de Liste_34', 'Voix_34', '% Voix/Ins_34', '% Voix/Exp_34']

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option("display.max_row",50)
pd.set_option("display.max_columns",130)

# %%
"""
- nettoyage de données:  doublons, nan, géronde (*2)


"""
# Out:
# '\n- nettoyage de données:  doublons, nan, géronde (*2)\n\n\n'

# %%
# LOUIS
data_louis_orig = pd.read_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER/geo_bureaux_de_vote.csv", encoding="utf" )
print(data_louis_orig.shape)
bv_louis =  data_louis_orig.copy()
bv_louis["L_bv_code_init"] =  bv_louis["code"]
bv_louis = bv_louis[bv_louis["libelle"]!="Belfort"] 
bv_louis = bv_louis[bv_louis["libelle"]!="Pont-Saint-Esprit"] #
bv_louis = bv_louis[bv_louis["libelle"]!="Gradignan"]
bv_louis.loc[70041-2:70040,:]
print(bv_louis.shape)
# Out:
# (70042, 22)
# (69985, 23)

# %%
bv_louis["longitude"].isnull().sum(), bv_louis["latitude"].isnull().sum()
# Out:
# (9045, 9045)

# %%
nom_longitude = 0
for k in range(bv_louis.shape[0]):
    try :
        float(bv_louis.iloc[k,13])
        
    except:
        nom_longitude = nom_longitude + 1
        #print(bv_louis.iloc[k,13])
        
nom_latitude = 0
for k in range(bv_louis.shape[0]):
    try :
        float(bv_louis.iloc[k,14])

    except:
        nom_latitude = nom_latitude + 1
        print(bv_louis.iloc[k,:])
print(nom_longitude,nom_latitude)
# Out:
# 0 0

# %%
bv_louis[bv_louis["longitude"]=="06-08"]
# Out:
# Empty DataFrame
# Columns: [commune_code, libelle, code, libelle.1, num_voie, voie, complement1, complement2, lieu_dit, code_postal, commune, canton_code, circonscription_code, longitude, latitude, geo_score, geo_type, geo_adresse, geo_id, geo_ligne, geo_l4, geo_l5, L_bv_code_init]
# Index: []

# %%
bv_louis.head(1)
# Out:
#   commune_code libelle code     libelle.1 num_voie        voie complement1  \
# 0        59350   Lille  807  ECOLE AMPERE       64  RUE D'IENA         NaN
#
#   complement2 lieu_dit code_postal commune canton_code circonscription_code  \
# 0         NaN      NaN       59000   LILLE       59-27                59-11
#
#    longitude   latitude  geo_score geo_type             geo_adresse  \
# 0   3.043027  50.621124       0.96   street  Rue d'Iena 59000 Lille
#
#        geo_id geo_ligne      geo_l4 geo_l5 L_bv_code_init
# 0  59350_4658         G  RUE D IENA    NaN            807

# %%
#######################   CORRECTION DE CODE BV DANS LES DEUX BV   #######################

# %%
################ CORRECTION DU BV DE LOUIS

# %%
for i in range(bv_louis.shape[0]):
   
    if bv_louis.iloc[i,1]=="Montbéliard":        
        continue
    if bv_louis.iloc[i,1]=="Toulouse":
        #try:
        #    bv_louis.iloc[i,2]=str(int(bv_louis.iloc[i,2]))
        #if bv_louis.iloc[i,2].find("0")!=-1:
        #    bv_louis.iloc[i,2] = bv_louis.iloc[i,2].replace("0","")
        #else:
        #except:
        #    if  bv_louis.iloc[i,2][0] =="0":
        #        bv_louis.iloc[i,2] = bv_louis.iloc[i,2][1:]      
        continue
            
    try :
        bv_louis.iloc[i,2]=str(int(bv_louis.iloc[i,2]))
        
    except:
        if (bv_louis.iloc[i,2]=="Unique")|(bv_louis.iloc[i,2]=="unique")|(bv_louis.iloc[i,2]=="UNIQUE")|(bv_louis.iloc[i,2]=="BUR")|(bv_louis.iloc[i,2]=="M1-3")|(bv_louis.iloc[i,2]=="1LC")|(bv_louis.iloc[i,2]=="01 - 1"): 
            bv_louis.iloc[i,2]="1"
        if (bv_louis.iloc[i,2]=="BV01")|(bv_louis.iloc[i,2]=="Bureau 1")|(bv_louis.iloc[i,2]=="M1 - 3")|(bv_louis.iloc[i,2]=="M1")|(bv_louis.iloc[i,2]=="UN")|(bv_louis.iloc[i,2]=="U")|(bv_louis.iloc[i,2]=="VO"):
            bv_louis.iloc[i,2]="1"
        if (bv_louis.iloc[i,2]=="BV02")|(bv_louis.iloc[i,2]=="Bureau 2"):
            bv_louis.iloc[i,2]="2"
        if (bv_louis.iloc[i,2][0]=="A")|(bv_louis.iloc[i,2][0]=="B")|(bv_louis.iloc[i,2][0]=="C")|(bv_louis.iloc[i,2][0]=="D")|(bv_louis.iloc[i,2][0]=="E")|(bv_louis.iloc[i,2][0]=="F") :
            bv_louis.iloc[i,2] = bv_louis.iloc[i,2][1:]
        if (bv_louis.iloc[i,2][-1]=="A")|(bv_louis.iloc[i,2][-1]=="B")|(bv_louis.iloc[i,2][-1]=="C")|(bv_louis.iloc[i,2][-1]=="D")|(bv_louis.iloc[i,2][-1]=="E")|(bv_louis.iloc[i,2][-1]=="F") : 
            bv_louis.iloc[i,2] = bv_louis.iloc[i,2][:-1]
        if bv_louis.iloc[i,2][0]=="0":
            bv_louis.iloc[i,2] = bv_louis.iloc[i,2][1:]
        if bv_louis.iloc[i,2][0]=="0":
            bv_louis.iloc[i,2] = bv_louis.iloc[i,2][1:]            
        #print("zedezd 1", bv_louis.iloc[i,2])    
        if bv_louis.iloc[i,2].find("-")!=-1:
            #print("vdkjhzdb")
            if bv_louis.iloc[i,2][0]=="-":
                print(bv_louis.iloc[i,2])
            if bv_louis.iloc[i,2][1]=="-":
                bv_louis.iloc[i,2] = bv_louis.iloc[i,2][0]
            #print("yyy",bv_louis.iloc[i,2])
            
        if bv_louis.iloc[i,2].find(" ")!=-1:
            if bv_louis.iloc[i,2][1]==" ":
                bv_louis.iloc[i,2] = bv_louis.iloc[i,2][0]      
                                
        try :
            if bv_louis.iloc[i,2][2]=="-":
                bv_louis.iloc[i,2] = bv_louis.iloc[i,2].replace("-","")
        except:
             continue
                
print("phase 1 fini")
# Out:
# phase 1 fini

# %%
# vérification 
for k in bv_louis[(bv_louis.loc[:,"libelle"]!="Montbéliard")&(bv_louis.loc[:,"libelle"]!="Toulouse")]["code"].value_counts().index:
    try:
        int(k)
    except:
        print(k,'-'*5, (bv_louis["code"]==k).sum() )
# Out:
# 9.2 ----- 1
# 24.1 ----- 1
# 18.1 ----- 1
# 4.1 ----- 1
# 4.2 ----- 1
# 2.2 ----- 1
# 6.1 ----- 1
# 23.2 ----- 1
# 6.2 ----- 1
# 19.2 ----- 1
# 18.2 ----- 1
# 10.1 ----- 1
# 23.1 ----- 1
# 4.3 ----- 1
# 18.3 ----- 1
# 17.2 ----- 1
# 5.2 ----- 1
# 15.1 ----- 1
# 16.2 ----- 1
# 22.2 ----- 1
# 13.3 ----- 1
# 8.1 ----- 1
# 2.1 ----- 1
# 4.4 ----- 1
# 9.1 ----- 1
# 17.3 ----- 1
# 16.4 ----- 1
# 9.3 ----- 1
# 11.1 ----- 1
# 10.3 ----- 1
# 12.1 ----- 1
# 14.2 ----- 1
# 20.1 ----- 1
# 13.2 ----- 1
# 17.1 ----- 1
# 23.3 ----- 1
# 7.1 ----- 1
# 3.2 ----- 1
# 19.3 ----- 1
# 15.2 ----- 1
# 14.1 ----- 1
# 7.3 ----- 1
# 10.2 ----- 1
# 7.2 ----- 1
# 11.3 ----- 1
# 11.2 ----- 1
# 13.1 ----- 1
# 21.2 ----- 1
# 16.3 ----- 1
# 21.1 ----- 1
# 1.1 ----- 1
# 22.1 ----- 1
# 16.1 ----- 1
# 19.1 ----- 1
# 3.1 ----- 1
# 5.1 ----- 1
# 13 - 2 ----- 1

# %%
# AJOUT DES VILLES
dt_temp = data_louis_orig[data_louis_orig["libelle"]=="Belfort"] 
dt_temp = pd.concat([dt_temp, data_louis_orig[data_louis_orig["libelle"]=="Pont-Saint-Esprit"]], axis=0) 
dt_temp = pd.concat([dt_temp, data_louis_orig[data_louis_orig["libelle"]=="Gradignan"]], axis=0) 

bv_louis = pd.concat([bv_louis,dt_temp], axis=0)
bv_louis.shape
# Out:
# (70042, 23)

# %%
################ CORRECTION DU BV DE PIERRE

# %%
# EUROPEEEN (AVEC LES ENTETES COMPLETS)
bv_euro_orig = pd.read_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER/resultats-definitifs-par-bureau-de-vote_entete_complet.csv",sep=";",header=0, names=nom_colonnes, dtype=str,encoding="iso-8859-1")
bv_euro = bv_euro_orig.copy()
bv_euro = bv_euro.iloc[:,:9]
bv_euro["E_bv_code_init"] = bv_euro["Code du b.vote"]
print(bv_euro.shape)
bv_euro.iloc[:2,:]
# Out:
# (69297, 10)
#   Code du département Libellé du département Code de la commune  \
# 0                  01                    Ain                001
# 1                  01                    Ain                002
#
#      Libellé de la commune Code du b.vote Inscrits Abstentions % Abs/Ins  \
# 0  L'Abergement-Clémenciat           0001      601         268     44.59
# 1    L'Abergement-de-Varey           0001      210          69     32.86
#
#   Votants E_bv_code_init
# 0     333           0001
# 1     141           0001

# %%
# CORRIGER LYON
for i in range(bv_euro.shape[0]):
    if bv_euro.iloc[i,3]=="Lyon":
        bv_euro.iloc[i,2]=str(69380+int(bv_euro.iloc[i,4][:2]))[2:]
    if bv_euro.iloc[i,3]=="Marseille":
        bv_euro.iloc[i,2]=str(13200+int(bv_euro.iloc[i,4][:2]))[2:]
    if bv_euro.iloc[i,3]=="Toulouse":
        try:
            bv_euro.iloc[i,4] = str(int(bv_euro.iloc[i,4]))
        except:
            if bv_euro.iloc[i,4][0]=="0":
                bv_euro.iloc[i,4] = bv_euro.iloc[i,4][1:]

# %%
# bv à l'étranger
bv_euro[bv_euro["Libellé du département"]=="Français établis hors de France"]["Code du département"].value_counts()
# Out:
# ZZ    209
# Name: Code du département, dtype: int64

# %%
#IL FAUT EFFACER CETTE LIGNE CAR LES INFORMATIONS NE SONT PAS REPRESENTANT DANS LA BASE DE PARIS
# fichier qui va être importer après
pd.DataFrame(bv_euro.loc[51452,:]).T
# Out:
#       Code du département Libellé du département Code de la commune  \
# 51452                  75                  Paris                056
#
#       Libellé de la commune Code du b.vote Inscrits Abstentions % Abs/Ins  \
# 51452                 Paris           JUS1     5184         789     15.22
#
#       Votants E_bv_code_init
# 51452    4395           JUS1

# %%
bv_euro = bv_euro.drop(51452,0)

# %%
bv_euro
# Out:
#       Code du département           Libellé du département Code de la commune  \
# 0                      01                              Ain                001
# 1                      01                              Ain                002
# 2                      01                              Ain                004
# 3                      01                              Ain                004
# 4                      01                              Ain                004
# ...                   ...                              ...                ...
# 69292                  ZZ  Français établis hors de France                227
# 69293                  ZZ  Français établis hors de France                228
# 69294                  ZZ  Français établis hors de France                229
# 69295                  ZZ  Français établis hors de France                231
# 69296                  ZZ  Français établis hors de France                233
#
# ...

# %%
#EFFACER LES BV A L'ETRANGER
liste_a_effacer=["ZD","ZA","ZB","ZN","ZP","ZZ","ZM","ZC","ZX","ZS","ZW"]
for i in liste_a_effacer:
    bv_euro = bv_euro[bv_euro["Code du département"]!=i]
bv_euro.shape
# Out:
# (66577, 10)

# %%
69296 - 66577
# Out:
# 2719

# %%
###############       CORRECTION CODE DE LA COMMUNE DE PARIS             #####################

# %%
test_code = pd.read_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER/paris_arrond_codebv/test_code.csv",sep=",",dtype=str)
print(test_code.shape)
test_code.head(2)
# Out:
# (896, 50)
#   id_bvote       scrutin annee tour        date num_circ num_quartie  \
# 0      1-5  EuropÃ©ennes  2019    1  2019/05/26        1           2
# 1     3-11  EuropÃ©ennes  2019    1  2019/05/26        1          12
#
#   num_arrond num_bureau nb_procu nb_inscr nb_emarg nb_votant nb_bl nb_nul  \
# 0          1          5       29     1059      626       626     1      1
# 1          3         11       57     1535      937       937     6      5
#
#   nb_exprim aubry_manon de_prevoisi camus_renau marie_flori loiseau_nat  \
# 0       624          16           0           0           4         257
# 1       926          38           0           0           4         382
#
#   traore_hama philippot_f alexandre_a bourg_domin vauclin_vin lagarde_jea  \
# 0           0           1           0          24           0           4
# 1           0           1           1          18           0          11
#
# ...

# %%
t_3=0;t_4=0;t_5=0;t_autre=0

for i in test_code["id_bvote"]:
    if len(i)==3:
        t_3=t_3+1
    elif len(i)==4:
        t_4=t_4+1  
    elif len(i)==5:
        t_5=t_5+1         
    else:
        t_autre=t_autre+1
print(t_3,t_4,t_5,t_autre)
# Out:
# 81 184 631 0

# %%
for i in range(test_code.shape[0]):
    if len(test_code.iloc[i,0])==3:
        test_code.iloc[i,0] ="0"+test_code.iloc[i,0][0:2]+"0"+test_code.iloc[i,0][2]
    if len(test_code.iloc[i,0])==4:
        if test_code.iloc[i,0][1]=="-":
            test_code.iloc[i,0] = "0"+test_code.iloc[i,0]
        else:
            test_code.iloc[i,0] = test_code.iloc[i,0][:3]+"0"+test_code.iloc[i,0][3]

t_3=0;t_4=0;t_5=0;t_autre=0
for i in test_code["id_bvote"]:
    if len(i)==3:
        t_3=t_3+1
    elif len(i)==4:
        t_4=t_4+1  
    elif len(i)==5:
        t_5=t_5+1         
    else:
        t_autre=t_autre+1
print(t_3,t_4,t_5,t_autre)
# Out:
# 0 0 896 0

# %%
for i in range(test_code.shape[0]):
    test_code.iloc[i,0]=test_code.iloc[i,0].replace("-","")
test_code
# Out:
#     id_bvote       scrutin annee tour        date num_circ num_quartie  \
# 0       0105  EuropÃ©ennes  2019    1  2019/05/26        1           2
# 1       0311  EuropÃ©ennes  2019    1  2019/05/26        1          12
# 2       0312  EuropÃ©ennes  2019    1  2019/05/26        1           9
# 3       0407  EuropÃ©ennes  2019    1  2019/05/26        7          15
# 4       0414  EuropÃ©ennes  2019    1  2019/05/26        7          14
# ..       ...           ...   ...  ...         ...      ...         ...
# 891     0921  EuropÃ©ennes  2019    1  2019/05/26       18          36
# 892     1014  EuropÃ©ennes  2019    1  2019/05/26        5          40
# 893     1022  EuropÃ©ennes  2019    1  2019/05/26        5          40
# 894     1027  EuropÃ©ennes  2019    1  2019/05/26        5          37
# 895     1133  EuropÃ©ennes  2019    1  2019/05/26        7          44
#
#     num_arrond num_bureau nb_procu nb_inscr nb_emarg nb_votant nb_bl nb_nul  \
# ...

# %%
test_code["id_bvote"].value_counts().shape
# Out:
# (896,)

# %%
(test_code["num_arrond"]=="15").sum()
# Out:
# 95

# %%
pate = 0
for ii in range(bv_euro.shape[0]):
    if bv_euro.iloc[ii,0]=="75":
        for jj in range(test_code.shape[0]):
            if ((bv_euro.iloc[ii,4])==test_code.iloc[jj,0]):
                bv_euro.iloc[ii,2]=str(75100+int(test_code.iloc[jj,7]))[2:]
                pate=pate+1
print(pate)
# Out:
# 896

# %%
bv_euro[bv_euro["Code du département"]=="75"]["Code de la commune"].value_counts()
# Out:
# 115    95
# 120    76
# 113    71
# 119    70
# 116    68
# 118    68
# 117    67
# 112    64
# 114    57
# 111    55
# 110    39
# 109    27
# 107    25
# 105    25
# 106    22
# 108    18
# 103    15
# 104    14
# 102    10
# 101    10
# Name: Code de la commune, dtype: int64

# %%
# ON PREND LES  DEUX CARACTERES DE CODE BV
for ii in range(bv_euro.shape[0]):
    if bv_euro.iloc[ii,0]=="75":
        bv_euro.iloc[ii,4]=str(int(bv_euro.iloc[ii,4][-2:]))

# %%
###############    FIN   CORRECTION CODE DE LA COMMUNE DE PARIS         #####################

# %%
###############       CORRECTION DE LA COLONNE Code du b.vote  #####################

# %%
for i in range(bv_euro.shape[0]):
    if bv_euro.iloc[i,3]=="Montbéliard":        
        continue
    if bv_euro.iloc[i,3]=="Toulouse":
        continue
    if bv_euro.iloc[i,3]=="Hérimoncourt": 
        bv_euro.iloc[i,4] =  bv_euro.iloc[i,4][2:]
        continue
      
    try :
        bv_euro.iloc[i,4]=str(int(bv_euro.iloc[i,4]))
        
    except:

        if (bv_euro.iloc[i,4]=="BV01")|(bv_euro.iloc[i,4]=="JUS1"):
            bv_euro.iloc[i,4]="1"
        if (bv_euro.iloc[i,4]=="BV02"):
            bv_euro.iloc[i,4]="2"
        if bv_euro.iloc[i,4][0]=="0":
            bv_euro.iloc[i,4] = bv_euro.iloc[i,4][1:]
            
print("phase 1 fini")
# Out:
# phase 1 fini

# %%
#vérification
for k in bv_euro[(bv_euro.loc[:,"Libellé de la commune"]!="Montbéliard")&(bv_euro.loc[:,"Libellé de la commune"]!="Toulouse")]["Code du b.vote"].value_counts().index:
    try:
        int(k)
    except:
        print(k, "-"*5,(bv_euro["Code du b.vote"]==k).sum()  )
# Out:
# 18.1 ----- 1
# 9.2 ----- 1
# 24.1 ----- 1
# 4.1 ----- 1
# 4.2 ----- 1
# 2.2 ----- 1
# 23.1 ----- 1
# 6.1 ----- 1
# 23.2 ----- 1
# 19.2 ----- 1
# 6.2 ----- 1
# 18.2 ----- 1
# 10.1 ----- 1
# 15.1 ----- 1
# 4.3 ----- 1
# 18.3 ----- 1
# 17.2 ----- 1
# 5.2 ----- 1
# 22.2 ----- 1
# 13.3 ----- 1
# 4.4 ----- 1
# 9.1 ----- 1
# 11.2 ----- 1
# 13.1 ----- 1
# 21.2 ----- 1
# 17.3 ----- 1
# 8.1 ----- 1
# 2.1 ----- 1
# 16.4 ----- 1
# 9.3 ----- 1
# 11.1 ----- 1
# 10.3 ----- 1
# 12.1 ----- 1
# 13.2 ----- 1
# 16.2 ----- 1
# 20.1 ----- 1
# 14.2 ----- 1
# 17.1 ----- 1
# 23.3 ----- 1
# 14.1 ----- 1
# 15.2 ----- 1
# 3.2 ----- 1
# 19.3 ----- 1
# 7.3 ----- 1
# 19.1 ----- 1
# 7.1 ----- 1
# 16.1 ----- 1
# 7.2 ----- 1
# 10.2 ----- 1
# 16.3 ----- 1
# 21.1 ----- 1
# 11.3 ----- 1
# 1.1 ----- 1
# 22.1 ----- 1
# 3.1 ----- 1
# 5.1 ----- 1

# %%
#########################################################################################
#                                      DOUBLONS 
#########################################################################################
"""
- Certains BV ont les mêmes coordonnées et des codes BV différents(deux salles dans un même bâtiment)


"""
# Out:
# '\n- Certains BV ont les mêmes coordonnées et des codes BV différents(deux salles dans un même bâtiment)\n\n\n'

# %%
bv_sans_doublons= bv_louis.drop_duplicates(subset=["code","longitude","latitude"])
print(bv_sans_doublons.shape)
bv_sans_nan_doublons = bv_sans_doublons[bv_sans_doublons["longitude"].isnull()==False]
print(bv_sans_nan_doublons.shape)
# Out:
# (61250, 23)
# (60879, 23)

# %%
bv_sans_nan_doublons
# Out:
#       commune_code      libelle code  \
# 0            59350        Lille  807
# 2            97401  Les Avirons    1
# 5            50502     Saint-Lô    8
# 7            97411  Saint-Denis  118
# 10           56121      Lorient   11
# ...            ...          ...  ...
# 52355        33192    Gradignan  03E
# 52450        33192    Gradignan  01C
# 52507        33192    Gradignan  05A
# 52511        33192    Gradignan  01E
# 54044        33192    Gradignan  05B
#
#                                       libelle.1 num_voie  \
# 0                                  ECOLE AMPERE       64
# 2                            MAIRIE DES AVIRONS       61
# 5                      HARAS-Ecurie n°5 (BV 08)      NaN
# 7      ECOLE PRIM. JEAN BAPTISTE  BOSSARD (118)      NaN
# 10                     GROUPE SCOLAIRE MERVILLE        1
# ...                                         ...      ...
# 52355                     SAINT GERY - Bureau E      NaN
# ...

# %%
# BV FRANCE METROPOLITAINE UNIQUEMENT
data_sans_nan_doublons_sup_97501 = bv_sans_nan_doublons.copy()
temp_sup_97501 = 0
temp_lettre = 0
for k in bv_sans_nan_doublons["commune_code"].value_counts().index:
    try:
        temp_k = int(k)
        if (temp_k >= 97000):
            temp_sup_97501 = temp_sup_97501 + 1
            print(temp_k)
            data_sans_nan_doublons_sup_97501 = data_sans_nan_doublons_sup_97501[data_sans_nan_doublons_sup_97501["commune_code"]!=k]
            
    except:
        temp_lettre = temp_lettre +1
        #print(k)
# Out:
# 97411
# 97415
# 97416
# 97422
# 97209
# 97414
# 97412
# 97101
# 97409
# 97410
# 97418
# 97413
# 97407
# 97408
# 97420
# 97611
# 97213
# 97128
# 97117
# 97103
# 97107
# 97118
# 97113
# 97120
# 97302
# 97116
# 97222
# 97228
# 97404
# 97115
# 97125
# 97405
# 97307
# 97210
# 97224
# 97401
# 97304
# 97309
# 97604
# 97230
# 97132
# 97105
# 97207
# 97220
# 97229
# 97227
# 97603
# 97614
# 97311
# 97221
# 97610
# 97212
# 97602
# 97124
# 97608
# 97605
# 97612
# 97617
# 97223
# 97421
# 97119
# 97601
# 97102
# 97616
# 97423
# 97607
# 97114
# 97121
# 97424
# 97305
# 97104
# 97217
# 97417
# 97403
# 97106
# 97214
# 97111
# 97615
# 97226
# 97609
# 97112
# 97406
# 97122
# 97225
# 97606
# 97109
# 97216
# 97204
# 97206
# 97218
# 97205
# 97134
# 97613
# 97126
# 97202
# 97203
# 97306
# 97234
# 97360
# 97310
# 97110
# 97133
# 97108
# 97219
# 97131
# 97130
# 97232
# 97308
# 97301
# 97201
# 97129
# 97231
# 97313
# 97356
# 97312
# 97419
# 97362
# 97402
# 97357
# 97208
# 97211
# 97314
# 97215
# 97233
# 97352
# ...

# %%
data_sans_nan_doublons_sup_97501
# Out:
#       commune_code                 libelle code                  libelle.1  \
# 0            59350                   Lille  807               ECOLE AMPERE
# 5            50502                Saint-Lô    8   HARAS-Ecurie n°5 (BV 08)
# 10           56121                 Lorient   11   GROUPE SCOLAIRE MERVILLE
# 11           76558  Saint-Aubin-Celloville    1                   Bureau 1
# 12           70407                Perrouse    1              BUREAU UNIQUE
# ...            ...                     ...  ...                        ...
# 52355        33192               Gradignan  03E      SAINT GERY - Bureau E
# 52450        33192               Gradignan  01C  PIERRE TOUPIAC - BUREAU C
# 52507        33192               Gradignan  05A        MANDAVIT - Bureau A
# 52511        33192               Gradignan  01E  PIERRE TOUPIAC - BUREAU E
# 54044        33192               Gradignan  05B        MANDAVIT - Bureau B
#
# ...

# %%
# vérification
data_sans_nan_doublons_sup_97501["geo_score"].isnull().sum()
# Out:
# 0

# %%
# CORRECTION D'UNE LIGNE
data_sans_nan_doublons_sup_97501[data_sans_nan_doublons_sup_97501["libelle.1"]=="ANCIENNE CURE"]
# Out:
#       commune_code             libelle code      libelle.1 num_voie  \
# 45674        85151  Mortagne-sur-Sèvre    4  ANCIENNE CURE      NaN
# 65725        42154             Néronde    1  ANCIENNE CURE    42510
#
#                    voie complement1 complement2 lieu_dit code_postal  \
# 45674   1 rue du Centre     Evrunes         NaN      NaN       85290
# 65725           NERONDE         NaN         NaN      NaN       42510
#
#                   commune canton_code circonscription_code  longitude  \
# 45674  MORTAGNE SUR SEVRE       85-11                85-04  -0.971915
# 65725             NÉRONDE       42-04                42-06   2.127469
#
#         latitude  geo_score      geo_type  \
# 45674  47.000255       0.95   housenumber
# 65725  22.927179       0.93  municipality
#
#                                     geo_adresse            geo_id geo_ligne  \
# 45674  1 Rue du Centre 85290 Mortagne-sur-Sèvre  85151_0150_00001         G
# ...

# %%
data_sans_nan_doublons_sup_97501.loc[65725,"longitude"] = 4.236545
data_sans_nan_doublons_sup_97501.loc[65725,"latitude"] = 45.838744

# %%
#vérification
data_sans_nan_doublons_sup_97501[data_sans_nan_doublons_sup_97501["libelle.1"]=="ANCIENNE CURE"]
# Out:
#       commune_code             libelle code      libelle.1 num_voie  \
# 45674        85151  Mortagne-sur-Sèvre    4  ANCIENNE CURE      NaN
# 65725        42154             Néronde    1  ANCIENNE CURE    42510
#
#                    voie complement1 complement2 lieu_dit code_postal  \
# 45674   1 rue du Centre     Evrunes         NaN      NaN       85290
# 65725           NERONDE         NaN         NaN      NaN       42510
#
#                   commune canton_code circonscription_code  longitude  \
# 45674  MORTAGNE SUR SEVRE       85-11                85-04  -0.971915
# 65725             NÉRONDE       42-04                42-06   4.236545
#
#         latitude  geo_score      geo_type  \
# 45674  47.000255       0.95   housenumber
# 65725  45.838744       0.93  municipality
#
#                                     geo_adresse            geo_id geo_ligne  \
# 45674  1 Rue du Centre 85290 Mortagne-sur-Sèvre  85151_0150_00001         G
# ...

# %%
###################    AJOUT D'UNE COLONNE       ########################
###### TRAITEMENT POUR OBTENIR UN IDENTIFIANT UNIQUE 
# CREATION DE CHR_CODE POUR FAIRE LA JOINTURE AVEC LE FICHIER BV (EUROPEENS)

# %%
data_sans_nan_doublons_sup_97501["CHR_CODE"]=data_sans_nan_doublons_sup_97501["commune_code"]+data_sans_nan_doublons_sup_97501["code"]

# %%
data_sans_nan_doublons_sup_97501["CHR_CODE"].value_counts().shape,data_sans_nan_doublons_sup_97501.shape
# Out:
# ((58993,), (59021, 24))

# %%
data_sans_nan_doublons_sup_97501.drop_duplicates(subset=["code", "longitude", "latitude"]).shape
# Out:
# (59021, 24)

# %%
data_sans_nan_doublons_sup_97501.drop_duplicates(subset=["commune_code", "code"]).shape
# Out:
# (58993, 24)

# %%
data_sans_nan_doublons_sup_97501.drop_duplicates().shape
# Out:
# (59021, 24)

# %%
data_sans_nan_doublons_sup_97501["CHR_CODE"].value_counts()[data_sans_nan_doublons_sup_97501["CHR_CODE"].value_counts()>1]
# Out:
# 210141     2
# 230371     2
# 422242     2
# 472581     2
# 1300213    2
# 331371     2
# 335111     2
# 111221     2
# 330701     2
# 112071     2
# 223201     2
# 770582     2
# 513391     2
# 852481     2
# 605571     2
# 516241     2
# 774511     2
# 570641     2
# 283351     2
# 1300217    2
# 770583     2
# 191741     2
# 523581     2
# 594142     2
# 572521     2
# 594143     2
# 273251     2
# 770584     2
# Name: CHR_CODE, dtype: int64

# %%
# POUR MIEUX VISUALISER LES CAS : 
#data_sans_nan_doublons_sup_97501[data_sans_nan_doublons_sup_97501["CHR_CODE"]=="770582"]
#bv_euro[bv_euro["CHR_CODE"]=="770582"]
#data_louis_orig[data_louis_orig["libelle"]=="Bussy-Saint-Georges"]

# %%
# ON VA RENDRE CHR_CODE UNIQUE (POUR FAIRE LA JOINTURE APRES)
data_sans_nan_doublons_sup_97501 = data_sans_nan_doublons_sup_97501.drop_duplicates(subset=["commune_code", "code"])
data_sans_nan_doublons_sup_97501 = data_sans_nan_doublons_sup_97501.drop(["CHR_CODE"], axis=1)
data_sans_nan_doublons_sup_97501["CHR_CODE"]=data_sans_nan_doublons_sup_97501["commune_code"]+data_sans_nan_doublons_sup_97501["code"]
data_sans_nan_doublons_sup_97501["CHR_CODE"].value_counts().shape, data_sans_nan_doublons_sup_97501.shape
# Out:
# ((58993,), (58993, 24))

# %%
# BROUILLON
#resultats_electoraux = pd.read_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Jointure_geo_v2/DATA_IRIS_BV/RESULTATS_ELECTORAUX/EUR2019_BV_6_PARTIS.csv", sep=";", dtype=str, encoding="iso-8859-1")

# %%
#########################################################################################
#                                      DOUBLONS 
#########################################################################################

# %%
# dimensions
bv_euro.shape, data_sans_nan_doublons_sup_97501.shape, data_louis_orig.shape
# Out:
# ((66577, 10), (58993, 24), (70042, 22))

# %%
bv_euro.drop_duplicates().shape # pas de doublons
# Out:
# (66577, 10)

# %%
# différence de BV
(69297-60689)/69297*100
# Out:
# 12.4218941656926

# %%
###################    AJOUT DE DEUX COLONNES        ########################
bv_euro["commune_code"]=bv_euro["Code du département"]+bv_euro["Code de la commune"] 
bv_euro["CHR_CODE"]= bv_euro["commune_code"]+bv_euro["Code du b.vote"]

# %%
# IDENTIFIANT UNIQUE (PAS DE DOUBLONS)
bv_euro["CHR_CODE"].value_counts().shape, bv_euro.shape
# Out:
# ((66577,), (66577, 12))

# %%
bv_euro
# Out:
#       Code du département Libellé du département Code de la commune  \
# 0                      01                    Ain                001
# 1                      01                    Ain                002
# 2                      01                    Ain                004
# 3                      01                    Ain                004
# 4                      01                    Ain                004
# ...                   ...                    ...                ...
# 66573                  95             Val-d'Oise                680
# 66574                  95             Val-d'Oise                680
# 66575                  95             Val-d'Oise                680
# 66576                  95             Val-d'Oise                682
# 66577                  95             Val-d'Oise                690
#
#          Libellé de la commune Code du b.vote Inscrits Abstentions % Abs/Ins  \
# ...

# %%
################################################################
# TESTE JOINTURE
################################################################

# %%
jointure_deux_bases_bv = pd.merge(data_sans_nan_doublons_sup_97501,bv_euro)
jointure_deux_bases_bv.head(3)
# Out:
#   commune_code   libelle code                 libelle.1 num_voie  \
# 0        59350     Lille  807              ECOLE AMPERE       64
# 1        50502  Saint-Lô    8  HARAS-Ecurie n°5 (BV 08)      NaN
# 2        56121   Lorient   11  GROUPE SCOLAIRE MERVILLE        1
#
#                    voie       complement1 complement2 lieu_dit code_postal  \
# 0            RUE D'IENA               NaN         NaN      NaN       59000
# 1  Rue de la Goubedière  HARAS-Ecurie n°5         NaN      NaN       50000
# 2    AVENUE DE LA MARNE               NaN         NaN      NaN       56100
#
#     commune canton_code circonscription_code  longitude   latitude  geo_score  \
# 0     LILLE       59-27                59-11   3.043027  50.621124       0.96
# 1  SAINT LO       50-23                50-01  -1.074428  49.117378       0.95
# 2   LORIENT       56-09                56-05  -3.368220  47.744513       0.96
#
#       geo_type                          geo_adresse            geo_id  \
# ...

# %%
# les dimensions de trois bases de données
print(data_sans_nan_doublons_sup_97501.shape)
print(bv_euro.shape)
print(jointure_deux_bases_bv.shape)
# Out:
# (58993, 24)
# (66577, 12)
# (57940, 34)

# %%
# identifiant unique dans les trois BD 
# (on peut ajouter une colonne en plus pour la jointure après et ça ne changera rien)
print(data_sans_nan_doublons_sup_97501["CHR_CODE"].value_counts().shape)
print(bv_euro["CHR_CODE"].value_counts().shape)
print(jointure_deux_bases_bv["CHR_CODE"].value_counts().shape)
# Out:
# (58993,)
# (66577,)
# (57940,)

# %%
# par rapport à l'avant derrière version (les BV de Paris dont présents)
56911 - 56015
# Out:
# 896

# %%
jointure_deux_bases_bv[jointure_deux_bases_bv["commune_code"]=="75115"].shape
# Out:
# (95, 34)

# %%
bv_euro[bv_euro["commune_code"]=="75115"].shape
# Out:
# (95, 12)

# %%
print(bv_euro["Code du département"].value_counts().shape)
pd.DataFrame(bv_euro["Code du département"].value_counts()).T
# Out:
# (96,)
#                        59    62    33    13    76    31    69    57    77  \
# Code du département  1991  1637  1373  1366  1337  1312  1291  1278  1094
#
#                        44    38    92   78   67   80   02   06   60   54   14  \
# Code du département  1091  1055  1015  990  983  983  979  975  934  932  926
#
#                       83   34   21   75   91   64   35   51   29   27   94  \
# Code du département  913  913  906  896  883  876  874  839  828  816  815
#
#                       93   95   17   25   71   50   63   30   24   68   49  \
# Code du département  811  802  775  765  758  744  739  713  690  684  675
#
#                       42   56   45   88   22   74   70   72   85   26   01  \
# Code du département  672  671  662  658  654  621  615  608  603  593  584
#
#                       89   55   11   39   52   65   61   28   08   37   10  \
# Code du département  584  584  579  578  567  566  563  562  560  558  532
#
# ...

# %%
print(jointure_deux_bases_bv["Code du département"].value_counts().shape)
pd.DataFrame(jointure_deux_bases_bv["Code du département"].value_counts()).T
# Out:
# (96,)
#                        59    62    13    69    31    57    33    44    76  \
# Code du département  1857  1465  1290  1207  1202  1199  1185  1053  1019
#
#                       92   80   06   77   38   78   67   75   60   02   34  \
# Code du département  998  966  943  933  926  926  897  896  866  848  848
#
#                       83   91   35   54   21   94   95   14   93   29   27  \
# Code du département  848  833  817  809  805  799  787  778  773  769  724
#
#                       63   25   50   49   17   51   68   42   22   56   45  \
# Code du département  677  676  669  657  649  646  641  636  615  614  612
#
#                       64   74   88   85   72   30   01   71   24   89   26  \
# Code du département  596  593  590  577  563  549  539  513  512  504  501
#
#                       37   70   39   16   61   79   11   03   55   52   81  \
# Code du département  494  492  490  484  471  454  450  441  428  422  421
#
# ...

# %%
tama1 = bv_euro["Code du département"].value_counts().index
tama2 = jointure_deux_bases_bv["Code du département"].value_counts().index

for i in tama1:
    k = 0
    for j in tama2:
        if i==j:    
            break
        else:
             k=k+1
    if k==len(tama2):
        print(i)
print("NORMALEMENT RIEN NE DOIT S'AFFICHER")
# Out:
# NORMALEMENT RIEN NE DOIT S'AFFICHER

# %%
################################ table_non_recon ###############################

# %%
bv_euro.merge(jointure_deux_bases_bv,on="CHR_CODE", how="left").head(1)
# Out:
#   Code du département_x Libellé du département_x Code de la commune_x  \
# 0                    01                      Ain                  001
#
#    Libellé de la commune_x Code du b.vote_x Inscrits_x Abstentions_x  \
# 0  L'Abergement-Clémenciat                1        601           268
#
#   % Abs/Ins_x Votants_x E_bv_code_init_x commune_code_x CHR_CODE  \
# 0       44.59       333             0001          01001   010011
#
#   commune_code_y                  libelle code libelle.1 num_voie    voie  \
# 0          01001  L'Abergement-Clémenciat    1  Bureau 1      NaN  MAIRIE
#
#   complement1 complement2 lieu_dit code_postal                commune  \
# 0         NaN         NaN      NaN       01400  ABERGEMENT CLEMENCIAT
#
#   canton_code circonscription_code  longitude   latitude  geo_score  \
# 0       01-08                01-04   4.920902  46.150784       0.91
#
#        geo_type                               geo_adresse  \
# ...

# %%
bv_euro.shape, jointure_deux_bases_bv.shape
# Out:
# ((66577, 12), (57940, 34))

# %%
table_non_recon = bv_euro.merge(jointure_deux_bases_bv,on="CHR_CODE", how="left")[bv_euro.merge(jointure_deux_bases_bv,on="CHR_CODE", how="left")["commune_code_y"].isnull()][["commune_code_x","Libellé de la commune_x","Inscrits_x"] ] 
table_non_recon
# Out:
#       commune_code_x Libellé de la commune_x Inscrits_x
# 23             01015         Arboys en Bugey        116
# 77             01045                 Birieux        200
# 116            01067                 Ceignes        208
# 156            01102                Chevroux        660
# 162            01108                 Coligny        865
# ...              ...                     ...        ...
# 66315          95447        Neuilly-en-Vexin        138
# 66351          95489                  Piscop        503
# 66359          95492       Le Plessis-Gassot         41
# 66388          95509       Puiseux-en-France        339
# 66514          95607                 Taverny        744
#
# [8637 rows x 3 columns]

# %%
table_non_recon["id"] = table_non_recon["commune_code_x"]+table_non_recon["Libellé de la commune_x"]
table_non_recon["Inscrits_x"] = table_non_recon["Inscrits_x"].astype(int)
table_non_recon["id"].value_counts()
# Out:
# 76351Le Havre                    112
# 30189Nîmes                        84
# 84007Avignon                      70
# 17300La Rochelle                  40
# 33281Mérignac                     36
#                                 ...
# 40125Heugas                        1
# 62298Epinoy                        1
# 09096Château-Verdun                1
# 55350Montigny-lès-Vaucouleurs      1
# 64188Chéraute                      1
# Name: id, Length: 6614, dtype: int64

# %%
table_non_recon["commune_code_x"].value_counts()
# Out:
# 76351    112
# 30189     84
# 84007     70
# 17300     40
# 33281     36
#         ...
# 04028      1
# 65402      1
# 17316      1
# 17365      1
# 55060      1
# Name: commune_code_x, Length: 6614, dtype: int64

# %%
table_inscrit = table_non_recon.groupby(['commune_code_x',"Libellé de la commune_x"]).sum().sort_values(by=['Inscrits_x'], ascending=False)
table_inscrit
# Out:
#                                         Inscrits_x
# commune_code_x Libellé de la commune_x
# 76351          Le Havre                     103885
# 30189          Nîmes                         87478
# 84007          Avignon                       55029
# 17300          La Rochelle                   35932
# 33281          Mérignac                      32583
# ...                                            ...
# 65379          Ris                              12
# 52109          Charmes-en-l'Angle               11
# 55394          Ornes                            11
# 26274          Rochefourchat                     8
# 54310          Leménil-Mitry                     5
#
# [6614 rows x 1 columns]

# %%
table_inscrit.iloc[:10,0] #["Inscrits_x"].astype(int).sum()
# Out:
# commune_code_x  Libellé de la commune_x
# 76351           Le Havre                   103885
# 30189           Nîmes                       87478
# 84007           Avignon                     55029
# 17300           La Rochelle                 35932
# 33281           Mérignac                    32583
# 10387           Troyes                      29292
# 30007           Alès                        26484
# 90010           Belfort                     24758
# 76217           Dieppe                      21196
# 71270           Mâcon                       19947
# Name: Inscrits_x, dtype: int32

# %%
table_code_commune_x = pd.DataFrame(table_non_recon['commune_code_x'].value_counts())
#table_code_commune_x
table_code_commune_x.rename(columns={'commune_code_x':"Nb_non_reconcilies"}, inplace=True)
ttt= pd.DataFrame(table_code_commune_x.index,columns=["commune_code_x"], index = range(table_code_commune_x.shape[0]))
#ttt

table_code_commune_x.index =range(table_code_commune_x.shape[0])
#table_code_commune_x
deux_col=pd.concat([ttt,table_code_commune_x], axis=1)
#deux_col
table_inscrit_nb_non_recon = table_inscrit.merge(deux_col, on="commune_code_x")
table_inscrit_nb_non_recon
# Out:
#      commune_code_x  Inscrits_x  Nb_non_reconcilies
# 0             76351      103885                 112
# 1             30189       87478                  84
# 2             84007       55029                  70
# 3             17300       35932                  40
# 4             33281       32583                  36
# ...             ...         ...                 ...
# 6609          65379          12                   1
# 6610          52109          11                   1
# 6611          55394          11                   1
# 6612          26274           8                   1
# 6613          54310           5                   1
#
# [6614 rows x 3 columns]

# %%
talbe_final_non_recon =table_inscrit_nb_non_recon.merge(table_non_recon, on="commune_code_x", how="left").drop_duplicates(subset="commune_code_x").iloc[:,:-2]
talbe_final_non_recon =talbe_final_non_recon[["commune_code_x","Libellé de la commune_x","Inscrits_x_x","Nb_non_reconcilies"]]
talbe_final_non_recon
# Out:
#      commune_code_x Libellé de la commune_x  Inscrits_x_x  Nb_non_reconcilies
# 0             76351                Le Havre        103885                 112
# 112           30189                   Nîmes         87478                  84
# 196           84007                 Avignon         55029                  70
# 266           17300             La Rochelle         35932                  40
# 306           33281                Mérignac         32583                  36
# ...             ...                     ...           ...                 ...
# 8632          65379                     Ris            12                   1
# 8633          52109      Charmes-en-l'Angle            11                   1
# 8634          55394                   Ornes            11                   1
# 8635          26274           Rochefourchat             8                   1
# 8636          54310           Leménil-Mitry             5                   1
#
# [6614 rows x 4 columns]

# %%
talbe_final_non_recon["Inscrits_x_x"].sum()
# Out:
# 4066084

# %%
bv_euro["Inscrits"].astype(int).sum()
# Out:
# 44225431

# %%
jointure_deux_bases_bv["Inscrits"].astype(int).sum()
# Out:
# 40159347

# %%
(44225431-40159347)/44225431
# Out:
# 0.09193995192494563

# %%
###################################     ENREGISTREMENT      ###################################
###########################################################################################
# OUVERTURE SOUS ACCESS : AFIN DE GARDER TOUS LES NOMS DE COLONNES SANS EN PERDRE
# IL VAUT MIEUX ENREGISTRER LES BD DANS UN FICHIER TEXTE AVEC UN SEPARATEUR ;

data_sans_nan_doublons_sup_97501= data_sans_nan_doublons_sup_97501.drop(["CHR_CODE"],axis=1)
bv_euro= bv_euro.drop(["CHR_CODE"],axis=1)
jointure_deux_bases_bv =jointure_deux_bases_bv.drop(["CHR_CODE"],axis=1)

data_sans_nan_doublons_sup_97501.to_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER/BV_louis_clean_pv_FM.txt",sep=";", index=False)

bv_euro.to_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER/BV_euro_clean_pv_FM.txt",sep=";", index=False)

jointure_deux_bases_bv.to_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER/2_BV_jointure_pv_FM.txt",sep=";", index=False)

talbe_final_non_recon.to_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER/FM_commune_bv_non_reconciliees.txt",sep=";", index=False)

# %%
#########################################################################################
#                                     BROUILLON
#########################################################################################

# %%
#########################################################################################
#           SI L'ON VOUDRAIT COMPLETER LES ADRESSES MANQUANTES (POUR LES MAIRIES)
#########################################################################################

# %%
print(bv_louis["longitude"].isnull().sum())
print((bv_louis[bv_louis["longitude"].isnull()]["libelle.1"]=="MAIRIE").sum())
print((bv_louis[bv_louis["longitude"].isnull()]["libelle.1"]=="Mairie").sum())
print((bv_louis[bv_louis["longitude"].isnull()]["libelle.1"]=="mairie").sum())
print((bv_louis[bv_louis["longitude"].isnull()]["libelle.1"]=="M A I R I E").sum())
# il manque des mairies (ex: maries de ...)
# Out:
# 9053
# 2135
# 711
# 11
# 123

# %%
test=bv_louis.drop_duplicates(subset=["code","longitude","latitude"])

# %%
print(test["longitude"].isnull().sum())
print((test[test["longitude"].isnull()]["libelle.1"]=="MAIRIE").sum())
print((test[test["longitude"].isnull()]["libelle.1"]=="Mairie").sum())
print((test[test["longitude"].isnull()]["libelle.1"]=="mairie").sum())
print((test[test["longitude"].isnull()]["libelle.1"]=="M A I R I E").sum())
# Out:
# 535
# 300
# 7
# 1
# 0

# %%
test = bv_euro[bv_euro["Libellé de la commune"]=="Lyon"].copy()
test["code"] = test["Code du b.vote"]
test
# Out:
#       Code du département Libellé du département Code de la commune  \
# 47424                  69                  Rhône              69381
# 47425                  69                  Rhône              69381
# 47426                  69                  Rhône              69381
# 47427                  69                  Rhône              69381
# 47428                  69                  Rhône              69381
# ...                   ...                    ...                ...
# 47713                  69                  Rhône              69389
# 47714                  69                  Rhône              69389
# 47715                  69                  Rhône              69389
# 47716                  69                  Rhône              69389
# 47717                  69                  Rhône              69389
#
#       Libellé de la commune Code du b.vote Inscrits Abstentions % Abs/Ins  \
# 47424                  Lyon            101      664         251      37.8
# ...

# %%
test[test["Code de la commune"]=="69386"]
# Out:
#       Code du département Libellé du département Code de la commune  \
# 47574                  69                  Rhône              69386
# 47575                  69                  Rhône              69386
# 47576                  69                  Rhône              69386
# 47577                  69                  Rhône              69386
# 47578                  69                  Rhône              69386
# 47579                  69                  Rhône              69386
# 47580                  69                  Rhône              69386
# 47581                  69                  Rhône              69386
# 47582                  69                  Rhône              69386
# 47583                  69                  Rhône              69386
# 47584                  69                  Rhône              69386
# 47585                  69                  Rhône              69386
# 47586                  69                  Rhône              69386
# ...

# %%
bv_louis[bv_louis["commune"]=="LYON"]
# Out:
#       commune_code                  libelle code  \
# 143          69386  Lyon 6e  Arrondissement  611
# 1793         69384  Lyon 4e  Arrondissement  409
# 2005         69383  Lyon 3e  Arrondissement  301
# 8423         69383  Lyon 3e  Arrondissement  328
# 8759         69382  Lyon 2e  Arrondissement  216
# ...            ...                      ...  ...
# 69794        69383  Lyon 3e  Arrondissement  348
# 69795        69383  Lyon 3e  Arrondissement  353
# 69824        69383  Lyon 3e  Arrondissement  349
# 69825        69383  Lyon 3e  Arrondissement  345
# 69826        69383  Lyon 3e  Arrondissement  343
#
#                             libelle.1 num_voie                          voie  \
# 143              ECOLE ANTOINE REMOND       58                rue Bellecombe
# 1793            ECOLE DU GROS CAILLOU      169  BOULEVARD DE LA CROIX ROUSSE
# 2005                   MAIRIE DU 3ÈME      215                rue Duguesclin
# ...

# %%
bv_euro[bv_euro["Libellé de la commune"]=="Marseille"]["Inscrits"].astype(int).sum()
# Out:
# 498570

# %%
test2 =test[test["Libellé de la commune"]=="Marseille"].merge(bv_louis[bv_louis["commune"]=="MARSEILLE"], on ="code", how="left")

# %%
test2[test2["L_bv_code_init"].isnull()]
# Out:
#     Code du département Libellé du département Code de la commune  \
# 125                  13       Bouches-du-Rhône              13206
# 159                  13       Bouches-du-Rhône              13208
#
#     Libellé de la commune Code du b.vote Inscrits Abstentions % Abs/Ins  \
# 125             Marseille            673      642         288     44.86
# 159             Marseille            806     1091         561     51.42
#
#     Votants E_bv_code_init commune_code_x    CHR_CODE code commune_code_y  \
# 125     354           0673        1313206  1313206673  673            NaN
# 159     530           0806        1313208  1313208806  806            NaN
#
#     libelle libelle.1 num_voie voie complement1 complement2 lieu_dit  \
# 125     NaN       NaN      NaN  NaN         NaN         NaN      NaN
# 159     NaN       NaN      NaN  NaN         NaN         NaN      NaN
#
#     code_postal commune canton_code circonscription_code  longitude  latitude  \
# ...

# %%
bv_euro
# Out:
#       Code du département Libellé du département Code de la commune  \
# 0                      01                    Ain                001
# 1                      01                    Ain                002
# 2                      01                    Ain                004
# 3                      01                    Ain                004
# 4                      01                    Ain                004
# ...                   ...                    ...                ...
# 66573                  95             Val-d'Oise                680
# 66574                  95             Val-d'Oise                680
# 66575                  95             Val-d'Oise                680
# 66576                  95             Val-d'Oise                682
# 66577                  95             Val-d'Oise                690
#
#          Libellé de la commune Code du b.vote Inscrits Abstentions % Abs/Ins  \
# ...

# %%
bv_euro[bv_euro["Libellé de la commune"]=="Le Havre"]
# Out:
#       Code du département Libellé du département Code de la commune  \
# 52891                  76         Seine-Maritime                351
# 52892                  76         Seine-Maritime                351
# 52893                  76         Seine-Maritime                351
# 52894                  76         Seine-Maritime                351
# 52895                  76         Seine-Maritime                351
# ...                   ...                    ...                ...
# 52998                  76         Seine-Maritime                351
# 52999                  76         Seine-Maritime                351
# 53000                  76         Seine-Maritime                351
# 53001                  76         Seine-Maritime                351
# 53002                  76         Seine-Maritime                351
#
#       Libellé de la commune Code du b.vote Inscrits Abstentions % Abs/Ins  \
# 52891              Le Havre              1     1194         572     47.91
# ...

# %%
data_sans_nan_doublons_sup_97501[data_sans_nan_doublons_sup_97501["libelle"]=="Le Havre"]
# Out:
#       commune_code   libelle  code                               libelle.1  \
# 57           76351  Le Havre  1910       ECOLE ELEMENTAIRE EDOUARD HERRIOT
# 111          76351  Le Havre  1406             SALLE DES FETES DE BLEVILLE
# 664          76351  Le Havre  1409             SALLE DES FETES DE BLEVILLE
# 1495         76351  Le Havre  1405     ECOLE ELEMENTAIRE THEOPHILE GAUTIER
# 1810         76351  Le Havre  1607           ECOLE ELEMENTAIRE GEORGE SAND
# ...            ...       ...   ...                                     ...
# 48818        76351  Le Havre  1919               SALLE DES FETES DE SANVIC
# 48824        76351  Le Havre  1815            ECOLE ELEMENTAIRE REPUBLIQUE
# 48831        76351  Le Havre  1711  ECOLE PREELEMENTAIRE FERDINAND BUISSON
# 48834        76351  Le Havre  1816           ECOLE ELEMENTAIRE LOUIS BLANC
# 48835        76351  Le Havre  1817           ECOLE ELEMENTAIRE LOUIS BLANC
#
# ...

# %%
40159347-39862311
# Out:
# 297036

# %%
jointure_deux_bases_bv
# Out:
#       commune_code                  libelle code                 libelle.1  \
# 0            59350                    Lille  807              ECOLE AMPERE
# 1            50502                 Saint-Lô    8  HARAS-Ecurie n°5 (BV 08)
# 2            56121                  Lorient   11  GROUPE SCOLAIRE MERVILLE
# 3            76558   Saint-Aubin-Celloville    1                  Bureau 1
# 4            70407                 Perrouse    1             BUREAU UNIQUE
# ...            ...                      ...  ...                       ...
# 57935        77412  Saint-Germain-sur-École    1                    MAIRIE
# 57936        67307                Mulhausen    1         Bureau de vote 01
# 57937        02810        Villers-Cotterêts    7    SALLE GERARD PHILIPE 1
# 57938        25040                  Badevel    1                    Mairie
# 57939        14563  Saint-Benoît-d'Hébertot    1   SAINT BENOIT D'HEBERTOT
#
#       num_voie                              voie  \
# ...
