# %%
nom_colonnes = ['Code du département',
 'Libellé du département',
 'Code de la commune',
 'Libellé de la commune',
 'Code du b.vote',
 'Inscrits',
 'Abstentions',
 '% Abs/Ins',
 'Votants',
 '% Vot/Ins',
 'Blancs',
 '% Blancs/Ins',
 '% Blancs/Vot',
 'Nuls',
 '% Nuls/Ins',
 '% Nuls/Vot',
 'Exprimés',
 '% Exp/Ins',
 '% Exp/Vot',
 'N°Liste_1',
 'Libellé Abrégé Liste_1',
 'Libellé Etendu Liste_1',
 'Nom Tête de Liste_1',
 'Voix_1',
 '% Voix/Ins_1',
 '% Voix/Exp_1',
 'N°Liste_2',
 'Libellé Abrégé Liste_2',
 'Libellé Etendu Liste_2',
 'Nom Tête de Liste_2',
 'Voix_2',
 '% Voix/Ins_2',
 '% Voix/Exp_2',
 'N°Liste_3',
 'Libellé Abrégé Liste_3',
 'Libellé Etendu Liste_3',
 'Nom Tête de Liste_3',
 'Voix_3',
 '% Voix/Ins_3',
 '% Voix/Exp_3',
 'N°Liste_4',
 'Libellé Abrégé Liste_4',
 'Libellé Etendu Liste_4',
 'Nom Tête de Liste_4',
 'Voix_4',
 '% Voix/Ins_4',
 '% Voix/Exp_4',
 'N°Liste_5',
 'Libellé Abrégé Liste_5',
 'Libellé Etendu Liste_5',
 'Nom Tête de Liste_5',
 'Voix_5',
 '% Voix/Ins_5',
 '% Voix/Exp_5',
 'N°Liste_6',
 'Libellé Abrégé Liste_6',
 'Libellé Etendu Liste_6',
 'Nom Tête de Liste_6',
 'Voix_6',
 '% Voix/Ins_6',
 '% Voix/Exp_6',
 'N°Liste_7',
 'Libellé Abrégé Liste_7',
 'Libellé Etendu Liste_7',
 'Nom Tête de Liste_7',
 'Voix_7',
 '% Voix/Ins_7',
 '% Voix/Exp_7',
 'N°Liste_8',
 'Libellé Abrégé Liste_8',
 'Libellé Etendu Liste_8',
 'Nom Tête de Liste_8',
 'Voix_8',
 '% Voix/Ins_8',
 '% Voix/Exp_8',
 'N°Liste_9',
 'Libellé Abrégé Liste_9',
 'Libellé Etendu Liste_9',
 'Nom Tête de Liste_9',
 'Voix_9',
 '% Voix/Ins_9',
 '% Voix/Exp_9',
 'N°Liste_10',
 'Libellé Abrégé Liste_10',
 'Libellé Etendu Liste_10',
 'Nom Tête de Liste_10',
 'Voix_10',
 '% Voix/Ins_10',
 '% Voix/Exp_10',
 'N°Liste_11',
 'Libellé Abrégé Liste_11',
 'Libellé Etendu Liste_11',
 'Nom Tête de Liste_11',
 'Voix_11',
 '% Voix/Ins_11',
 '% Voix/Exp_11',
 'N°Liste_12',
 'Libellé Abrégé Liste_12',
 'Libellé Etendu Liste_12',
 'Nom Tête de Liste_12',
 'Voix_12',
 '% Voix/Ins_12',
 '% Voix/Exp_12',
 'N°Liste_13',
 'Libellé Abrégé Liste_13',
 'Libellé Etendu Liste_13',
 'Nom Tête de Liste_13',
 'Voix_13',
 '% Voix/Ins_13',
 '% Voix/Exp_13',
 'N°Liste_14',
 'Libellé Abrégé Liste_14',
 'Libellé Etendu Liste_14',
 'Nom Tête de Liste_14',
 'Voix_14',
 '% Voix/Ins_14',
 '% Voix/Exp_14',
 'N°Liste_15',
 'Libellé Abrégé Liste_15',
 'Libellé Etendu Liste_15',
 'Nom Tête de Liste_15',
 'Voix_15',
 '% Voix/Ins_15',
 '% Voix/Exp_15',
 'N°Liste_16',
 'Libellé Abrégé Liste_16',
 'Libellé Etendu Liste_16',
 'Nom Tête de Liste_16',
 'Voix_16',
 '% Voix/Ins_16',
 '% Voix/Exp_16',
 'N°Liste_17',
 'Libellé Abrégé Liste_17',
 'Libellé Etendu Liste_17',
 'Nom Tête de Liste_17',
 'Voix_17',
 '% Voix/Ins_17',
 '% Voix/Exp_17',
 'N°Liste_18',
 'Libellé Abrégé Liste_18',
 'Libellé Etendu Liste_18',
 'Nom Tête de Liste_18',
 'Voix_18',
 '% Voix/Ins_18',
 '% Voix/Exp_18',
 'N°Liste_19',
 'Libellé Abrégé Liste_19',
 'Libellé Etendu Liste_19',
 'Nom Tête de Liste_19',
 'Voix_19',
 '% Voix/Ins_19',
 '% Voix/Exp_19',
 'N°Liste_20',
 'Libellé Abrégé Liste_20',
 'Libellé Etendu Liste_20',
 'Nom Tête de Liste_20',
 'Voix_20',
 '% Voix/Ins_20',
 '% Voix/Exp_20',
 'N°Liste_21',
 'Libellé Abrégé Liste_21',
 'Libellé Etendu Liste_21',
 'Nom Tête de Liste_21',
 'Voix_21',
 '% Voix/Ins_21',
 '% Voix/Exp_21',
 'N°Liste_22',
 'Libellé Abrégé Liste_22',
 'Libellé Etendu Liste_22',
 'Nom Tête de Liste_22',
 'Voix_22',
 '% Voix/Ins_22',
 '% Voix/Exp_22',
 'N°Liste_23',
 'Libellé Abrégé Liste_23',
 'Libellé Etendu Liste_23',
 'Nom Tête de Liste_23',
 'Voix_23',
 '% Voix/Ins_23',
 '% Voix/Exp_23',
 'N°Liste_24',
 'Libellé Abrégé Liste_24',
 'Libellé Etendu Liste_24',
 'Nom Tête de Liste_24',
 'Voix_24',
 '% Voix/Ins_24',
 '% Voix/Exp_24',
 'N°Liste_25',
 'Libellé Abrégé Liste_25',
 'Libellé Etendu Liste_25',
 'Nom Tête de Liste_25',
 'Voix_25',
 '% Voix/Ins_25',
 '% Voix/Exp_25',
 'N°Liste_26',
 'Libellé Abrégé Liste_26',
 'Libellé Etendu Liste_26',
 'Nom Tête de Liste_26',
 'Voix_26',
 '% Voix/Ins_26',
 '% Voix/Exp_26',
 'N°Liste_27',
 'Libellé Abrégé Liste_27',
 'Libellé Etendu Liste_27',
 'Nom Tête de Liste_27',
 'Voix_27',
 '% Voix/Ins_27',
 '% Voix/Exp_27',
 'N°Liste_28',
 'Libellé Abrégé Liste_28',
 'Libellé Etendu Liste_28',
 'Nom Tête de Liste_28',
 'Voix_28',
 '% Voix/Ins_28',
 '% Voix/Exp_28',
 'N°Liste_29',
 'Libellé Abrégé Liste_29',
 'Libellé Etendu Liste_29',
 'Nom Tête de Liste_29',
 'Voix_29',
 '% Voix/Ins_29',
 '% Voix/Exp_29',
 'N°Liste_30',
 'Libellé Abrégé Liste_30',
 'Libellé Etendu Liste_30',
 'Nom Tête de Liste_30',
 'Voix_30',
 '% Voix/Ins_30',
 '% Voix/Exp_30',
 'N°Liste_31',
 'Libellé Abrégé Liste_31',
 'Libellé Etendu Liste_31',
 'Nom Tête de Liste_31',
 'Voix_31',
 '% Voix/Ins_31',
 '% Voix/Exp_31',
 'N°Liste_32',
 'Libellé Abrégé Liste_32',
 'Libellé Etendu Liste_32',
 'Nom Tête de Liste_32',
 'Voix_32',
 '% Voix/Ins_32',
 '% Voix/Exp_32',
 'N°Liste_33',
 'Libellé Abrégé Liste_33',
 'Libellé Etendu Liste_33',
 'Nom Tête de Liste_33',
 'Voix_33',
 '% Voix/Ins_33',
 '% Voix/Exp_33',
 'N°Liste_34',
 'Libellé Abrégé Liste_34',
 'Libellé Etendu Liste_34',
 'Nom Tête de Liste_34',
 'Voix_34',
 '% Voix/Ins_34',
 '% Voix/Exp_34']

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option("display.max_row",130)
pd.set_option("display.max_columns",130)

# %%
"""
- nettoyage de données:  doublons, nan, géronde (*2)


"""
# Out:
# '\n- nettoyage de données:  doublons, nan, géronde (*2)\n\n\n'

# %%
# LOUIS
bv_louis = pd.read_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER/geo_bureaux_de_vote.csv", encoding="utf" )
bv_louis = bv_louis[bv_louis["libelle"]!="Belfort"] 
bv_louis = bv_louis[bv_louis["libelle"]!="Pont-Saint-Esprit"] #
bv_louis = bv_louis[bv_louis["libelle"]!="Gradignan"]
bv_louis.loc[70041-2:70040,:]
# Out:
#       commune_code                  libelle code  \
# 70039        14563  Saint-Benoît-d'Hébertot  001
# 70040        97109                Gourbeyre  004
#
#                               libelle.1 num_voie                 voie  \
# 70039           SAINT BENOIT D'HEBERTOT      185    route de l'Eglise
# 70040  ECOLE MATERNELLE EULOGE NOGLOTTE        0  RUE EULOGE NOGLOTTE
#
#       complement1 complement2 lieu_dit code_postal                  commune  \
# 70039      Mairie         NaN      NaN       14130  SAINT BENOIT D'HEBERTOT
# 70040         NaN         NaN      NaN       97113                GOURBEYRE
#
#       canton_code circonscription_code  longitude   latitude  geo_score  \
# 70039       14-21                14-04   0.270550  49.316366       0.62
# 70040      971-20               971-04 -61.709542  15.991323       0.95
#
#       geo_type                                       geo_adresse  \
# 70039   street  Chemin de l'Eglise 14130 Saint-Benoît-d'Hébertot
# 70040   street               Rue Euloge Noglotte 97113 Gourbeyre
#
#              geo_id geo_ligne               geo_l4 geo_l5
# 70039  14563_396noi         G   CHEMIN DE L EGLISE    NaN
# 70040    97109_0051         G  RUE EULOGE NOGLOTTE    NaN

# %%
# EUROPEEEN (AVEC LES ENTETES COMPLETS)
bv_euro = pd.read_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER/resultats-definitifs-par-bureau-de-vote_entete_complet.csv",sep=";",header=0, names=nom_colonnes, dtype=str,encoding="iso-8859-1")
bv_euro.iloc[:2,:]
# Out:
#   Code du département Libellé du département Code de la commune  \
# 0                  01                    Ain                001
# 1                  01                    Ain                002
#
#      Libellé de la commune Code du b.vote Inscrits Abstentions % Abs/Ins  \
# 0  L'Abergement-Clémenciat           0001      601         268     44.59
# 1    L'Abergement-de-Varey           0001      210          69     32.86
#
#   Votants % Vot/Ins Blancs % Blancs/Ins % Blancs/Vot Nuls % Nuls/Ins  \
# 0     333     55.41      1         0.17          0.3   18          3
# 1     141     67.14      4          1.9         2.84    2       0.95
#
#   % Nuls/Vot Exprimés % Exp/Ins % Exp/Vot N°Liste_1 Libellé Abrégé Liste_1  \
# 0       5.41      314     52.25     94.29         1    LA FRANCE INSOUMISE
# 1       1.42      135     64.29     95.74         1    LA FRANCE INSOUMISE
#
#   Libellé Etendu Liste_1 Nom Tête de Liste_1 Voix_1 % Voix/Ins_1 % Voix/Exp_1  \
# 0    LA FRANCE INSOUMISE         AUBRY Manon     13         2.16         4.14
# 1    LA FRANCE INSOUMISE         AUBRY Manon      6         2.86         4.44
#
#   N°Liste_2 Libellé Abrégé Liste_2                  Libellé Etendu Liste_2  \
# 0         2      UNE FRANCE ROYALE  UNE FRANCE ROYALE AU COEUR DE L'EUROPE
# 1         2      UNE FRANCE ROYALE  UNE FRANCE ROYALE AU COEUR DE L'EUROPE
#
#    Nom Tête de Liste_2 Voix_2 % Voix/Ins_2 % Voix/Exp_2 N°Liste_3  \
# 0  DE PREVOISIN Robert      0            0            0         3
# 1  DE PREVOISIN Robert      0            0            0         3
#
#   Libellé Abrégé Liste_3 Libellé Etendu Liste_3 Nom Tête de Liste_3 Voix_3  \
# 0        LA LIGNE CLAIRE        LA LIGNE CLAIRE        CAMUS Renaud      0
# 1        LA LIGNE CLAIRE        LA LIGNE CLAIRE        CAMUS Renaud      0
#
#   % Voix/Ins_3 % Voix/Exp_3 N°Liste_4 Libellé Abrégé Liste_4  \
# 0            0            0         4           PARTI PIRATE
# 1            0            0         4           PARTI PIRATE
#
#   Libellé Etendu Liste_4 Nom Tête de Liste_4 Voix_4 % Voix/Ins_4 % Voix/Exp_4  \
# 0           PARTI PIRATE        MARIE Florie      0            0            0
# 1           PARTI PIRATE        MARIE Florie      0            0            0
#
#   N°Liste_5 Libellé Abrégé Liste_5  \
# 0         5            RENAISSANCE
# 1         5            RENAISSANCE
#
#                               Libellé Etendu Liste_5 Nom Tête de Liste_5  \
# 0  RENAISSANCE SOUTENUE PAR LA RÉPUBLIQUE EN MARC...    LOISEAU Nathalie
# 1  RENAISSANCE SOUTENUE PAR LA RÉPUBLIQUE EN MARC...    LOISEAU Nathalie
#
#   Voix_5 % Voix/Ins_5 % Voix/Exp_5 N°Liste_6     Libellé Abrégé Liste_6  \
# 0     64        10.65        20.38         6  DÉMOCRATIE REPRÉSENTATIVE
# 1     29        13.81        21.48         6  DÉMOCRATIE REPRÉSENTATIVE
#
#       Libellé Etendu Liste_6 Nom Tête de Liste_6 Voix_6 % Voix/Ins_6  \
# 0  DÉMOCRATIE REPRÉSENTATIVE       TRAORÉ Hamada      0            0
# 1  DÉMOCRATIE REPRÉSENTATIVE       TRAORÉ Hamada      0            0
#
#   % Voix/Exp_6 N°Liste_7 Libellé Abrégé Liste_7  \
# 0            0         7     ENSEMBLE PATRIOTES
# 1            0         7     ENSEMBLE PATRIOTES
#
#                               Libellé Etendu Liste_7 Nom Tête de Liste_7  ...  \
# 0  ENSEMBLE PATRIOTES ET GILETS JAUNES : POUR LA ...   PHILIPPOT Florian  ...
# 1  ENSEMBLE PATRIOTES ET GILETS JAUNES : POUR LA ...   PHILIPPOT Florian  ...
#
#   % Voix/Ins_25 % Voix/Exp_25 N°Liste_26 Libellé Abrégé Liste_26  \
# 0             0             0         26               ESPERANTO
# 1             0             0         26               ESPERANTO
#
#                              Libellé Etendu Liste_26 Nom Tête de Liste_26  \
# 0  ESPÉRANTO - LANGUE COMMUNE ÉQUITABLE POUR L'EU...    DIEUMEGARD Pierre
# 1  ESPÉRANTO - LANGUE COMMUNE ÉQUITABLE POUR L'EU...    DIEUMEGARD Pierre
#
#   Voix_26 % Voix/Ins_26 % Voix/Exp_26 N°Liste_27 Libellé Abrégé Liste_27  \
# 0       1          0.17          0.32         27     ÉVOLUTION CITOYENNE
# 1       0             0             0         27     ÉVOLUTION CITOYENNE
#
#   Libellé Etendu Liste_27  Nom Tête de Liste_27 Voix_27 % Voix/Ins_27  \
# 0     ÉVOLUTION CITOYENNE  CHALENÇON Christophe       0             0
# 1     ÉVOLUTION CITOYENNE  CHALENÇON Christophe       0             0
#
#   % Voix/Exp_27 N°Liste_28 Libellé Abrégé Liste_28  \
# 0             0         28          ALLIANCE JAUNE
# 1             0         28          ALLIANCE JAUNE
#
#                   Libellé Etendu Liste_28 Nom Tête de Liste_28 Voix_28  \
# 0  ALLIANCE JAUNE, LA RÉVOLTE PAR LE VOTE      LALANNE Francis       1
# 1  ALLIANCE JAUNE, LA RÉVOLTE PAR LE VOTE      LALANNE Francis       0
#
#   % Voix/Ins_28 % Voix/Exp_28 N°Liste_29 Libellé Abrégé Liste_29  \
# 0          0.17          0.32         29     UNION DROITE-CENTRE
# 1             0             0         29     UNION DROITE-CENTRE
#
#            Libellé Etendu Liste_29     Nom Tête de Liste_29 Voix_29  \
# 0  UNION DE LA DROITE ET DU CENTRE  BELLAMY François-Xavier      28
# 1  UNION DE LA DROITE ET DU CENTRE  BELLAMY François-Xavier      16
#
#   % Voix/Ins_29 % Voix/Exp_29 N°Liste_30 Libellé Abrégé Liste_30  \
# 0          4.66          8.92         30         EUROPE ÉCOLOGIE
# 1          7.62         11.85         30         EUROPE ÉCOLOGIE
#
#   Libellé Etendu Liste_30 Nom Tête de Liste_30 Voix_30 % Voix/Ins_30  \
# 0         EUROPE ÉCOLOGIE        JADOT Yannick      52          8.65
# 1         EUROPE ÉCOLOGIE        JADOT Yannick      36         17.14
#
#   % Voix/Exp_30 N°Liste_31 Libellé Abrégé Liste_31 Libellé Etendu Liste_31  \
# 0         16.56         31        PARTI ANIMALISTE        PARTI ANIMALISTE
# 1         26.67         31        PARTI ANIMALISTE        PARTI ANIMALISTE
#
#   Nom Tête de Liste_31 Voix_31 % Voix/Ins_31 % Voix/Exp_31 N°Liste_32  \
# 0         THOUY Hélène       7          1.16          2.23         32
# 1         THOUY Hélène       5          2.38           3.7         32
#
#    Libellé Abrégé Liste_32                            Libellé Etendu Liste_32  \
# 0  LES OUBLIES DE L'EUROPE  LES OUBLIÉS DE L'EUROPE - ARTISANS, COMMERÇANT...
# 1  LES OUBLIES DE L'EUROPE  LES OUBLIÉS DE L'EUROPE - ARTISANS, COMMERÇANT...
#
#   Nom Tête de Liste_32 Voix_32 % Voix/Ins_32 % Voix/Exp_32 N°Liste_33  \
# 0        BIDOU Olivier       4          0.67          1.27         33
# 1        BIDOU Olivier       1          0.48          0.74         33
#
#   Libellé Abrégé Liste_33                            Libellé Etendu Liste_33  \
# 0                   UDLEF  UDLEF (UNION DÉMOCRATIQUE POUR LA LIBERTÉ ÉGAL...
# 1                   UDLEF  UDLEF (UNION DÉMOCRATIQUE POUR LA LIBERTÉ ÉGAL...
#
#    Nom Tête de Liste_33 Voix_33 % Voix/Ins_33 % Voix/Exp_33 N°Liste_34  \
# 0  PERSON Christian Luc       0             0             0         34
# 1  PERSON Christian Luc       0             0             0         34
#
#      Libellé Abrégé Liste_34            Libellé Etendu Liste_34  \
# 0  EUROPE AU SERVICE PEUPLES  UNE EUROPE AU SERVICE DES PEUPLES
# 1  EUROPE AU SERVICE PEUPLES  UNE EUROPE AU SERVICE DES PEUPLES
#
#   Nom Tête de Liste_34 Voix_34 % Voix/Ins_34 % Voix/Exp_34
# 0        AZERGUI Nagib       0             0             0
# 1        AZERGUI Nagib       0             0             0
#
# [2 rows x 257 columns]

# %%
#######################   CORRECTION DE CODE BV DANS LES DEUX BV   #######################

# %%
for i in range(bv_louis.shape[0]):
    try :
        bv_louis.iloc[i,2]=str(int(bv_louis.iloc[i,2]))
    except:
        if (bv_louis.iloc[i,2]=="Unique")|(bv_louis.iloc[i,2]=="unique")|(bv_louis.iloc[i,2]=="UNIQUE")|(bv_louis.iloc[i,2]=="BUR"): 
            bv_louis.iloc[i,2]="1"
        if bv_louis.iloc[i,2]=="BV01":
            bv_louis.iloc[i,2]="1"
        if bv_louis.iloc[i,2]=="BV02":
            bv_louis.iloc[i,2]="2"
# Out:
# 0        807
# 1          1
# 2        001
# 3          1
# 4          1
#         ...
# 70037    007
# 70038      1
# 70039    001
# 70040    004
# 70041    005
# Name: code, Length: 70042, dtype: object

# %%
for i in range(bv_louis.shape[0]):
    
    if bv_louis.iloc[i,1]=="Montbéliard":
        
        continue
    if bv_louis.iloc[i,1]=="Toulouse":
        if bv_louis.iloc[i,2].find("0")!=-1:
            bv_louis.iloc[i,2] = bv_louis.iloc[i,2].replace("0","")
        else:
            continue
    try :
        m = int(bv_louis.iloc[i,2])
        bv_louis.iloc[i,2]=str(m)
    except:
        if (bv_louis.iloc[i,2]=="Unique")|(bv_louis.iloc[i,2]=="unique")|(bv_louis.iloc[i,2]=="UNIQUE")|(bv_louis.iloc[i,2]=="BUR")|(bv_louis.iloc[i,2]=="M1-3")|(bv_louis.iloc[i,2]=="1LC")|(bv_louis.iloc[i,2]=="01 - 1"): 
            bv_louis.iloc[i,2]="1"
        if (bv_louis.iloc[i,2]=="BV01")|(bv_louis.iloc[i,2]=="Bureau 1")|(bv_louis.iloc[i,2]=="M1 - 3")|(bv_louis.iloc[i,2]=="M1")|(bv_louis.iloc[i,2]=="UN")|(bv_louis.iloc[i,2]=="U")|(bv_louis.iloc[i,2]=="VO"):
            bv_louis.iloc[i,2]="1"
        if (bv_louis.iloc[i,2]=="BV02")|(bv_louis.iloc[i,2]=="Bureau 2"):
            bv_louis.iloc[i,2]="2"
        if (bv_louis.iloc[i,2][0]=="A")|(bv_louis.iloc[i,2][0]=="B")|(bv_louis.iloc[i,2][0]=="C")|(bv_louis.iloc[i,2][0]=="D")|(bv_louis.iloc[i,2][0]=="E")|(bv_louis.iloc[i,2][0]=="F") :
            bv_louis.iloc[i,2] = bv_louis.iloc[i,2][1:]
        if (bv_louis.iloc[i,2][-1]=="A")|(bv_louis.iloc[i,2][-1]=="B")|(bv_louis.iloc[i,2][-1]=="C")|(bv_louis.iloc[i,2][-1]=="D")|(bv_louis.iloc[i,2][-1]=="E")|(bv_louis.iloc[i,2][-1]=="F") : 
            bv_louis.iloc[i,2] = bv_louis.iloc[i,2][:-1]
        if bv_louis.iloc[i,2][0]=="0":
            bv_louis.iloc[i,2] = bv_louis.iloc[i,2][1:]
        #print("zedezd 1", bv_louis.iloc[i,2])    
        if bv_louis.iloc[i,2].find("-")!=-1:
            #print("vdkjhzdb")
            if bv_louis.iloc[i,2][0]=="-":
                print(bv_louis.iloc[i,2])
            if bv_louis.iloc[i,2][1]=="-":
                bv_louis.iloc[i,2] = bv_louis.iloc[i,2][0]
            #print("yyy",bv_louis.iloc[i,2])
            
        if bv_louis.iloc[i,2].find(" ")!=-1:
            if bv_louis.iloc[i,2][1]==" ":
                bv_louis.iloc[i,2] = bv_louis.iloc[i,2][0]      
                                
        try :
            if bv_louis.iloc[i,2][2]=="-":
                bv_louis.iloc[i,2] = bv_louis.iloc[i,2].replace("-","")
        except:
             continue
                
print("phase 1 fini")
# Out:
# phase 1 fini

# %%
# Out:
# True

# %%
# Out:
# phase 1 fini

# %%
for i in range(bv_louis.shape[0]):
    try :
        bv_louis.iloc[i,2]=str(int(bv_louis.iloc[i,2]))
    except:
        if (bv_louis.iloc[i,2][0]=="A")|(bv_louis.iloc[i,2][0]=="B")|(bv_louis.iloc[i,2][0]=="C")|(bv_louis.iloc[i,2][0]=="D")|(bv_louis.iloc[i,2][0]=="E")|(bv_louis.iloc[i,2][0]=="F") :
            bv_louis.iloc[i,2] = bv_louis.iloc[i,2][1:]
print("phase 1 fini")

for i in range(bv_louis.shape[0]):
    try :
    except:
        if (bv_louis.iloc[i,2][-1]=="A")|(bv_louis.iloc[i,2][-1]=="B")|(bv_louis.iloc[i,2][-1]=="C")|(bv_louis.iloc[i,2][-1]=="D")|(bv_louis.iloc[i,2][-1]=="E")|(bv_louis.iloc[i,2][-1]=="F") : 
            bv_louis.iloc[i,2] = bv_louis.iloc[i,2][:-1]
print("phase 2 fini")

for i in range(bv_louis.shape[0]):
    try :
    except:
        if (bv_louis.iloc[i,2][-1]=="A")|(bv_louis.iloc[i,2][-1]=="B")|(bv_louis.iloc[i,2][-1]=="C")|(bv_louis.iloc[i,2][-1]=="D")|(bv_louis.iloc[i,2][-1]=="E")|(bv_louis.iloc[i,2][-1]=="F") : 
            bv_louis.iloc[i,2] = bv_louis.iloc[i,2][:-1]
print("phase 2 fini")

# %%
# Out:
# 1-1

# %%
#################################   DOUBLONS    ###########################################
"""
- Certains BV ont les mêmes coordonnées et des codes BV différents(deux salles dans un même bâtiment)


"""

# %%
bv_sans_doublons= bv_louis.drop_duplicates(subset=["longitude","latitude"])
print(bv_sans_doublons.shape)
bv_sans_nan_doublons = bv_sans_doublons[bv_sans_doublons["longitude"].isnull()==False]
print(bv_sans_nan_doublons.shape)
# Out:
# (47354, 22)
# (47353, 22)

# %%
bv_sans_nan_doublons
# Out:
#       commune_code                  libelle code  \
# 0            59350                    Lille  807
# 2            97401              Les Avirons  001
# 5            50502                 Saint-Lô  008
# 7            97411              Saint-Denis  118
# 10           56121                  Lorient   11
# ...            ...                      ...  ...
# 70032        97616                     Sada   83
# 70033        97616                     Sada  129
# 70038        25040                  Badevel    1
# 70039        14563  Saint-Benoît-d'Hébertot  001
# 70040        97109                Gourbeyre  004
#
#                                       libelle.1 num_voie  \
# 0                                  ECOLE AMPERE       64
# 2                            MAIRIE DES AVIRONS       61
# 5                      HARAS-Ecurie n°5 (BV 08)      NaN
# 7      ECOLE PRIM. JEAN BAPTISTE  BOSSARD (118)      NaN
# 10                     GROUPE SCOLAIRE MERVILLE        1
# ...                                         ...      ...
# 70032              ECOLE DE MTSANGAMTITI SADA 3      NaN
# 70033                         SADA BIBLIOTHEQUE      NaN
# 70038                                    Mairie       16
# 70039                   SAINT BENOIT D'HEBERTOT      185
# 70040          ECOLE MATERNELLE EULOGE NOGLOTTE        0
#
#                            voie       complement1 complement2 lieu_dit  \
# 0                    RUE D'IENA               NaN         NaN      NaN
# 2      AV. DU GENERAL DE GAULLE               NaN         NaN      NaN
# 5          Rue de la Goubedière  HARAS-Ecurie n°5         NaN      NaN
# 7                 9 RUE LACROIX               NaN         NaN      NaN
# 10           AVENUE DE LA MARNE               NaN         NaN      NaN
# ...                         ...               ...         ...      ...
# 70032     ECOLE DE MTSANGAMTITI               NaN         NaN      NaN
# 70033      BIBLIOTHEQUE DE SADA               NaN         NaN      NaN
# 70038                Grande Rue     25490 BADEVEL         NaN      NaN
# 70039         route de l'Eglise            Mairie         NaN      NaN
# 70040       RUE EULOGE NOGLOTTE               NaN         NaN      NaN
#
#       code_postal                  commune canton_code circonscription_code  \
# 0           59000                    LILLE       59-27                59-11
# 2           97425              Les Avirons      974-01               974-07
# 5           50000                 SAINT LO       50-23                50-01
# 7           97490          SAINTE CLOTILDE      974-09               974-01
# 10          56100                  LORIENT       56-09                56-05
# ...           ...                      ...         ...                  ...
# 70032       97640                     SADA      976-12               976-02
# 70033       97640                     SADA      976-12               976-02
# 70038       25490                  BADEVEL       25-01                25-04
# 70039       14130  SAINT BENOIT D'HEBERTOT       14-21                14-04
# 70040       97113                GOURBEYRE      971-20               971-04
#
#        longitude   latitude  geo_score     geo_type  \
# 0       3.043027  50.621124       0.96       street
# 2      55.333200 -21.242358       0.88  housenumber
# 5      -1.074428  49.117378       0.95       street
# 7      55.483666 -20.893953       0.96  housenumber
# 10     -3.368220  47.744513       0.96  housenumber
# ...          ...        ...        ...          ...
# 70032  45.093095 -12.851659       0.34       street
# 70033  45.108125 -12.845941       0.88       street
# 70038   6.939282  47.500913       0.94  housenumber
# 70039   0.270550  49.316366       0.62       street
# 70040 -61.709542  15.991323       0.95       street
#
#                                             geo_adresse             geo_id  \
# 0                                Rue d'Iena 59000 Lille         59350_4658
# 2      61 Avenue du Général de Gaulle 97425 Les Avirons   97401_0127_00061
# 5                   Rue de la Goubediere 50000 Saint-Lô         50502_1162
# 7                       9 Rue Lacroix 97400 Saint-Denis  BANO_974110728X_9
# 10                   1 Avenue de la Marne 56100 Lorient   56121_3890_00001
# ...                                                 ...                ...
# 70032                      Impasse Mtsangani 97640 Sada         97616_0644
# 70033                 Rue de la Bibliothéque 97640 Sada         97616_0200
# 70038                       16 Grande Rue 25490 Badevel   25040_0113_00016
# 70039  Chemin de l'Eglise 14130 Saint-Benoît-d'Hébertot       14563_396noi
# 70040               Rue Euloge Noglotte 97113 Gourbeyre         97109_0051
#
#       geo_ligne                          geo_l4 geo_l5
# 0             G                      RUE D IENA    NaN
# 2             G  61 AVENUE DU GENERAL DE GAULLE    NaN
# 5             G            RUE DE LA GOUBEDIERE    NaN
# 7             G                   9 RUE LACROIX    NaN
# 10            G            1 AVENUE DE LA MARNE    NaN
# ...         ...                             ...    ...
# 70032         G               IMPASSE MTSANGANI    NaN
# 70033         G          RUE DE LA BIBLIOTHEQUE    NaN
# 70038         G                   16 GRANDE RUE    NaN
# 70039         G              CHEMIN DE L EGLISE    NaN
# 70040         G             RUE EULOGE NOGLOTTE    NaN
#
# [47353 rows x 22 columns]

# %%
data_sans_nan_doublons_sup_97501 = bv_sans_nan_doublons.copy()
temp_sup_97501 = 0
temp_lettre = 0
for k in bv_sans_nan_doublons["commune_code"].value_counts().index:
    try:
        temp_k = int(k)
        if (temp_k >= 97501):
            temp_sup_97501 = temp_sup_97501 + 1
            print(temp_k)
            data_sans_nan_doublons_sup_97501 = data_sans_nan_doublons_sup_97501[data_sans_nan_doublons_sup_97501["commune_code"]!=k]
            
    except:
        temp_lettre = temp_lettre +1
        #print(k)
# Out:
# 97611
# 97604
# 97610
# 97612
# 97602
# 97605
# 97603
# 97607
# 97616
# 97617
# 97609
# 97615
# 97606
# 97614
# 97608
# 97613
# 97601

# %%
data_sans_nan_doublons_sup_97501
# Out:
#       commune_code                  libelle code  \
# 0            59350                    Lille  807
# 2            97401              Les Avirons  001
# 5            50502                 Saint-Lô  008
# 7            97411              Saint-Denis  118
# 10           56121                  Lorient   11
# ...            ...                      ...  ...
# 70027        77412  Saint-Germain-sur-École    1
# 70028        67307                Mulhausen   01
# 70038        25040                  Badevel    1
# 70039        14563  Saint-Benoît-d'Hébertot  001
# 70040        97109                Gourbeyre  004
#
#                                       libelle.1 num_voie  \
# 0                                  ECOLE AMPERE       64
# 2                            MAIRIE DES AVIRONS       61
# 5                      HARAS-Ecurie n°5 (BV 08)      NaN
# 7      ECOLE PRIM. JEAN BAPTISTE  BOSSARD (118)      NaN
# 10                     GROUPE SCOLAIRE MERVILLE        1
# ...                                         ...      ...
# 70027                                    MAIRIE      NaN
# 70028                         Bureau de vote 01        2
# 70038                                    Mairie       16
# 70039                   SAINT BENOIT D'HEBERTOT      185
# 70040          ECOLE MATERNELLE EULOGE NOGLOTTE        0
#
#                            voie                    complement1 complement2  \
# 0                    RUE D'IENA                            NaN         NaN
# 2      AV. DU GENERAL DE GAULLE                            NaN         NaN
# 5          Rue de la Goubedière               HARAS-Ecurie n°5         NaN
# 7                 9 RUE LACROIX                            NaN         NaN
# 10           AVENUE DE LA MARNE                            NaN         NaN
# ...                         ...                            ...         ...
# 70027         Chemin des Portes  77930 SAINT GERMAIN SUR ECOLE         NaN
# 70028          rue de la Mairie                            NaN         NaN
# 70038                Grande Rue                  25490 BADEVEL         NaN
# 70039         route de l'Eglise                         Mairie         NaN
# 70040       RUE EULOGE NOGLOTTE                            NaN         NaN
#
#       lieu_dit code_postal                  commune canton_code  \
# 0          NaN       59000                    LILLE       59-27
# 2          NaN       97425              Les Avirons      974-01
# 5          NaN       50000                 SAINT LO       50-23
# 7          NaN       97490          SAINTE CLOTILDE      974-09
# 10         NaN       56100                  LORIENT       56-09
# ...        ...         ...                      ...         ...
# 70027      NaN       77930  SAINT-GERMAIN-SUR-ÉCOLE       77-07
# 70028      NaN       67350                MULHAUSEN       67-08
# 70038      NaN       25490                  BADEVEL       25-01
# 70039      NaN       14130  SAINT BENOIT D'HEBERTOT       14-21
# 70040      NaN       97113                GOURBEYRE      971-20
#
#       circonscription_code  longitude   latitude  geo_score     geo_type  \
# 0                    59-11   3.043027  50.621124       0.96       street
# 2                   974-07  55.333200 -21.242358       0.88  housenumber
# 5                    50-01  -1.074428  49.117378       0.95       street
# 7                   974-01  55.483666 -20.893953       0.96  housenumber
# 10                   56-05  -3.368220  47.744513       0.96  housenumber
# ...                    ...        ...        ...        ...          ...
# 70027                77-01   2.509938  48.474254       0.93       street
# 70028                67-07   7.551771  48.882282       0.94  housenumber
# 70038                25-04   6.939282  47.500913       0.94  housenumber
# 70039                14-04   0.270550  49.316366       0.62       street
# 70040               971-04 -61.709542  15.991323       0.95       street
#
#                                             geo_adresse             geo_id  \
# 0                                Rue d'Iena 59000 Lille         59350_4658
# 2      61 Avenue du Général de Gaulle 97425 Les Avirons   97401_0127_00061
# 5                   Rue de la Goubediere 50000 Saint-Lô         50502_1162
# 7                       9 Rue Lacroix 97400 Saint-Denis  BANO_974110728X_9
# 10                   1 Avenue de la Marne 56100 Lorient   56121_3890_00001
# ...                                                 ...                ...
# 70027   Chemin des Portes 77930 Saint-Germain-sur-École         77412_0240
# 70028                2 Rue de la Mairie 67350 Mulhausen   67307_0023_00002
# 70038                       16 Grande Rue 25490 Badevel   25040_0113_00016
# 70039  Chemin de l'Eglise 14130 Saint-Benoît-d'Hébertot       14563_396noi
# 70040               Rue Euloge Noglotte 97113 Gourbeyre         97109_0051
#
#       geo_ligne                          geo_l4 geo_l5
# 0             G                      RUE D IENA    NaN
# 2             G  61 AVENUE DU GENERAL DE GAULLE    NaN
# 5             G            RUE DE LA GOUBEDIERE    NaN
# 7             G                   9 RUE LACROIX    NaN
# 10            G            1 AVENUE DE LA MARNE    NaN
# ...         ...                             ...    ...
# 70027         G               CHEMIN DES PORTES    NaN
# 70028         G              2 RUE DE LA MAIRIE    NaN
# 70038         G                   16 GRANDE RUE    NaN
# 70039         G              CHEMIN DE L EGLISE    NaN
# 70040         G             RUE EULOGE NOGLOTTE    NaN
#
# [47234 rows x 22 columns]

# %%
# vérification
data_sans_nan_doublons_sup_97501["geo_score"].isnull().sum()
# Out:
# 0

# %%
data_sans_nan_doublons_sup_97501[data_sans_nan_doublons_sup_97501["libelle.1"]=="ANCIENNE CURE"]
# Out:
#       commune_code             libelle  code      libelle.1 num_voie  \
# 45674        85151  Mortagne-sur-Sèvre  0004  ANCIENNE CURE      NaN
# 65725        42154             Néronde     1  ANCIENNE CURE    42510
#
#                    voie complement1 complement2 lieu_dit code_postal  \
# 45674   1 rue du Centre     Evrunes         NaN      NaN       85290
# 65725           NERONDE         NaN         NaN      NaN       42510
#
#                   commune canton_code circonscription_code  longitude  \
# 45674  MORTAGNE SUR SEVRE       85-11                85-04  -0.971915
# 65725             NÉRONDE       42-04                42-06   2.127469
#
#         latitude  geo_score      geo_type  \
# 45674  47.000255       0.95   housenumber
# 65725  22.927179       0.93  municipality
#
#                                     geo_adresse            geo_id geo_ligne  \
# 45674  1 Rue du Centre 85290 Mortagne-sur-Sèvre  85151_0150_00001         G
# 65725                                   Néronde             42154         G
#
#                 geo_l4 geo_l5
# 45674  1 RUE DU CENTRE    NaN
# 65725          NERONDE    NaN

# %%
data_sans_nan_doublons_sup_97501.loc[65725,"longitude"]=4.236545
data_sans_nan_doublons_sup_97501.loc[65725,"latitude"]= 45.838744

# %%
#vérification
data_sans_nan_doublons_sup_97501[data_sans_nan_doublons_sup_97501["libelle.1"]=="ANCIENNE CURE"]
# Out:
#       commune_code             libelle  code      libelle.1 num_voie  \
# 45674        85151  Mortagne-sur-Sèvre  0004  ANCIENNE CURE      NaN
# 65725        42154             Néronde     1  ANCIENNE CURE    42510
#
#                    voie complement1 complement2 lieu_dit code_postal  \
# 45674   1 rue du Centre     Evrunes         NaN      NaN       85290
# 65725           NERONDE         NaN         NaN      NaN       42510
#
#                   commune canton_code circonscription_code  longitude  \
# 45674  MORTAGNE SUR SEVRE       85-11                85-04  -0.971915
# 65725             NÉRONDE       42-04                42-06   4.236545
#
#         latitude  geo_score      geo_type  \
# 45674  47.000255       0.95   housenumber
# 65725  45.838744       0.93  municipality
#
#                                     geo_adresse            geo_id geo_ligne  \
# 45674  1 Rue du Centre 85290 Mortagne-sur-Sèvre  85151_0150_00001         G
# 65725                                   Néronde             42154         G
#
#                 geo_l4 geo_l5
# 45674  1 RUE DU CENTRE    NaN
# 65725          NERONDE    NaN

# %%
#data_sans_nan_doublons_sup_97501.to_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/CORRIGER/BV_clean.csv", index=False)

# %%
bv_louis.drop_duplicates(subset=["longitude","latitude"])
# Out:
#       commune_code                  libelle code  \
# 0            59350                    Lille  807
# 1            63058                   Bulhon    1
# 2            97401              Les Avirons  001
# 5            50502                 Saint-Lô  008
# 7            97411              Saint-Denis  118
# ...            ...                      ...  ...
# 70032        97616                     Sada   83
# 70033        97616                     Sada  129
# 70038        25040                  Badevel    1
# 70039        14563  Saint-Benoît-d'Hébertot  001
# 70040        97109                Gourbeyre  004
#
#                                       libelle.1 num_voie  \
# 0                                  ECOLE AMPERE       64
# 1                                      BUREAU 1      NaN
# 2                            MAIRIE DES AVIRONS       61
# 5                      HARAS-Ecurie n°5 (BV 08)      NaN
# 7      ECOLE PRIM. JEAN BAPTISTE  BOSSARD (118)      NaN
# ...                                         ...      ...
# 70032              ECOLE DE MTSANGAMTITI SADA 3      NaN
# 70033                         SADA BIBLIOTHEQUE      NaN
# 70038                                    Mairie       16
# 70039                   SAINT BENOIT D'HEBERTOT      185
# 70040          ECOLE MATERNELLE EULOGE NOGLOTTE        0
#
#                            voie       complement1 complement2 lieu_dit  \
# 0                    RUE D'IENA               NaN         NaN      NaN
# 1                        Mairie               NaN         NaN      NaN
# 2      AV. DU GENERAL DE GAULLE               NaN         NaN      NaN
# 5          Rue de la Goubedière  HARAS-Ecurie n°5         NaN      NaN
# 7                 9 RUE LACROIX               NaN         NaN      NaN
# ...                         ...               ...         ...      ...
# 70032     ECOLE DE MTSANGAMTITI               NaN         NaN      NaN
# 70033      BIBLIOTHEQUE DE SADA               NaN         NaN      NaN
# 70038                Grande Rue     25490 BADEVEL         NaN      NaN
# 70039         route de l'Eglise            Mairie         NaN      NaN
# 70040       RUE EULOGE NOGLOTTE               NaN         NaN      NaN
#
#       code_postal                  commune canton_code circonscription_code  \
# 0           59000                    LILLE       59-27                59-11
# 1           63350                   BULHON       63-19                63-05
# 2           97425              Les Avirons      974-01               974-07
# 5           50000                 SAINT LO       50-23                50-01
# 7           97490          SAINTE CLOTILDE      974-09               974-01
# ...           ...                      ...         ...                  ...
# 70032       97640                     SADA      976-12               976-02
# 70033       97640                     SADA      976-12               976-02
# 70038       25490                  BADEVEL       25-01                25-04
# 70039       14130  SAINT BENOIT D'HEBERTOT       14-21                14-04
# 70040       97113                GOURBEYRE      971-20               971-04
#
#        longitude   latitude  geo_score     geo_type  \
# 0       3.043027  50.621124       0.96       street
# 1            NaN        NaN       0.00          NaN
# 2      55.333200 -21.242358       0.88  housenumber
# 5      -1.074428  49.117378       0.95       street
# 7      55.483666 -20.893953       0.96  housenumber
# ...          ...        ...        ...          ...
# 70032  45.093095 -12.851659       0.34       street
# 70033  45.108125 -12.845941       0.88       street
# 70038   6.939282  47.500913       0.94  housenumber
# 70039   0.270550  49.316366       0.62       street
# 70040 -61.709542  15.991323       0.95       street
#
#                                             geo_adresse             geo_id  \
# 0                                Rue d'Iena 59000 Lille         59350_4658
# 1                                                   NaN                NaN
# 2      61 Avenue du Général de Gaulle 97425 Les Avirons   97401_0127_00061
# 5                   Rue de la Goubediere 50000 Saint-Lô         50502_1162
# 7                       9 Rue Lacroix 97400 Saint-Denis  BANO_974110728X_9
# ...                                                 ...                ...
# 70032                      Impasse Mtsangani 97640 Sada         97616_0644
# 70033                 Rue de la Bibliothéque 97640 Sada         97616_0200
# 70038                       16 Grande Rue 25490 Badevel   25040_0113_00016
# 70039  Chemin de l'Eglise 14130 Saint-Benoît-d'Hébertot       14563_396noi
# 70040               Rue Euloge Noglotte 97113 Gourbeyre         97109_0051
#
#       geo_ligne                          geo_l4 geo_l5
# 0             G                      RUE D IENA    NaN
# 1           NaN                             NaN    NaN
# 2             G  61 AVENUE DU GENERAL DE GAULLE    NaN
# 5             G            RUE DE LA GOUBEDIERE    NaN
# 7             G                   9 RUE LACROIX    NaN
# ...         ...                             ...    ...
# 70032         G               IMPASSE MTSANGANI    NaN
# 70033         G          RUE DE LA BIBLIOTHEQUE    NaN
# 70038         G                   16 GRANDE RUE    NaN
# 70039         G              CHEMIN DE L EGLISE    NaN
# 70040         G             RUE EULOGE NOGLOTTE    NaN
#
# [47354 rows x 22 columns]

# %%
bv_louis.drop_duplicates(subset=["code","longitude","latitude"])
# Out:
#       commune_code                  libelle code  \
# 0            59350                    Lille  807
# 1            63058                   Bulhon    1
# 2            97401              Les Avirons  001
# 5            50502                 Saint-Lô  008
# 7            97411              Saint-Denis  118
# ...            ...                      ...  ...
# 70037        02810        Villers-Cotterêts  007
# 70038        25040                  Badevel    1
# 70039        14563  Saint-Benoît-d'Hébertot  001
# 70040        97109                Gourbeyre  004
# 70041        97109                Gourbeyre  005
#
#                                       libelle.1 num_voie  \
# 0                                  ECOLE AMPERE       64
# 1                                      BUREAU 1      NaN
# 2                            MAIRIE DES AVIRONS       61
# 5                      HARAS-Ecurie n°5 (BV 08)      NaN
# 7      ECOLE PRIM. JEAN BAPTISTE  BOSSARD (118)      NaN
# ...                                         ...      ...
# 70037                    SALLE GERARD PHILIPE 1      NaN
# 70038                                    Mairie       16
# 70039                   SAINT BENOIT D'HEBERTOT      185
# 70040          ECOLE MATERNELLE EULOGE NOGLOTTE        0
# 70041            ECOLE PRIMAIRE EULOGE NOGLOTTE        0
#
#                            voie       complement1 complement2 lieu_dit  \
# 0                    RUE D'IENA               NaN         NaN      NaN
# 1                        Mairie               NaN         NaN      NaN
# 2      AV. DU GENERAL DE GAULLE               NaN         NaN      NaN
# 5          Rue de la Goubedière  HARAS-Ecurie n°5         NaN      NaN
# 7                 9 RUE LACROIX               NaN         NaN      NaN
# ...                         ...               ...         ...      ...
# 70037            Rue d'Artagnan               NaN         NaN      NaN
# 70038                Grande Rue     25490 BADEVEL         NaN      NaN
# 70039         route de l'Eglise            Mairie         NaN      NaN
# 70040       RUE EULOGE NOGLOTTE               NaN         NaN      NaN
# 70041       RUE EULOGE NOGLOTTE               NaN         NaN      NaN
#
#       code_postal                  commune canton_code circonscription_code  \
# 0           59000                    LILLE       59-27                59-11
# 1           63350                   BULHON       63-19                63-05
# 2           97425              Les Avirons      974-01               974-07
# 5           50000                 SAINT LO       50-23                50-01
# 7           97490          SAINTE CLOTILDE      974-09               974-01
# ...           ...                      ...         ...                  ...
# 70037       02600        VILLERS-COTTERETS       02-21                02-05
# 70038       25490                  BADEVEL       25-01                25-04
# 70039       14130  SAINT BENOIT D'HEBERTOT       14-21                14-04
# 70040       97113                GOURBEYRE      971-20               971-04
# 70041       97113                GOURBEYRE      971-20               971-04
#
#        longitude   latitude  geo_score     geo_type  \
# 0       3.043027  50.621124       0.96       street
# 1            NaN        NaN       0.00          NaN
# 2      55.333200 -21.242358       0.88  housenumber
# 5      -1.074428  49.117378       0.95       street
# 7      55.483666 -20.893953       0.96  housenumber
# ...          ...        ...        ...          ...
# 70037   3.097397  49.260343       0.95       street
# 70038   6.939282  47.500913       0.94  housenumber
# 70039   0.270550  49.316366       0.62       street
# 70040 -61.709542  15.991323       0.95       street
# 70041 -61.709542  15.991323       0.95       street
#
#                                             geo_adresse             geo_id  \
# 0                                Rue d'Iena 59000 Lille         59350_4658
# 1                                                   NaN                NaN
# 2      61 Avenue du Général de Gaulle 97425 Les Avirons   97401_0127_00061
# 5                   Rue de la Goubediere 50000 Saint-Lô         50502_1162
# 7                       9 Rue Lacroix 97400 Saint-Denis  BANO_974110728X_9
# ...                                                 ...                ...
# 70037            Rue d'Artagnan 02600 Villers-Cotterêts         02810_0051
# 70038                       16 Grande Rue 25490 Badevel   25040_0113_00016
# 70039  Chemin de l'Eglise 14130 Saint-Benoît-d'Hébertot       14563_396noi
# 70040               Rue Euloge Noglotte 97113 Gourbeyre         97109_0051
# 70041               Rue Euloge Noglotte 97113 Gourbeyre         97109_0051
#
#       geo_ligne                          geo_l4 geo_l5
# 0             G                      RUE D IENA    NaN
# 1           NaN                             NaN    NaN
# 2             G  61 AVENUE DU GENERAL DE GAULLE    NaN
# 5             G            RUE DE LA GOUBEDIERE    NaN
# 7             G                   9 RUE LACROIX    NaN
# ...         ...                             ...    ...
# 70037         G                  RUE D ARTAGNAN    NaN
# 70038         G                   16 GRANDE RUE    NaN
# 70039         G              CHEMIN DE L EGLISE    NaN
# 70040         G             RUE EULOGE NOGLOTTE    NaN
# 70041         G             RUE EULOGE NOGLOTTE    NaN
#
# [61524 rows x 22 columns]

# %%
bv_louis[bv_louis["libelle"]=="Villers-Cotterêts"]
# Out:
#       commune_code            libelle code                         libelle.1  \
# 1845         02810  Villers-Cotterêts  001                  SALLE DEMOUSTIER
# 1983         02810  Villers-Cotterêts  003       SALLE MARIE-LOUISE LABOURET
# 2267         02810  Villers-Cotterêts  004             SALLE GEORGES BOURDON
# 2788         02810  Villers-Cotterêts  005         ECOLE MATERNELLE JEAN ZAY
# 2857         02810  Villers-Cotterêts  008            SALLE GERARD PHILIPE 2
# 17006        02810  Villers-Cotterêts  002  PREAU ECOLE PRIMAIRE L. LAGRANGE
# 27371        02810  Villers-Cotterêts  006                  SALLE DE L'OASIS
# 70037        02810  Villers-Cotterêts  007            SALLE GERARD PHILIPE 1
#
#       num_voie                   voie complement1 complement2 lieu_dit  \
# 1845       NaN       Place de l'école         NaN         NaN      NaN
# 1983       NaN    Place du 8 mai 1945         NaN         NaN      NaN
# 2267       NaN  Place Aristide Briand         NaN         NaN      NaN
# 2788       NaN        Avenue Jean Zay         NaN         NaN      NaN
# 2857       NaN         Rue d'Artagnan         NaN         NaN      NaN
# 17006      NaN       Rue Léo Lagrange         NaN         NaN      NaN
# 27371      126         Rue Demoustier         NaN         NaN      NaN
# 70037      NaN         Rue d'Artagnan         NaN         NaN      NaN
#
#       code_postal            commune canton_code circonscription_code  \
# 1845        02600  VILLERS-COTTERETS       02-21                02-05
# 1983        02600  VILLERS-COTTERETS       02-21                02-05
# 2267        02600  VILLERS-COTTERETS       02-21                02-05
# 2788        02600  VILLERS-COTTERETS       02-21                02-05
# 2857        02600  VILLERS-COTTERETS       02-21                02-05
# 17006       02600  VILLERS-COTTERETS       02-21                02-05
# 27371       02600  VILLERS-COTTERETS       02-21                02-05
# 70037       02600  VILLERS-COTTERETS       02-21                02-05
#
#        longitude   latitude  geo_score     geo_type  \
# 1845    3.090036  49.253037       0.68       street
# 1983         NaN        NaN       0.00          NaN
# 2267    3.092460  49.255926       0.95       street
# 2788    3.100256  49.258798       0.95       street
# 2857    3.097397  49.260343       0.95       street
# 17006   3.088572  49.254815       0.95       street
# 27371   3.086796  49.247827       0.95  housenumber
# 70037   3.097397  49.260343       0.95       street
#
#                                          geo_adresse            geo_id  \
# 1845        Place des Ecoles 02600 Villers-Cotterêts        02810_0180
# 1983                                             NaN               NaN
# 2267   Place Aristide Briand 02600 Villers-Cotterêts        02810_0049
# 2788         Avenue Jean Zay 02600 Villers-Cotterêts        02810_0355
# 2857          Rue d'Artagnan 02600 Villers-Cotterêts        02810_0051
# 17006       Rue Leo Lagrange 02600 Villers-Cotterêts        02810_0380
# 27371     126 Rue Démoustier 02600 Villers-Cotterêts  02810_0150_00126
# 70037         Rue d'Artagnan 02600 Villers-Cotterêts        02810_0051
#
#       geo_ligne                 geo_l4 geo_l5
# 1845          G       PLACE DES ECOLES    NaN
# 1983        NaN                    NaN    NaN
# 2267          G  PLACE ARISTIDE BRIAND    NaN
# 2788          G        AVENUE JEAN ZAY    NaN
# 2857          G         RUE D ARTAGNAN    NaN
# 17006         G       RUE LEO LAGRANGE    NaN
# 27371         G     126 RUE DEMOUSTIER    NaN
# 70037         G         RUE D ARTAGNAN    NaN

# %%
bv_louis[(bv_louis["longitude"]==3.097397)&(bv_louis["latitude"]==49.260343)]
# Out:
#       commune_code            libelle code               libelle.1 num_voie  \
# 2857         02810  Villers-Cotterêts  008  SALLE GERARD PHILIPE 2      NaN
# 70037        02810  Villers-Cotterêts  007  SALLE GERARD PHILIPE 1      NaN
#
#                  voie complement1 complement2 lieu_dit code_postal  \
# 2857   Rue d'Artagnan         NaN         NaN      NaN       02600
# 70037  Rue d'Artagnan         NaN         NaN      NaN       02600
#
#                  commune canton_code circonscription_code  longitude  \
# 2857   VILLERS-COTTERETS       02-21                02-05   3.097397
# 70037  VILLERS-COTTERETS       02-21                02-05   3.097397
#
#         latitude  geo_score geo_type                             geo_adresse  \
# 2857   49.260343       0.95   street  Rue d'Artagnan 02600 Villers-Cotterêts
# 70037  49.260343       0.95   street  Rue d'Artagnan 02600 Villers-Cotterêts
#
#            geo_id geo_ligne          geo_l4 geo_l5
# 2857   02810_0051         G  RUE D ARTAGNAN    NaN
# 70037  02810_0051         G  RUE D ARTAGNAN    NaN

# %%
resultats_electoraux = pd.read_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Jointure_geo_v2/DATA_IRIS_BV/RESULTATS_ELECTORAUX/EUR2019_BV_6_PARTIS.csv", sep=";", dtype=str, encoding="iso-8859-1")

# %%
resultats_electoraux[resultats_electoraux["Code_commune"]=="02810"]
# Out:
#      Code_commune Libellé de la commune Code du bvote Inscrits Exprimes  \
# 1532        02810     Villers-Cotterêts          0001      797      370
# 1533        02810     Villers-Cotterêts          0002      916      397
# 1534        02810     Villers-Cotterêts          0003     1073      463
# 1535        02810     Villers-Cotterêts          0004      820      353
# 1536        02810     Villers-Cotterêts          0005      879      370
# 1537        02810     Villers-Cotterêts          0006      898      470
# 1538        02810     Villers-Cotterêts          0007      791      279
# 1539        02810     Villers-Cotterêts          0008      853      301
#
#      % Voix/Exp LFI % Voix/Exp_LREM % Voix/Exp_PS % Voix/Exp_RN  \
# 1532           4,32           24,05          2,70         26,76
# 1533           5,79           11,08          5,29         43,83
# 1534           6,70           13,82          4,10         44,92
# 1535           4,25           16,43          3,97         34,84
# 1536           7,30           17,84          3,51         31,89
# 1537           5,53           18,09          5,11         35,11
# 1538          11,11           12,54          5,38         48,39
# 1539          10,96           13,62          2,66         44,52
#
#      % Voix/Exp_UMP % Voix/Exp_EELV
# 1532           9,19           13,78
# 1533           9,07            8,31
# 1534           3,02            8,64
# 1535           7,93           11,90
# 1536           7,30           10,54
# 1537           7,45           10,21
# 1538           2,87            5,02
# 1539           1,66            4,65

# %%
#resultats_electoraux[resultats_electoraux["Libellé de la commune"]=="Saint-Benoît-d'Hébertot"]

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69297 entries, 0 to 69296
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Code_commune           69297 non-null  object
#  1   Libellé de la commune  69297 non-null  object
#  2   Code du bvote          69297 non-null  object
#  3   Inscrits               69297 non-null  object
#  4   Exprimes               69297 non-null  object
#  5   % Voix/Exp LFI         69297 non-null  object
#  6   % Voix/Exp_LREM        69297 non-null  object
#  7   % Voix/Exp_PS          69297 non-null  object
#  8   % Voix/Exp_RN          69297 non-null  object
#  9   % Voix/Exp_UMP         69297 non-null  object
#  10  % Voix/Exp_EELV        69297 non-null  object
# dtypes: object(11)
# memory usage: 5.8+ MB

# %%
#for kk in resultats_electoraux["Code du bvote"].value_counts().index:
#    print(kk)

# %%
for k in bv_euro["Code du b.vote"].value_counts().index:
    try:
        int(k)
    except:
        print(k, "-"*5,(bv_euro["Code du b.vote"]==k).sum()  )
# Out:
# BV02 ----- 2
# BV01 ----- 2
# 13.3 ----- 1
# 10.1 ----- 1
# 182A ----- 1
# 18.3 ----- 1
# 06.1 ----- 1
# 10.2 ----- 1
# 112A ----- 1
# 14.1 ----- 1
# 03.2 ----- 1
# JUS1 ----- 1
# 11.2 ----- 1
# 22.2 ----- 1
# 0A03 ----- 1
# 12.1 ----- 1
# 08.1 ----- 1
# 07.1 ----- 1
# 04.4 ----- 1
# 09.3 ----- 1
# 198A ----- 1
# 05.2 ----- 1
# 01.1 ----- 1
# 0D21 ----- 1
# 14.2 ----- 1
# 0A21 ----- 1
# 0B11 ----- 1
# 0E41 ----- 1
# 15.1 ----- 1
# 04.2 ----- 1
# 081A ----- 1
# 192A ----- 1
# 0A01 ----- 1
# 02.2 ----- 1
# 0D11 ----- 1
# 23.3 ----- 1
# 0F11 ----- 1
# 21.2 ----- 1
# 23.1 ----- 1
# 0F21 ----- 1
# 22.1 ----- 1
# 0C11 ----- 1
# 04.3 ----- 1
# 16.4 ----- 1
# 15.2 ----- 1
# 0H21 ----- 1
# 09.1 ----- 1
# 083A ----- 1
# 04.1 ----- 1
# 0H11 ----- 1
# 19.2 ----- 1
# 11.3 ----- 1
# 07.3 ----- 1
# 0E11 ----- 1
# 20.1 ----- 1
# 13.1 ----- 1
# 18.1 ----- 1
# 11.1 ----- 1
# 16.1 ----- 1
# 13.2 ----- 1
# 0G11 ----- 1
# 0A11 ----- 1
# 17.2 ----- 1
# 23.2 ----- 1
# 06.2 ----- 1
# 02.1 ----- 1
# 16.3 ----- 1
# 19.1 ----- 1
# 17.1 ----- 1
# 0A02 ----- 1
# 0E31 ----- 1
# 16.2 ----- 1
# 24.1 ----- 1
# 05.1 ----- 1
# 07.2 ----- 1
# 21.1 ----- 1
# 17.3 ----- 1
# 10.3 ----- 1
# 18.2 ----- 1
# 03.1 ----- 1
# 069A ----- 1
# 09.2 ----- 1
# 0C21 ----- 1
# 19.3 ----- 1
# 0E21 ----- 1
# 0G21 ----- 1
# 0F31 ----- 1

# %%
for k in bv_louis[(bv_louis.loc[:,"libelle"]!="Montbéliard")&(bv_louis.loc[:,"libelle"]!="Toulouse")]["code"].value_counts().index:
    try:
        int(k)
    except:
        print(k,'-'*5, (bv_louis["code"]==k).sum() )
# Out:
# 3.1 ----- 1
# 6.1 ----- 1
# 23.3 ----- 1
# 5.1 ----- 1
# 10.2 ----- 1
# 9.2 ----- 1
# 21.2 ----- 1
# 9.3 ----- 1
# 17.1 ----- 1
# 5.2 ----- 1
# 4.4 ----- 1
# 2.1 ----- 1
# 14.2 ----- 1
# 16.1 ----- 1
# 11.1 ----- 1
# 19.3 ----- 1
# 23.1 ----- 1
# 20.1 ----- 1
# 13.2 ----- 1
# 10.1 ----- 1
# 3.2 ----- 1
# 01 - 1 ----- 1
# 16.2 ----- 1
# 4.1 ----- 1
# 17.3 ----- 1
# 15.1 ----- 1
# 16.4 ----- 1
# 6.2 ----- 1
# 18.3 ----- 1
# 13 - 2 ----- 1
# 18.1 ----- 1
# 19.2 ----- 1
# 22.1 ----- 1
# 11.3 ----- 1
# 7.2 ----- 1
# 12.1 ----- 1
# 21.1 ----- 1
# 14.1 ----- 1
# 11.2 ----- 1
# 1.1 ----- 1
# 18.2 ----- 1
# 13.1 ----- 1
# 13.3 ----- 1
# 7.1 ----- 1
# 8.1 ----- 1
# 17.2 ----- 1
# 22.2 ----- 1
# 10.3 ----- 1
# 2.2 ----- 1
# 7.3 ----- 1
# 16.3 ----- 1
# 15.2 ----- 1
# 24.1 ----- 1
# 9.1 ----- 1
# 4.2 ----- 1
# 23.2 ----- 1
# 4.3 ----- 1
# 19.1 ----- 1

# %%
bv_louis[bv_louis["code"]=="13 - 2"]
# Out:
#       commune_code              libelle    code                    libelle.1  \
# 42014        77058  Bussy-Saint-Georges  13 - 2  Groupe Scolaire George Sand
#
#       num_voie voie complement1 complement2 lieu_dit code_postal commune  \
# 42014      NaN  NaN         NaN         NaN      NaN         NaN     NaN
#
#       canton_code circonscription_code  longitude   latitude  geo_score  \
# 42014         NaN                  NaN   2.721899  48.833553       0.52
#
#       geo_type                                        geo_adresse      geo_id  \
# 42014   street  Cour Père Damien Boulogne 77600 Bussy-Saint-Ge...  77058_0326
#
#       geo_ligne                     geo_l4 geo_l5
# 42014         D  COUR PERE DAMIEN BOULOGNE    NaN

# %%
bv_louis[bv_louis["libelle"]=="Bussy-Saint-Georges"]

#for i in bv_louis[bv_louis["libelle"]=="Toulouse"]["code"].value_counts().index:
#    print(i)
# Out:
#       commune_code              libelle    code  \
# 3187         77058  Bussy-Saint-Georges      10
# 33952        77058  Bussy-Saint-Georges      11
# 37207        77058  Bussy-Saint-Georges       4
# 37562        77058  Bussy-Saint-Georges       8
# 41430        77058  Bussy-Saint-Georges      12
# 42002        77058  Bussy-Saint-Georges      10
# 42014        77058  Bussy-Saint-Georges  13 - 2
# 42136        77058  Bussy-Saint-Georges       5
# 42335        77058  Bussy-Saint-Georges       3
# 42754        77058  Bussy-Saint-Georges       6
# 43400        77058  Bussy-Saint-Georges       2
# 43462        77058  Bussy-Saint-Georges       1
# 43543        77058  Bussy-Saint-Georges       9
# 44046        77058  Bussy-Saint-Georges       3
# 45067        77058  Bussy-Saint-Georges       7
# 59313        77058  Bussy-Saint-Georges       1
# 59385        77058  Bussy-Saint-Georges       2
# 59461        77058  Bussy-Saint-Georges       3
# 59693        77058  Bussy-Saint-Georges       4
# 59747        77058  Bussy-Saint-Georges       5
# 60335        77058  Bussy-Saint-Georges       6
# 60396        77058  Bussy-Saint-Georges       7
# 60445        77058  Bussy-Saint-Georges       8
# 60535        77058  Bussy-Saint-Georges       9
# 60556        77058  Bussy-Saint-Georges      11
# 60589        77058  Bussy-Saint-Georges      12
# 60735        77058  Bussy-Saint-Georges      13
#
#                                    libelle.1 num_voie  \
# 3187             Groupe Scolaire Jules Verne      NaN
# 33952        Groupe Scolaire Antoine Giroust      NaN
# 37207       Groupe Scolaire Charles Perrault      NaN
# 37562            Groupe Scolaire Jules Verne      NaN
# 41430  Espace Charlemagne salle Louise Wiess      NaN
# 42002            Groupe Scolaire Jules Verne      NaN
# 42014            Groupe Scolaire George Sand      NaN
# 42136          Groupe Scolaire Louis Braille      NaN
# 42335    Groupe Scolaire Jean de la Fontaine      NaN
# 42754          Groupe Scolaire Louis Braille      NaN
# 43400  Groupe Scolaire du Clos Saint Georges      NaN
# 43462             Salle du Conseil Municipal      NaN
# 43543            Groupe Scolaire Jules Verne      NaN
# 44046    Groupe Scolaire Jean de La Fontaine      NaN
# 45067          Groupe Scolaire Louis Guibert      NaN
# 59313             Salle du Conseil Municipal      NaN
# 59385  Groupe Scolaire du Clos Saint-Georges      NaN
# 59461    Groupe Scolaire Jean de La Fontaine      NaN
# 59693       Groupe Scolaire Charles Perrault      NaN
# 59747          Groupe Scolaire Louis Braille      NaN
# 60335          Groupe Scolaire Louis Braille      NaN
# 60396          Groupe Scolaire Louis Guibert      NaN
# 60445            Groupe Scolaire Jules Verne      NaN
# 60535            Groupe Scolaire Jules Verne      NaN
# 60556        Groupe Scolaire Antoine Giroust      NaN
# 60589                     Espace Charlemagne      NaN
# 60735            Groupe Scolaire George Sand      NaN
#
#                                    voie complement1 complement2 lieu_dit  \
# 3187           18 Avenue Haroun Tazieff         NaN         NaN      NaN
# 33952                               NaN         NaN         NaN      NaN
# 37207                               NaN         NaN         NaN      NaN
# 37562                               NaN         NaN         NaN      NaN
# 41430                               NaN         NaN         NaN      NaN
# 42002                               NaN         NaN         NaN      NaN
# 42014                               NaN         NaN         NaN      NaN
# 42136                               NaN         NaN         NaN      NaN
# 42335                               NaN         NaN         NaN      NaN
# 42754                               NaN         NaN         NaN      NaN
# 43400                               NaN         NaN         NaN      NaN
# 43462                               NaN         NaN         NaN      NaN
# 43543                               NaN         NaN         NaN      NaN
# 44046                               NaN         NaN         NaN      NaN
# 45067                               NaN         NaN         NaN      NaN
# 59313                Place de la Mairie         NaN         NaN      NaN
# 59385   41 Avenue du Clos Saint Georges         NaN         NaN      NaN
# 59461               18 Rue Buissonnière         NaN         NaN      NaN
# 59693      30 Boulevard T. de Champagne         NaN         NaN      NaN
# 59747           15 Boulevard des Genêts         NaN         NaN      NaN
# 60335           15 Boulevard des Genêts         NaN         NaN      NaN
# 60396  148 Avenue du Clos Saint Georges         NaN         NaN      NaN
# 60445          18 Avenue Haroun Tazieff         NaN         NaN      NaN
# 60535          18 Avenue Haroun Tazieff         NaN         NaN      NaN
# 60556      20 rue du Clos Saint Georges         NaN         NaN      NaN
# 60589                  2 passage Carter         NaN         NaN      NaN
# 60735         6 boulevard Louis Guibert         NaN         NaN      NaN
#
#       code_postal           commune canton_code circonscription_code  \
# 3187        77600  BUSSY ST GEORGES       77-22                77-08
# 33952         NaN               NaN         NaN                  NaN
# 37207         NaN               NaN         NaN                  NaN
# 37562         NaN               NaN         NaN                  NaN
# 41430         NaN               NaN         NaN                  NaN
# 42002         NaN               NaN         NaN                  NaN
# 42014         NaN               NaN         NaN                  NaN
# 42136         NaN               NaN         NaN                  NaN
# 42335         NaN               NaN         NaN                  NaN
# 42754         NaN               NaN         NaN                  NaN
# 43400         NaN               NaN         NaN                  NaN
# 43462         NaN               NaN         NaN                  NaN
# 43543         NaN               NaN         NaN                  NaN
# 44046         NaN               NaN         NaN                  NaN
# 45067         NaN               NaN         NaN                  NaN
# 59313       77600  BUSSY ST GEORGES       77-22                77-08
# 59385       77600  BUSSY ST GEORGES       77-22                77-08
# 59461       77600  BUSSY ST GEORGES       77-22                77-08
# 59693       77600  BUSSY ST GEORGES       77-22                77-08
# 59747       77600  BUSSY ST GEORGES       77-22                77-08
# 60335       77600  BUSSY ST GEORGES       77-22                77-08
# 60396       77600  BUSSY ST GEORGES       77-22                77-08
# 60445       77600  BUSSY ST GEORGES       77-22                77-08
# 60535       77600  BUSSY ST GEORGES       77-22                77-08
# 60556       77600  BUSSY ST GEORGES       77-22                77-08
# 60589       77600  BUSSY ST GEORGES       77-22                77-08
# 60735       77600  BUSSY ST GEORGES       77-22                77-08
#
#        longitude   latitude  geo_score     geo_type  \
# 3187    2.712853  48.834694       0.95  housenumber
# 33952        NaN        NaN       0.00          NaN
# 37207   2.718295  48.843965       0.44       street
# 37562        NaN        NaN       0.00          NaN
# 41430        NaN        NaN       0.00          NaN
# 42002        NaN        NaN       0.00          NaN
# 42014   2.721899  48.833553       0.52       street
# 42136        NaN        NaN       0.00          NaN
# 42335        NaN        NaN       0.00          NaN
# 42754        NaN        NaN       0.00          NaN
# 43400   2.697023  48.843911       0.42  housenumber
# 43462        NaN        NaN       0.00          NaN
# 43543        NaN        NaN       0.00          NaN
# 44046   2.706414  48.835124       0.44       street
# 45067        NaN        NaN       0.00          NaN
# 59313   2.697963  48.843815       0.95       street
# 59385   2.714223  48.843349       0.95  housenumber
# 59461   2.708444  48.839746       0.95  housenumber
# 59693   2.714804  48.841782       0.89  housenumber
# 59747   2.720648  48.842144       0.95  housenumber
# 60335   2.720648  48.842144       0.95  housenumber
# 60396   2.731794  48.845374       0.95  housenumber
# 60445   2.712853  48.834694       0.95  housenumber
# 60535   2.712853  48.834694       0.95  housenumber
# 60556   2.709495  48.842669       0.86  housenumber
# 60589   2.709547  48.837603       0.95  housenumber
# 60735   2.731438  48.844841       0.95  housenumber
#
#                                              geo_adresse            geo_id  \
# 3187   18 Avenue Haroun Tazieff 77600 Bussy-Saint-Geo...  77058_0116_00018
# 33952                                                NaN               NaN
# 37207  Allée du Poirier Cornet 77600 Bussy-Saint-Georges   BANO_770580346Y
# 37562                                                NaN               NaN
# 41430                                                NaN               NaN
# 42002                                                NaN               NaN
# 42014  Cour Père Damien Boulogne 77600 Bussy-Saint-Ge...        77058_0326
# 42136                                                NaN               NaN
# 42335                                                NaN               NaN
# 42754                                                NaN               NaN
# 43400     2 Place de la Mairie 77600 Bussy-Saint-Georges  77058_0220_00002
# 43462                                                NaN               NaN
# 43543                                                NaN               NaN
# 44046  Rue du Souvenir Français 77600 Bussy-Saint-Geo...        77058_0385
# 45067                                                NaN               NaN
# 59313       Place de la Mairie 77600 Bussy-Saint-Georges        77058_0220
# 59385  41 Avenue du Clos Saint Georges 77600 Bussy-Sa...  77058_0152_00041
# 59461      18 Rue Buissonnière 77600 Bussy-Saint-Georges  77058_0042_00018
# 59693  30 Boulevard Thibaud de Champagne 77600 Bussy-...  77058_0401_00030
# 59747  15 Boulevard des Genêts 77600 Bussy-Saint-Georges  77058_0102_00015
# 60335  15 Boulevard des Genêts 77600 Bussy-Saint-Georges  77058_0102_00015
# 60396  148 Avenue du Clos Saint Georges 77600 Bussy-S...  77058_0152_00148
# 60445  18 Avenue Haroun Tazieff 77600 Bussy-Saint-Geo...  77058_0116_00018
# 60535  18 Avenue Haroun Tazieff 77600 Bussy-Saint-Geo...  77058_0116_00018
# 60556  20 Avenue du Clos Saint Georges 77600 Bussy-Sa...  77058_0152_00020
# 60589         2 Passage Carter 77600 Bussy-Saint-Georges  77058_0031_00002
# 60735  6 Boulevard Louis Guibert 77600 Bussy-Saint-Ge...  77058_0208_00006
#
#       geo_ligne                            geo_l4 geo_l5
# 3187          G          18 AVENUE HAROUN TAZIEFF    NaN
# 33952       NaN                               NaN    NaN
# 37207         D           ALLEE DU POIRIER CORNET    NaN
# 37562       NaN                               NaN    NaN
# 41430       NaN                               NaN    NaN
# 42002       NaN                               NaN    NaN
# 42014         D         COUR PERE DAMIEN BOULOGNE    NaN
# 42136       NaN                               NaN    NaN
# 42335       NaN                               NaN    NaN
# 42754       NaN                               NaN    NaN
# 43400         D              2 PLACE DE LA MAIRIE    NaN
# 43462       NaN                               NaN    NaN
# 43543       NaN                               NaN    NaN
# 44046         D          RUE DU SOUVENIR FRANCAIS    NaN
# 45067       NaN                               NaN    NaN
# 59313         G                PLACE DE LA MAIRIE    NaN
# 59385         G   41 AVENUE DU CLOS SAINT GEORGES    NaN
# 59461         G               18 RUE BUISSONNIERE    NaN
# 59693         G        30 BD THIBAUD DE CHAMPAGNE    NaN
# 59747         G           15 BOULEVARD DES GENETS    NaN
# 60335         G           15 BOULEVARD DES GENETS    NaN
# 60396         G  148 AVENUE DU CLOS SAINT GEORGES    NaN
# 60445         G          18 AVENUE HAROUN TAZIEFF    NaN
# 60535         G          18 AVENUE HAROUN TAZIEFF    NaN
# 60556         G   20 AVENUE DU CLOS SAINT GEORGES    NaN
# 60589         G                  2 PASSAGE CARTER    NaN
# 60735         G         6 BOULEVARD LOUIS GUIBERT    NaN

# %%
bv_euro[bv_euro["Libellé de la commune"]=="Marcillac-la-Croze"]
#for i in bv_euro[bv_euro["Libellé de la commune"]=="Toulouse"]["Code du b.vote"].value_counts().index:
#    print(i)
# Out:
#       Code du département Libellé du département Code de la commune  \
# 10910                  19                Corrèze                126
#
#       Libellé de la commune Code du b.vote Inscrits Abstentions % Abs/Ins  \
# 10910    Marcillac-la-Croze           0001      184          66     35.87
#
#       Votants % Vot/Ins Blancs % Blancs/Ins % Blancs/Vot Nuls % Nuls/Ins  \
# 10910     118     64.13      5         2.72         4.24    6       3.26
#
#       % Nuls/Vot Exprimés % Exp/Ins % Exp/Vot N°Liste_1  \
# 10910       5.08      107     58.15     90.68         1
#
#       Libellé Abrégé Liste_1 Libellé Etendu Liste_1 Nom Tête de Liste_1  \
# 10910    LA FRANCE INSOUMISE    LA FRANCE INSOUMISE         AUBRY Manon
#
#       Voix_1 % Voix/Ins_1 % Voix/Exp_1 N°Liste_2 Libellé Abrégé Liste_2  \
# 10910      8         4.35         7.48         2      UNE FRANCE ROYALE
#
#                        Libellé Etendu Liste_2  Nom Tête de Liste_2 Voix_2  \
# 10910  UNE FRANCE ROYALE AU COEUR DE L'EUROPE  DE PREVOISIN Robert      0
#
#       % Voix/Ins_2 % Voix/Exp_2 N°Liste_3 Libellé Abrégé Liste_3  \
# 10910            0            0         3        LA LIGNE CLAIRE
#
#       Libellé Etendu Liste_3 Nom Tête de Liste_3 Voix_3 % Voix/Ins_3  \
# 10910        LA LIGNE CLAIRE        CAMUS Renaud      0            0
#
#       % Voix/Exp_3 N°Liste_4 Libellé Abrégé Liste_4 Libellé Etendu Liste_4  \
# 10910            0         4           PARTI PIRATE           PARTI PIRATE
#
#       Nom Tête de Liste_4 Voix_4 % Voix/Ins_4 % Voix/Exp_4 N°Liste_5  \
# 10910        MARIE Florie      0            0            0         5
#
#       Libellé Abrégé Liste_5  \
# 10910            RENAISSANCE
#
#                                   Libellé Etendu Liste_5 Nom Tête de Liste_5  \
# 10910  RENAISSANCE SOUTENUE PAR LA RÉPUBLIQUE EN MARC...    LOISEAU Nathalie
#
#       Voix_5 % Voix/Ins_5 % Voix/Exp_5 N°Liste_6     Libellé Abrégé Liste_6  \
# 10910     24        13.04        22.43         6  DÉMOCRATIE REPRÉSENTATIVE
#
#           Libellé Etendu Liste_6 Nom Tête de Liste_6 Voix_6 % Voix/Ins_6  \
# 10910  DÉMOCRATIE REPRÉSENTATIVE       TRAORÉ Hamada      0            0
#
#       % Voix/Exp_6 N°Liste_7 Libellé Abrégé Liste_7  \
# 10910            0         7     ENSEMBLE PATRIOTES
#
#                                   Libellé Etendu Liste_7 Nom Tête de Liste_7  \
# 10910  ENSEMBLE PATRIOTES ET GILETS JAUNES : POUR LA ...   PHILIPPOT Florian
#
#        ... % Voix/Ins_25 % Voix/Exp_25 N°Liste_26 Libellé Abrégé Liste_26  \
# 10910  ...             0             0         26               ESPERANTO
#
#                                  Libellé Etendu Liste_26 Nom Tête de Liste_26  \
# 10910  ESPÉRANTO - LANGUE COMMUNE ÉQUITABLE POUR L'EU...    DIEUMEGARD Pierre
#
#       Voix_26 % Voix/Ins_26 % Voix/Exp_26 N°Liste_27 Libellé Abrégé Liste_27  \
# 10910       0             0             0         27     ÉVOLUTION CITOYENNE
#
#       Libellé Etendu Liste_27  Nom Tête de Liste_27 Voix_27 % Voix/Ins_27  \
# 10910     ÉVOLUTION CITOYENNE  CHALENÇON Christophe       0             0
#
#       % Voix/Exp_27 N°Liste_28 Libellé Abrégé Liste_28  \
# 10910             0         28          ALLIANCE JAUNE
#
#                       Libellé Etendu Liste_28 Nom Tête de Liste_28 Voix_28  \
# 10910  ALLIANCE JAUNE, LA RÉVOLTE PAR LE VOTE      LALANNE Francis       0
#
#       % Voix/Ins_28 % Voix/Exp_28 N°Liste_29 Libellé Abrégé Liste_29  \
# 10910             0             0         29     UNION DROITE-CENTRE
#
#                Libellé Etendu Liste_29     Nom Tête de Liste_29 Voix_29  \
# 10910  UNION DE LA DROITE ET DU CENTRE  BELLAMY François-Xavier      10
#
#       % Voix/Ins_29 % Voix/Exp_29 N°Liste_30 Libellé Abrégé Liste_30  \
# 10910          5.43          9.35         30         EUROPE ÉCOLOGIE
#
#       Libellé Etendu Liste_30 Nom Tête de Liste_30 Voix_30 % Voix/Ins_30  \
# 10910         EUROPE ÉCOLOGIE        JADOT Yannick      15          8.15
#
#       % Voix/Exp_30 N°Liste_31 Libellé Abrégé Liste_31  \
# 10910         14.02         31        PARTI ANIMALISTE
#
#       Libellé Etendu Liste_31 Nom Tête de Liste_31 Voix_31 % Voix/Ins_31  \
# 10910        PARTI ANIMALISTE         THOUY Hélène       1          0.54
#
#       % Voix/Exp_31 N°Liste_32  Libellé Abrégé Liste_32  \
# 10910          0.93         32  LES OUBLIES DE L'EUROPE
#
#                                  Libellé Etendu Liste_32 Nom Tête de Liste_32  \
# 10910  LES OUBLIÉS DE L'EUROPE - ARTISANS, COMMERÇANT...        BIDOU Olivier
#
#       Voix_32 % Voix/Ins_32 % Voix/Exp_32 N°Liste_33 Libellé Abrégé Liste_33  \
# 10910       1          0.54          0.93         33                   UDLEF
#
#                                  Libellé Etendu Liste_33  \
# 10910  UDLEF (UNION DÉMOCRATIQUE POUR LA LIBERTÉ ÉGAL...
#
#        Nom Tête de Liste_33 Voix_33 % Voix/Ins_33 % Voix/Exp_33 N°Liste_34  \
# 10910  PERSON Christian Luc       0             0             0         34
#
#          Libellé Abrégé Liste_34            Libellé Etendu Liste_34  \
# 10910  EUROPE AU SERVICE PEUPLES  UNE EUROPE AU SERVICE DES PEUPLES
#
#       Nom Tête de Liste_34 Voix_34 % Voix/Ins_34 % Voix/Exp_34
# 10910        AZERGUI Nagib       0             0             0
#
# [1 rows x 257 columns]

# %%
bv_louis[bv_louis["commune_code"]=="77451"]
# Out:
#     commune_code        libelle   code          libelle.1 num_voie  \
# 424        77451  Signy-Signets  1 - 2  Salle Polyvalente      NaN
# 520        77451  Signy-Signets  1 - 1             Mairie        5
#
#                      voie complement1 complement2 lieu_dit code_postal  \
# 424  Place de la Jouvence         NaN         NaN      NaN       77640
# 520     Place de l'Eglise         NaN         NaN      NaN       77640
#
#            commune canton_code circonscription_code  longitude   latitude  \
# 424  SIGNY-SIGNETS       77-06                77-05   3.069259  48.927300
# 520  SIGNY-SIGNETS       77-06                77-05   3.068093  48.927631
#
#      geo_score     geo_type                               geo_adresse  \
# 424       0.94       street  Place de la Jouvence 77640 Signy-Signets
# 520       0.94  housenumber   5 Place de l'Eglise 77640 Signy-Signets
#
#                geo_id geo_ligne                geo_l4 geo_l5
# 424        77451_0036         G  PLACE DE LA JOUVENCE    NaN
# 520  77451_0026_00005         G   5 PLACE DE L EGLISE    NaN

# %%
resultats_electoraux[resultats_electoraux["Code_commune"]=="77451"]
# Out:
#       Code_commune Libellé de la commune Code du bvote Inscrits Exprimes  \
# 54632        77451         Signy-Signets          0001      446      213
#
#       % Voix/Exp LFI % Voix/Exp_LREM % Voix/Exp_PS % Voix/Exp_RN  \
# 54632           5,16           12,21          4,23         36,15
#
#       % Voix/Exp_UMP % Voix/Exp_EELV
# 54632           7,51            9,39

# %%
print(bv_louis["longitude"].isnull().sum())
print((bv_louis[bv_louis["longitude"].isnull()]["libelle.1"]=="MAIRIE").sum())
print((bv_louis[bv_louis["longitude"].isnull()]["libelle.1"]=="Mairie").sum())
print((bv_louis[bv_louis["longitude"].isnull()]["libelle.1"]=="mairie").sum())
print((bv_louis[bv_louis["longitude"].isnull()]["libelle.1"]=="M A I R I E").sum())
# il manque des mairies (ex: maries de ...)
# Out:
# 9053
# 2135
# 711
# 11
# 123

# %%
bv_louis[bv_louis["longitude"].isnull()]
# Out:
#       commune_code                 libelle  code  \
# 1            63058                  Bulhon     1
# 3            98712                    Arue     1
# 4            54141               Coyviller     1
# 6            21560  Saint-Martin-de-la-Mer     1
# 8            98725                  Mahina     2
# ...            ...                     ...   ...
# 70011        97129             Sainte-Rose  0004
# 70017        97129             Sainte-Rose  0005
# 70018        97129             Sainte-Rose  0006
# 70035        97616                    Sada   168
# 70036        97129             Sainte-Rose  0008
#
#                               libelle.1 num_voie                    voie  \
# 1                              BUREAU 1      NaN                  Mairie
# 3                              Bureau 1      NaN  Ecole Ahutoru primaire
# 4                                MAIRIE      NaN                     NaN
# 6      Mairie de Saint-Martin-de-la-Mer      NaN                     NaN
# 8                                MAHINA      NaN                     NaN
# ...                                 ...      ...                     ...
# 70011          REFECTOIRE ECOLE MIXTE 1      NaN                     NaN
# 70017              ECOLE MIXTE DE VIARD      NaN                     NaN
# 70018              ECOLE MIXTE DE VIARD      NaN                     NaN
# 70035    ECOLE PRIMAIRE SADA 2 BANDRANI      NaN                     NaN
# 70036          ECOLE MIXTE DE LA BOUCAN      NaN                     NaN
#
#       complement1 complement2               lieu_dit code_postal  \
# 1             NaN         NaN                    NaN       63350
# 3             NaN         NaN  Ecole primaire Arue 1       98701
# 4             NaN         NaN                    NaN         NaN
# 6             NaN         NaN                    NaN       21210
# 8             NaN         NaN                    NaN       98725
# ...           ...         ...                    ...         ...
# 70011         NaN         NaN                    NaN       97115
# 70017         NaN         NaN                    NaN       97115
# 70018         NaN         NaN                    NaN       97115
# 70035         NaN         NaN                    NaN       97640
# 70036         NaN         NaN                    NaN       97115
#
#                       commune canton_code circonscription_code  longitude  \
# 1                      BULHON       63-19                63-05        NaN
# 3                        ARUE         NaN               987-01        NaN
# 4                         NaN       54-05                54-04        NaN
# 6      SAINT-MARTIN-DE-LA-MER       21-01                21-05        NaN
# 8                      MAHINA         NaN               987-02        NaN
# ...                       ...         ...                  ...        ...
# 70011             SAINTE-ROSE      971-19               971-03        NaN
# 70017             SAINTE-ROSE      971-19               971-03        NaN
# 70018             SAINTE-ROSE      971-19               971-03        NaN
# 70035                    SADA      976-12               976-02        NaN
# 70036             SAINTE-ROSE      971-19               971-03        NaN
#
#        latitude  geo_score geo_type geo_adresse geo_id geo_ligne geo_l4 geo_l5
# 1           NaN        0.0      NaN         NaN    NaN       NaN    NaN    NaN
# 3           NaN        0.0      NaN         NaN    NaN       NaN    NaN    NaN
# 4           NaN        0.0      NaN         NaN    NaN       NaN    NaN    NaN
# 6           NaN        0.0      NaN         NaN    NaN       NaN    NaN    NaN
# 8           NaN        0.0      NaN         NaN    NaN       NaN    NaN    NaN
# ...         ...        ...      ...         ...    ...       ...    ...    ...
# 70011       NaN        0.0      NaN         NaN    NaN       NaN    NaN    NaN
# 70017       NaN        0.0      NaN         NaN    NaN       NaN    NaN    NaN
# 70018       NaN        0.0      NaN         NaN    NaN       NaN    NaN    NaN
# 70035       NaN        0.0      NaN         NaN    NaN       NaN    NaN    NaN
# 70036       NaN        0.0      NaN         NaN    NaN       NaN    NaN    NaN
#
# [9053 rows x 22 columns]

# %%
test=bv_louis.drop_duplicates(subset=["code","longitude","latitude"])

# %%
print(test["longitude"].isnull().sum())
print((test[test["longitude"].isnull()]["libelle.1"]=="MAIRIE").sum())
print((test[test["longitude"].isnull()]["libelle.1"]=="Mairie").sum())
print((test[test["longitude"].isnull()]["libelle.1"]=="mairie").sum())
print((test[test["longitude"].isnull()]["libelle.1"]=="M A I R I E").sum())
# Out:
# 535
# 300
# 7
# 1
# 0

# %%
bv_louis
# Out:
#       commune_code                  libelle code  \
# 0            59350                    Lille  807
# 1            63058                   Bulhon    1
# 2            97401              Les Avirons  001
# 3            98712                     Arue    1
# 4            54141                Coyviller    1
# ...            ...                      ...  ...
# 70037        02810        Villers-Cotterêts  007
# 70038        25040                  Badevel    1
# 70039        14563  Saint-Benoît-d'Hébertot  001
# 70040        97109                Gourbeyre  004
# 70041        97109                Gourbeyre  005
#
#                               libelle.1 num_voie                      voie  \
# 0                          ECOLE AMPERE       64                RUE D'IENA
# 1                              BUREAU 1      NaN                    Mairie
# 2                    MAIRIE DES AVIRONS       61  AV. DU GENERAL DE GAULLE
# 3                              Bureau 1      NaN    Ecole Ahutoru primaire
# 4                                MAIRIE      NaN                       NaN
# ...                                 ...      ...                       ...
# 70037            SALLE GERARD PHILIPE 1      NaN            Rue d'Artagnan
# 70038                            Mairie       16                Grande Rue
# 70039           SAINT BENOIT D'HEBERTOT      185         route de l'Eglise
# 70040  ECOLE MATERNELLE EULOGE NOGLOTTE        0       RUE EULOGE NOGLOTTE
# 70041    ECOLE PRIMAIRE EULOGE NOGLOTTE        0       RUE EULOGE NOGLOTTE
#
#          complement1 complement2               lieu_dit code_postal  \
# 0                NaN         NaN                    NaN       59000
# 1                NaN         NaN                    NaN       63350
# 2                NaN         NaN                    NaN       97425
# 3                NaN         NaN  Ecole primaire Arue 1       98701
# 4                NaN         NaN                    NaN         NaN
# ...              ...         ...                    ...         ...
# 70037            NaN         NaN                    NaN       02600
# 70038  25490 BADEVEL         NaN                    NaN       25490
# 70039         Mairie         NaN                    NaN       14130
# 70040            NaN         NaN                    NaN       97113
# 70041            NaN         NaN                    NaN       97113
#
#                        commune canton_code circonscription_code  longitude  \
# 0                        LILLE       59-27                59-11   3.043027
# 1                       BULHON       63-19                63-05        NaN
# 2                  Les Avirons      974-01               974-07  55.333200
# 3                         ARUE         NaN               987-01        NaN
# 4                          NaN       54-05                54-04        NaN
# ...                        ...         ...                  ...        ...
# 70037        VILLERS-COTTERETS       02-21                02-05   3.097397
# 70038                  BADEVEL       25-01                25-04   6.939282
# 70039  SAINT BENOIT D'HEBERTOT       14-21                14-04   0.270550
# 70040                GOURBEYRE      971-20               971-04 -61.709542
# 70041                GOURBEYRE      971-20               971-04 -61.709542
#
#         latitude  geo_score     geo_type  \
# 0      50.621124       0.96       street
# 1            NaN       0.00          NaN
# 2     -21.242358       0.88  housenumber
# 3            NaN       0.00          NaN
# 4            NaN       0.00          NaN
# ...          ...        ...          ...
# 70037  49.260343       0.95       street
# 70038  47.500913       0.94  housenumber
# 70039  49.316366       0.62       street
# 70040  15.991323       0.95       street
# 70041  15.991323       0.95       street
#
#                                             geo_adresse            geo_id  \
# 0                                Rue d'Iena 59000 Lille        59350_4658
# 1                                                   NaN               NaN
# 2      61 Avenue du Général de Gaulle 97425 Les Avirons  97401_0127_00061
# 3                                                   NaN               NaN
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 70037            Rue d'Artagnan 02600 Villers-Cotterêts        02810_0051
# 70038                       16 Grande Rue 25490 Badevel  25040_0113_00016
# 70039  Chemin de l'Eglise 14130 Saint-Benoît-d'Hébertot      14563_396noi
# 70040               Rue Euloge Noglotte 97113 Gourbeyre        97109_0051
# 70041               Rue Euloge Noglotte 97113 Gourbeyre        97109_0051
#
#       geo_ligne                          geo_l4 geo_l5
# 0             G                      RUE D IENA    NaN
# 1           NaN                             NaN    NaN
# 2             G  61 AVENUE DU GENERAL DE GAULLE    NaN
# 3           NaN                             NaN    NaN
# 4           NaN                             NaN    NaN
# ...         ...                             ...    ...
# 70037         G                  RUE D ARTAGNAN    NaN
# 70038         G                   16 GRANDE RUE    NaN
# 70039         G              CHEMIN DE L EGLISE    NaN
# 70040         G             RUE EULOGE NOGLOTTE    NaN
# 70041         G             RUE EULOGE NOGLOTTE    NaN
#
# [70042 rows x 22 columns]

# %%
list_0 = ["Code du département","Libellé du département","Code de la commune","Libellé de la commune","Code du b.vote","Inscrits","Abstentions","% Abs/Ins","Votants","% Vot/Ins","Blancs","% Blancs/Ins","% Blancs/Vot","Nuls","% Nuls/Ins","% Nuls/Vot","Exprimés","% Exp/Ins","% Exp/Vot"]

# %%
list_1=["N°Liste","Libellé Abrégé Liste","Libellé Etendu Liste","Nom Tête de Liste","Voix","% Voix/Ins","% Voix/Exp"]
list_1
# Out:
# ['N°Liste',
#  'Libellé Abrégé Liste',
#  'Libellé Etendu Liste',
#  'Nom Tête de Liste',
#  'Voix',
#  '% Voix/Ins',
#  '% Voix/Exp']

# %%
list_totale=[]
m=1
for j in range(1,35):
    for i in list_1 :
        list_totale.append(i+str("_")+str(j))

# %%
pd.DataFrame(list_totale).T
# Out:
#          0                       1                       2    \
# 0  N°Liste_1  Libellé Abrégé Liste_1  Libellé Etendu Liste_1
#
#                    3       4             5             6          7    \
# 0  Nom Tête de Liste_1  Voix_1  % Voix/Ins_1  % Voix/Exp_1  N°Liste_2
#
#                       8                       9                    10   \
# 0  Libellé Abrégé Liste_2  Libellé Etendu Liste_2  Nom Tête de Liste_2
#
#       11            12            13         14                      15   \
# 0  Voix_2  % Voix/Ins_2  % Voix/Exp_2  N°Liste_3  Libellé Abrégé Liste_3
#
#                       16                   17      18            19   \
# 0  Libellé Etendu Liste_3  Nom Tête de Liste_3  Voix_3  % Voix/Ins_3
#
#             20         21                      22                      23   \
# 0  % Voix/Exp_3  N°Liste_4  Libellé Abrégé Liste_4  Libellé Etendu Liste_4
#
#                    24      25            26            27         28   \
# 0  Nom Tête de Liste_4  Voix_4  % Voix/Ins_4  % Voix/Exp_4  N°Liste_5
#
#                       29                      30                   31   \
# 0  Libellé Abrégé Liste_5  Libellé Etendu Liste_5  Nom Tête de Liste_5
#
#       32            33            34         35                      36   \
# 0  Voix_5  % Voix/Ins_5  % Voix/Exp_5  N°Liste_6  Libellé Abrégé Liste_6
#
#                       37                   38      39            40   \
# 0  Libellé Etendu Liste_6  Nom Tête de Liste_6  Voix_6  % Voix/Ins_6
#
#             41         42                      43                      44   \
# 0  % Voix/Exp_6  N°Liste_7  Libellé Abrégé Liste_7  Libellé Etendu Liste_7
#
#                    45      46            47            48         49   \
# 0  Nom Tête de Liste_7  Voix_7  % Voix/Ins_7  % Voix/Exp_7  N°Liste_8
#
#                       50                      51                   52   \
# 0  Libellé Abrégé Liste_8  Libellé Etendu Liste_8  Nom Tête de Liste_8
#
#       53            54            55         56                      57   \
# 0  Voix_8  % Voix/Ins_8  % Voix/Exp_8  N°Liste_9  Libellé Abrégé Liste_9
#
#                       58                   59      60            61   \
# 0  Libellé Etendu Liste_9  Nom Tête de Liste_9  Voix_9  % Voix/Ins_9
#
#             62          63                       64   ...            173  \
# 0  % Voix/Exp_9  N°Liste_10  Libellé Abrégé Liste_10  ...  % Voix/Ins_25
#
#              174         175                      176  \
# 0  % Voix/Exp_25  N°Liste_26  Libellé Abrégé Liste_26
#
#                        177                   178      179            180  \
# 0  Libellé Etendu Liste_26  Nom Tête de Liste_26  Voix_26  % Voix/Ins_26
#
#              181         182                      183  \
# 0  % Voix/Exp_26  N°Liste_27  Libellé Abrégé Liste_27
#
#                        184                   185      186            187  \
# 0  Libellé Etendu Liste_27  Nom Tête de Liste_27  Voix_27  % Voix/Ins_27
#
#              188         189                      190  \
# 0  % Voix/Exp_27  N°Liste_28  Libellé Abrégé Liste_28
#
#                        191                   192      193            194  \
# 0  Libellé Etendu Liste_28  Nom Tête de Liste_28  Voix_28  % Voix/Ins_28
#
#              195         196                      197  \
# 0  % Voix/Exp_28  N°Liste_29  Libellé Abrégé Liste_29
#
#                        198                   199      200            201  \
# 0  Libellé Etendu Liste_29  Nom Tête de Liste_29  Voix_29  % Voix/Ins_29
#
#              202         203                      204  \
# 0  % Voix/Exp_29  N°Liste_30  Libellé Abrégé Liste_30
#
#                        205                   206      207            208  \
# 0  Libellé Etendu Liste_30  Nom Tête de Liste_30  Voix_30  % Voix/Ins_30
#
#              209         210                      211  \
# 0  % Voix/Exp_30  N°Liste_31  Libellé Abrégé Liste_31
#
#                        212                   213      214            215  \
# 0  Libellé Etendu Liste_31  Nom Tête de Liste_31  Voix_31  % Voix/Ins_31
#
#              216         217                      218  \
# 0  % Voix/Exp_31  N°Liste_32  Libellé Abrégé Liste_32
#
#                        219                   220      221            222  \
# 0  Libellé Etendu Liste_32  Nom Tête de Liste_32  Voix_32  % Voix/Ins_32
#
#              223         224                      225  \
# 0  % Voix/Exp_32  N°Liste_33  Libellé Abrégé Liste_33
#
#                        226                   227      228            229  \
# 0  Libellé Etendu Liste_33  Nom Tête de Liste_33  Voix_33  % Voix/Ins_33
#
#              230         231                      232  \
# 0  % Voix/Exp_33  N°Liste_34  Libellé Abrégé Liste_34
#
#                        233                   234      235            236  \
# 0  Libellé Etendu Liste_34  Nom Tête de Liste_34  Voix_34  % Voix/Ins_34
#
#              237
# 0  % Voix/Exp_34
#
# [1 rows x 238 columns]

# %%
pd.DataFrame(list_0+list_totale).T
# Out:
#                    0                       1                   2    \
# 0  Code du département  Libellé du département  Code de la commune
#
#                      3               4         5            6          7    \
# 0  Libellé de la commune  Code du b.vote  Inscrits  Abstentions  % Abs/Ins
#
#        8          9       10            11            12    13          14   \
# 0  Votants  % Vot/Ins  Blancs  % Blancs/Ins  % Blancs/Vot  Nuls  % Nuls/Ins
#
#           15        16         17         18         19   \
# 0  % Nuls/Vot  Exprimés  % Exp/Ins  % Exp/Vot  N°Liste_1
#
#                       20                      21                   22   \
# 0  Libellé Abrégé Liste_1  Libellé Etendu Liste_1  Nom Tête de Liste_1
#
#       23            24            25         26                      27   \
# 0  Voix_1  % Voix/Ins_1  % Voix/Exp_1  N°Liste_2  Libellé Abrégé Liste_2
#
#                       28                   29      30            31   \
# 0  Libellé Etendu Liste_2  Nom Tête de Liste_2  Voix_2  % Voix/Ins_2
#
#             32         33                      34                      35   \
# 0  % Voix/Exp_2  N°Liste_3  Libellé Abrégé Liste_3  Libellé Etendu Liste_3
#
#                    36      37            38            39         40   \
# 0  Nom Tête de Liste_3  Voix_3  % Voix/Ins_3  % Voix/Exp_3  N°Liste_4
#
#                       41                      42                   43   \
# 0  Libellé Abrégé Liste_4  Libellé Etendu Liste_4  Nom Tête de Liste_4
#
#       44            45            46         47                      48   \
# 0  Voix_4  % Voix/Ins_4  % Voix/Exp_4  N°Liste_5  Libellé Abrégé Liste_5
#
#                       49                   50      51            52   \
# 0  Libellé Etendu Liste_5  Nom Tête de Liste_5  Voix_5  % Voix/Ins_5
#
#             53         54                      55                      56   \
# 0  % Voix/Exp_5  N°Liste_6  Libellé Abrégé Liste_6  Libellé Etendu Liste_6
#
#                    57      58            59            60         61   \
# 0  Nom Tête de Liste_6  Voix_6  % Voix/Ins_6  % Voix/Exp_6  N°Liste_7
#
#                       62                      63                   64   ...  \
# 0  Libellé Abrégé Liste_7  Libellé Etendu Liste_7  Nom Tête de Liste_7  ...
#
#              192            193         194                      195  \
# 0  % Voix/Ins_25  % Voix/Exp_25  N°Liste_26  Libellé Abrégé Liste_26
#
#                        196                   197      198            199  \
# 0  Libellé Etendu Liste_26  Nom Tête de Liste_26  Voix_26  % Voix/Ins_26
#
#              200         201                      202  \
# 0  % Voix/Exp_26  N°Liste_27  Libellé Abrégé Liste_27
#
#                        203                   204      205            206  \
# 0  Libellé Etendu Liste_27  Nom Tête de Liste_27  Voix_27  % Voix/Ins_27
#
#              207         208                      209  \
# 0  % Voix/Exp_27  N°Liste_28  Libellé Abrégé Liste_28
#
#                        210                   211      212            213  \
# 0  Libellé Etendu Liste_28  Nom Tête de Liste_28  Voix_28  % Voix/Ins_28
#
#              214         215                      216  \
# 0  % Voix/Exp_28  N°Liste_29  Libellé Abrégé Liste_29
#
#                        217                   218      219            220  \
# 0  Libellé Etendu Liste_29  Nom Tête de Liste_29  Voix_29  % Voix/Ins_29
#
#              221         222                      223  \
# 0  % Voix/Exp_29  N°Liste_30  Libellé Abrégé Liste_30
#
#                        224                   225      226            227  \
# 0  Libellé Etendu Liste_30  Nom Tête de Liste_30  Voix_30  % Voix/Ins_30
#
#              228         229                      230  \
# 0  % Voix/Exp_30  N°Liste_31  Libellé Abrégé Liste_31
#
#                        231                   232      233            234  \
# 0  Libellé Etendu Liste_31  Nom Tête de Liste_31  Voix_31  % Voix/Ins_31
#
#              235         236                      237  \
# 0  % Voix/Exp_31  N°Liste_32  Libellé Abrégé Liste_32
#
#                        238                   239      240            241  \
# 0  Libellé Etendu Liste_32  Nom Tête de Liste_32  Voix_32  % Voix/Ins_32
#
#              242         243                      244  \
# 0  % Voix/Exp_32  N°Liste_33  Libellé Abrégé Liste_33
#
#                        245                   246      247            248  \
# 0  Libellé Etendu Liste_33  Nom Tête de Liste_33  Voix_33  % Voix/Ins_33
#
#              249         250                      251  \
# 0  % Voix/Exp_33  N°Liste_34  Libellé Abrégé Liste_34
#
#                        252                   253      254            255  \
# 0  Libellé Etendu Liste_34  Nom Tête de Liste_34  Voix_34  % Voix/Ins_34
#
#              256
# 0  % Voix/Exp_34
#
# [1 rows x 257 columns]

# %%
# Out:
#       commune_code                  libelle code  \
# 0            59350                    Lille  807
# 1            63058                   Bulhon    1
# 2            97401              Les Avirons  001
# 3            98712                     Arue    1
# 4            54141                Coyviller    1
# ...            ...                      ...  ...
# 70037        02810        Villers-Cotterêts  007
# 70038        25040                  Badevel    1
# 70039        14563  Saint-Benoît-d'Hébertot  001
# 70040        97109                Gourbeyre  004
# 70041        97109                Gourbeyre  005
#
#                               libelle.1 num_voie                      voie  \
# 0                          ECOLE AMPERE       64                RUE D'IENA
# 1                              BUREAU 1      NaN                    Mairie
# 2                    MAIRIE DES AVIRONS       61  AV. DU GENERAL DE GAULLE
# 3                              Bureau 1      NaN    Ecole Ahutoru primaire
# 4                                MAIRIE      NaN                       NaN
# ...                                 ...      ...                       ...
# 70037            SALLE GERARD PHILIPE 1      NaN            Rue d'Artagnan
# 70038                            Mairie       16                Grande Rue
# 70039           SAINT BENOIT D'HEBERTOT      185         route de l'Eglise
# 70040  ECOLE MATERNELLE EULOGE NOGLOTTE        0       RUE EULOGE NOGLOTTE
# 70041    ECOLE PRIMAIRE EULOGE NOGLOTTE        0       RUE EULOGE NOGLOTTE
#
#          complement1 complement2               lieu_dit code_postal  \
# 0                NaN         NaN                    NaN       59000
# 1                NaN         NaN                    NaN       63350
# 2                NaN         NaN                    NaN       97425
# 3                NaN         NaN  Ecole primaire Arue 1       98701
# 4                NaN         NaN                    NaN         NaN
# ...              ...         ...                    ...         ...
# 70037            NaN         NaN                    NaN       02600
# 70038  25490 BADEVEL         NaN                    NaN       25490
# 70039         Mairie         NaN                    NaN       14130
# 70040            NaN         NaN                    NaN       97113
# 70041            NaN         NaN                    NaN       97113
#
#                        commune canton_code circonscription_code  longitude  \
# 0                        LILLE       59-27                59-11   3.043027
# 1                       BULHON       63-19                63-05        NaN
# 2                  Les Avirons      974-01               974-07  55.333200
# 3                         ARUE         NaN               987-01        NaN
# 4                          NaN       54-05                54-04        NaN
# ...                        ...         ...                  ...        ...
# 70037        VILLERS-COTTERETS       02-21                02-05   3.097397
# 70038                  BADEVEL       25-01                25-04   6.939282
# 70039  SAINT BENOIT D'HEBERTOT       14-21                14-04   0.270550
# 70040                GOURBEYRE      971-20               971-04 -61.709542
# 70041                GOURBEYRE      971-20               971-04 -61.709542
#
#         latitude  geo_score     geo_type  \
# 0      50.621124       0.96       street
# 1            NaN       0.00          NaN
# 2     -21.242358       0.88  housenumber
# 3            NaN       0.00          NaN
# 4            NaN       0.00          NaN
# ...          ...        ...          ...
# 70037  49.260343       0.95       street
# 70038  47.500913       0.94  housenumber
# 70039  49.316366       0.62       street
# 70040  15.991323       0.95       street
# 70041  15.991323       0.95       street
#
#                                             geo_adresse            geo_id  \
# 0                                Rue d'Iena 59000 Lille        59350_4658
# 1                                                   NaN               NaN
# 2      61 Avenue du Général de Gaulle 97425 Les Avirons  97401_0127_00061
# 3                                                   NaN               NaN
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 70037            Rue d'Artagnan 02600 Villers-Cotterêts        02810_0051
# 70038                       16 Grande Rue 25490 Badevel  25040_0113_00016
# 70039  Chemin de l'Eglise 14130 Saint-Benoît-d'Hébertot      14563_396noi
# 70040               Rue Euloge Noglotte 97113 Gourbeyre        97109_0051
# 70041               Rue Euloge Noglotte 97113 Gourbeyre        97109_0051
#
#       geo_ligne                          geo_l4 geo_l5
# 0             G                      RUE D IENA    NaN
# 1           NaN                             NaN    NaN
# 2             G  61 AVENUE DU GENERAL DE GAULLE    NaN
# 3           NaN                             NaN    NaN
# 4           NaN                             NaN    NaN
# ...         ...                             ...    ...
# 70037         G                  RUE D ARTAGNAN    NaN
# 70038         G                   16 GRANDE RUE    NaN
# 70039         G              CHEMIN DE L EGLISE    NaN
# 70040         G             RUE EULOGE NOGLOTTE    NaN
# 70041         G             RUE EULOGE NOGLOTTE    NaN
#
# [69988 rows x 22 columns]
