# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option("display.max_row",50)
pd.set_option("display.max_columns",130)

# %%
L_BV_complet_orig = pd.read_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/13_09_CORRIGER/L_BV_complet.csv",sep=",", header=0, dtype=str)
L_BV_complet = L_BV_complet_orig.copy()
L_BV_complet
# Out:
#       commune_co                libelle  code code_corr Code du bv Code du _1  \
# 0          72191                  Mayet     1       NaN       0001          1
# 1          72191                  Mayet     2       NaN       0002          2
# 2          81199                 Padiès     1       NaN       0001          1
# 3          59225               Feignies  0003       NaN       0003          3
# 4          60397   Le Mesnil-Conteville     1       NaN       0001          1
# ...          ...                    ...   ...       ...        ...        ...
# 59036      13056              Martigues     2       NaN       0002          2
# 59037      34003                   Agde    14       NaN       0014         14
# 59038      83069                 Hyères   009       NaN       0009          9
# 59039      22198         Pleumeur-Bodou   005       NaN       0005          5
# 59040      06104  Roquebrune-Cap-Martin   011       NaN       0011         11
#
# ...

# %%
L_BV_complet["IRIS"].value_counts()
# Out:
# 276640000    38
# 140610000    20
# 766180000    20
# 762140000    19
# 270490000    15
#              ..
# 543670000     1
# 394580000     1
# 882980000     1
# 580970000     1
# 262860000     1
# Name: IRIS, Length: 36970, dtype: int64

# %%
columns_L = L_BV_complet.columns
columns_1 = []

# %%
columns_1.append(L_BV_complet.columns[28])

columns_1.append(L_BV_complet.columns[25])

columns_1 = columns_1 + list(L_BV_complet.columns[:25].values)
columns_1 = columns_1 + list(L_BV_complet.columns[26:28].values)
columns_1 = columns_1 + list(L_BV_complet.columns[29:].values)

# %%
L_BV_complet_bon_ordre = L_BV_complet[columns_1]
L_BV_complet_bon_ordre
# Out:
#             IRIS  ID_BV commune_co                libelle  code code_corr  \
# 0      721910000  17428      72191                  Mayet     1       NaN
# 1      721910000  55161      72191                  Mayet     2       NaN
# 2      811990000   2567      81199                 Padiès     1       NaN
# 3      592250102  36765      59225               Feignies  0003       NaN
# 4      603970000  38892      60397   Le Mesnil-Conteville     1       NaN
# ...          ...    ...        ...                    ...   ...       ...
# 59036  130560106  10739      13056              Martigues     2       NaN
# 59037  340030201  11466      34003                   Agde    14       NaN
# 59038  830690123  27023      83069                 Hyères   009       NaN
# 59039  223430000  48580      22198         Pleumeur-Bodou   005       NaN
# 59040  060120102  49467      06104  Roquebrune-Cap-Martin   011       NaN
#
#       Code du bv Code du _1  \
# 0           0001          1
# ...

# %%
I_IRIS_NAN_a_ordonner_orig = pd.read_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/13_09_CORRIGER/I_IRIS_NAN_a_ordonner.csv",sep=",", header=0, dtype=str)
I_IRIS_NAN_a_ordonner = I_IRIS_NAN_a_ordonner_orig.copy()
I_IRIS_NAN_a_ordonner
# Out:
#             IRIS  ID_BV B_commune_          B_libelle B_code B_code_cor  \
# 0      772480000  46984      77132           Coupvray      2        NaN
# 1      514260000  23394      51092             Broyes    001        NaN
# 2      144260000  48767      14077  Blangy-le-Château    001        NaN
# 3      784740000  31005      78439            Mulcent    001        NaN
# 4      102430000  50349      10214         Magnicourt     01        NaN
# ...          ...    ...        ...                ...    ...        ...
# 19352  910270114  39698      91027         Athis-Mons    016        NaN
# 19353  910270114  44900      91027         Athis-Mons    001        NaN
# 19354  104300000   8531      51377         Montépreux     01        NaN
# 19355  394510000  27758      39452               Rans      1        NaN
# 19356  930010501  42860      93001      Aubervilliers    010        NaN
#
#       B_Code du B_Code d_1                         B_libelle_ B_num_voie  \
# ...

# %%
I_IRIS_NAN_a_ordonner["IRIS"].value_counts()
# Out:
# 061570104    13
# 061570103    13
# 061570107    13
# 061570101    13
# 061570102    13
#              ..
# 511080302     1
# 720760000     1
# 672010000     1
# 110510000     1
# 751135020     1
# Name: IRIS, Length: 11620, dtype: int64

# %%
36970+11620
# Out:
# 48590

# %%
colonnes_final_1=['IRIS','ID_BV','commune_code', 'libelle', 'code', 'code_corr', 'Code du bvote',
       'Code du bvote_sans 0 devant', 'libelle_bv', 'num_voie', 'voie',
       'complement1', 'complement2', 'lieu_dit', 'code_postal', 'commune',
       'canton_code', 'circonscription_code', 'longitude', 'latitude',
       'geo_score', 'geo_type', 'geo_adresse', 'geo_id', 'geo_ligne', 'geo_l4',
       'geo_l5','INSEE_COM','NOM_COM','I_NOM_IRIS']

# %%
L_BV_complet_bon_ordre.columns = colonnes_final_1
I_IRIS_NAN_a_ordonner.columns = colonnes_final_1

# %%
fusion = pd.concat([L_BV_complet_bon_ordre, I_IRIS_NAN_a_ordonner], axis=0)

# %%
fusion["ID_BV"].value_counts()
# Out:
# 31400    13
# 16557    10
# 16680     9
# 55673     7
# 21440     7
#          ..
# 51946     1
# 20157     1
# 13599     1
# 10477     1
# 8980      1
# Name: ID_BV, Length: 59041, dtype: int64

# %%
fusion.shape[0]-59041
# Out:
# 19357

# %%
19357-11620
# Out:
# 7737

# %%
fusion[fusion["ID_BV"]=="31400"]
# Out:
#             IRIS  ID_BV commune_code libelle code code_corr Code du bvote  \
# 53860  2B1110000  31400        2B111   Felce    1       NaN          0001
# 2682   2B3340000  31400        2B111   Felce    1       NaN          0001
# 3253   2B1640000  31400        2B111   Felce    1       NaN          0001
# 4892   2B2160000  31400        2B111   Felce    1       NaN          0001
# 5412   2B3210000  31400        2B111   Felce    1       NaN          0001
# 6808   2B3380000  31400        2B111   Felce    1       NaN          0001
# 9584   2B2270000  31400        2B111   Felce    1       NaN          0001
# 9987   2B0670000  31400        2B111   Felce    1       NaN          0001
# 10912  2B1790000  31400        2B111   Felce    1       NaN          0001
# 10995  2B2080000  31400        2B111   Felce    1       NaN          0001
# 12949  2B2340000  31400        2B111   Felce    1       NaN          0001
# 14152  2B2020000  31400        2B111   Felce    1       NaN          0001
# ...

# %%
78398-59041
# Out:
# 19357

# %%
19357-11620
# Out:
# 7737

# %%
fusion.drop_duplicates(subset=["Code du bvote_sans 0 devant","longitude","latitude"])
# Out:
#             IRIS  ID_BV commune_code                libelle  code code_corr  \
# 0      721910000  17428        72191                  Mayet     1       NaN
# 1      721910000  55161        72191                  Mayet     2       NaN
# 2      811990000   2567        81199                 Padiès     1       NaN
# 3      592250102  36765        59225               Feignies  0003       NaN
# 4      603970000  38892        60397   Le Mesnil-Conteville     1       NaN
# ...          ...    ...          ...                    ...   ...       ...
# 59036  130560106  10739        13056              Martigues     2       NaN
# 59037  340030201  11466        34003                   Agde    14       NaN
# 59038  830690123  27023        83069                 Hyères   009       NaN
# 59039  223430000  48580        22198         Pleumeur-Bodou   005       NaN
# 59040  060120102  49467        06104  Roquebrune-Cap-Martin   011       NaN
#
#       Code du bvote Code du bvote_sans 0 devant  \
# ...

# %%
78398-59041
# Out:
# 19357

# %%
fusion.drop_duplicates(subset=["IRIS","longitude","latitude"])
# Out:
#             IRIS  ID_BV commune_code               libelle  code code_corr  \
# 0      721910000  17428        72191                 Mayet     1       NaN
# 2      811990000   2567        81199                Padiès     1       NaN
# 3      592250102  36765        59225              Feignies  0003       NaN
# 4      603970000  38892        60397  Le Mesnil-Conteville     1       NaN
# 5      383820104  38576        38382          Saint-Égrève   006       NaN
# ...          ...    ...          ...                   ...   ...       ...
# 19350  930050101  59010        93005      Aulnay-sous-Bois   028       NaN
# 19352  910270114  39698        91027            Athis-Mons   016       NaN
# 19354  104300000   8531        51377            Montépreux    01       NaN
# 19355  394510000  27758        39452                  Rans     1       NaN
# 19356  930010501  42860        93001         Aubervilliers   010       NaN
#
#       Code du bvote Code du bvote_sans 0 devant  \
# ...

# %%
###
data_final =  fusion.drop(["INSEE_COM","NOM_COM","I_NOM_IRIS"], axis=1)
data_final.shape
# Out:
# (78398, 27)

# %%
# ENREGISTREMENT
data_final.to_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/13_09_CORRIGER/NUMERO_DE_IRIS__BV_reconcialiation.txt",sep=";", index=False)

# %%
data_final.head(2)
# Out:
#         IRIS  ID_BV commune_code libelle code code_corr Code du bvote  \
# 0  721910000  17428        72191   Mayet    1       NaN          0001
# 1  721910000  55161        72191   Mayet    2       NaN          0002
#
#   Code du bvote_sans 0 devant             libelle_bv num_voie  \
# 0                           1  ECOLE ST EXUPERY NORD      NaN
# 1                           2   ECOLE ST EXUPERY SUD      NaN
#
#                 voie complement1  complement2 lieu_dit code_postal commune  \
# 0  Rue Paul FOURNIER         NaN  72360 MAYET      NaN       72360   MAYET
# 1  Rue Paul FOURNIER         NaN  72360 MAYET      NaN       72360   MAYET
#
#   canton_code circonscription_code          longitude            latitude  \
# 0       72-08                72-03  0.271986000000000  47.759019000000002
# 1       72-08                72-03  0.271986000000000  47.759019000000002
#
#   geo_score geo_type                    geo_adresse      geo_id geo_ligne  \
# ...

# %%
########################"""
IRIS_FM_orig = pd.read_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/13_09_CORRIGER/IRIS_FM.txt",sep=";", header=0, dtype=str)
IRIS_FM = IRIS_FM_orig.copy()

# %%
IRIS_FM = IRIS_FM.drop(["REG","DEP","UU2010","COM","LIBCOM","TRIRIS","GRD_QUART","LIBIRIS","TYP_IRIS","MODIF_IRIS","LAB_IRIS"], axis=1)
IRIS_FM
# Out:
#             IRIS           C17_MEN      C17_MENPSEUL      C17_MENHSEUL  \
# 0      010010000  315.154411747961  71.9296252481944  35.9648126240972
# 1      010020000   107.16049382716  30.6172839506173  25.5144032921811
# 2      010040101  818.920838366148  420.956661379367  220.250379106688
# 3      010040102   1716.8049286733  810.251047139158   377.36576295732
# 4      010040201  1932.15371936262  831.658993297402   381.25485915517
# ...          ...               ...               ...               ...
# 48585  956800112  610.109974906573   120.40387627638  51.7984905000734
# 48586  956800113  647.251779873958  136.329359447637  81.3824967036576
# 48587  956800114  546.455989610396  157.713354764675  67.5548460838215
# 48588  956820000  73.4126984126983  14.6825396825397  9.78835978835978
# 48589  956900000  149.993370427891  45.6223108237432  20.2765825883303
#
#            C17_MENFSEUL       C17_MENSFAM        C17_MENFAM   C17_MENCOUPSENF  \
# ...

# %%
jointure_final = data_final.merge(IRIS_FM, on="IRIS")
jointure_final
# Out:
#             IRIS  ID_BV commune_code               libelle  code code_corr  \
# 0      721910000  17428        72191                 Mayet     1       NaN
# 1      721910000  55161        72191                 Mayet     2       NaN
# 2      811990000   2567        81199                Padiès     1       NaN
# 3      592250102  36765        59225              Feignies  0003       NaN
# 4      603970000  38892        60397  Le Mesnil-Conteville     1       NaN
# ...          ...    ...          ...                   ...   ...       ...
# 78393  910270114  39698        91027            Athis-Mons   016       NaN
# 78394  910270114  44900        91027            Athis-Mons   001       NaN
# 78395  104300000   8531        51377            Montépreux    01       NaN
# 78396  394510000  27758        39452                  Rans     1       NaN
# 78397  930010501  42860        93001         Aubervilliers   010       NaN
#
#       Code du bvote Code du bvote_sans 0 devant  \
# ...

# %%
joniture_final_col_interest = jointure_final.drop(["code_corr","complement1","complement2","lieu_dit","geo_type","geo_adresse","geo_id","geo_ligne","geo_l4","geo_l5"], axis=1)
joniture_final_col_interest
# Out:
#             IRIS  ID_BV commune_code               libelle  code  \
# 0      721910000  17428        72191                 Mayet     1
# 1      721910000  55161        72191                 Mayet     2
# 2      811990000   2567        81199                Padiès     1
# 3      592250102  36765        59225              Feignies  0003
# 4      603970000  38892        60397  Le Mesnil-Conteville     1
# ...          ...    ...          ...                   ...   ...
# 78393  910270114  39698        91027            Athis-Mons   016
# 78394  910270114  44900        91027            Athis-Mons   001
# 78395  104300000   8531        51377            Montépreux    01
# 78396  394510000  27758        39452                  Rans     1
# 78397  930010501  42860        93001         Aubervilliers   010
#
#       Code du bvote Code du bvote_sans 0 devant  \
# 0              0001                           1
# 1              0002                           2
# ...

# %%
jointure_final["IRIS"].value_counts()
# Out:
# 276640000    38
# 140610000    20
# 766180000    20
# 762140000    19
# 147260000    15
#              ..
# 023820000     1
# 882940000     1
# 640010000     1
# 830690103     1
# 262860000     1
# Name: IRIS, Length: 48590, dtype: int64

# %%
jointure_final["ID_BV"].value_counts()
# Out:
# 31400    13
# 16557    10
# 16680     9
# 6652      7
# 55673     7
#          ..
# 10477     1
# 23214     1
# 47734     1
# 27387     1
# 8980      1
# Name: ID_BV, Length: 59041, dtype: int64

# %%
# ENREGISTREMENT
#jointure_final.to_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/13_09_CORRIGER/RECENSEMENT_IRIS__BV_reconcialiation.txt",sep=";", index=False)

# %%
# ENREGISTREMENT
joniture_final_col_interest.to_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/13_09_CORRIGER/RECENSEMENT_IRIS__BV_reconcialiation.txt",sep=";", index=False)

# %%
test_data_mean =joniture_final_col_interest.drop(["IRIS","commune_code","libelle","code","Code du bvote","Code du bvote_sans 0 devant","libelle_bv","num_voie","voie","code_postal","commune","canton_code","circonscription_code","longitude","latitude","geo_score"], axis=1)
test_data_mean
# Out:
#        ID_BV           C17_MEN      C17_MENPSEUL      C17_MENHSEUL  \
# 0      17428  1372.65678220089  447.579121498123  172.928296942457
# 1      55161  1372.65678220089  447.579121498123  172.928296942457
# 2       2567              90.0              25.0              15.0
# 3      36765  1008.18611906652  287.270580635821  87.2071405501599
# 4      38892              35.0              10.0               5.0
# ...      ...               ...               ...               ...
# 78393  39698  24.2179654763111               0.0               0.0
# 78394  44900  24.2179654763111               0.0               0.0
# 78395   8531              40.0              15.0              10.0
# 78396  27758  220.948787061994  63.8296495956873  34.3698113207547
# 78397  42860  962.056539832305  298.400973939694  173.036749430921
#
#            C17_MENFSEUL       C17_MENSFAM        C17_MENFAM   C17_MENCOUPSENF  \
# 0      274.650824555666  25.0027324900068  900.074928212759  503.362514570496
# ...

# %%
for j in test_data_mean.columns :
    if j!="ID_BV":
        test_data_mean.loc[:,j] = test_data_mean.loc[:,j].astype(float)

# %%
ID_BV_mean = test_data_mean.groupby(["ID_BV"]).mean()

# %%
ID_BV_mean.to_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/13_09_CORRIGER/ID_BV_mean_intermediaire.txt",sep=";", index=True)

# %%
######

 
ID_BV_mean_avec_une_nouvelle_colonne = pd.read_csv("C:/Users/Christian/Desktop/IRIS_BV_final/Bureau_de_votes_louis/13_09_CORRIGER/ID_BV_mean_intermediaire.txt",sep=";", header=0, dtype=str)

# %%
ID_BV_mean_avec_une_nouvelle_colonne
# Out:
#        ID_BV             C17_MEN       C17_MENPSEUL       C17_MENHSEUL  \
# 0          1    1230.49622261214   827.886503577334   393.789688264987
# 1         10                72.5   15.5357142857143                0.0
# 2        100     45.483870967742   15.1612903225807   15.1612903225807
# 3       1000  1054.8696312434024  525.5919687826924  201.2392939146245
# 4      10000    1334.23101922628   385.979389029922   142.759500052163
# ...      ...                 ...                ...                ...
# 59036   9995     1481.8221588262   806.961491036356    314.79294775711
# 59037   9996    1498.55654696451   535.089945416007   191.774773884646
# 59038   9997    1213.63128827586   500.758496172141   189.161723173967
# 59039   9998    1550.18724666632   582.640633162506   202.657154165067
# 59040   9999    491.563055062167   152.384547069272   54.0719360568384
#
#             C17_MENFSEUL         C17_MENSFAM        C17_MENFAM  \
# ...

# %%
ID_BV_mean_final = data_final.merge(ID_BV_mean_avec_une_nouvelle_colonne,on ="ID_BV", how="left")

#ID_BV_mean_final = ID_BV_mean_final.drop(["code_corr","complement1","complement2","lieu_dit","geo_type","geo_adresse","geo_id","geo_ligne","geo_l4","geo_l5"], axis=1)
ID_BV_mean_final["C17_MEN"].isnull().sum()
# Out:
# 0

# %%
ID_BV__IRIS =data_final.merge(ID_BV_mean_avec_une_nouvelle_colonne,on ="ID_BV")

# %%
ID_BV__IRIS_unique = ID_BV__IRIS.drop_duplicates(subset="ID_BV")

# %%
ID_BV__IRIS_unique = ID_BV__IRIS_unique.drop(["code_corr","complement1","complement2","lieu_dit","geo_type","geo_adresse","geo_id","geo_ligne","geo_l4","geo_l5"], axis=1)
ID_BV__IRIS_unique
# Out:
#             IRIS  ID_BV commune_code                libelle  code  \
# 0      721910000  17428        72191                  Mayet     1
# 1      721910000  55161        72191                  Mayet     2
# 2      811990000   2567        81199                 Padiès     1
# 3      592250102  36765        59225               Feignies  0003
# 4      603970000  38892        60397   Le Mesnil-Conteville     1
# ...          ...    ...          ...                    ...   ...
# 78391  130560106  10739        13056              Martigues     2
# 78393  340030201  11466        34003                   Agde    14
# 78394  830690123  27023        83069                 Hyères   009
# 78395  223430000  48580        22198         Pleumeur-Bodou   005
# 78396  060120102  49467        06104  Roquebrune-Cap-Martin   011
#
#       Code du bvote Code du bvote_sans 0 devant  \
# 0              0001                           1
# 1              0002                           2
# ...

# %%
78398

# %%
ID_BV_mean_final
# Out:
#             IRIS  ID_BV commune_code                libelle  code  \
# 0      721910000  17428        72191                  Mayet     1
# 1      721910000  55161        72191                  Mayet     2
# 2      811990000   2567        81199                 Padiès     1
# 3      592250102  36765        59225               Feignies  0003
# 4      603970000  38892        60397   Le Mesnil-Conteville     1
# ...          ...    ...          ...                    ...   ...
# 78393  340030201  11466        34003                   Agde    14
# 78394  830690123  27023        83069                 Hyères   009
# 78395  223430000  48580        22198         Pleumeur-Bodou   005
# 78396  060120102  49467        06104  Roquebrune-Cap-Martin   011
# 78397  061040103  49467        06104  Roquebrune-Cap-Martin   011
#
#       Code du bvote Code du bvote_sans 0 devant  \
# 0              0001                           1
# 1              0002                           2
# ...
